# %% [markdown]
# # Code

# %%
# !date
# Out:
# Wed Oct  4 11:36:54 AM UTC 2023

# %%
# !nvidia-smi
# Out:
# Wed Oct  4 11:37:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip  install  -q tiktoken==0.4.0  langchain==0.0.231 openai==0.27.8 faiss-cpu==1.7.4 gspread oauth2client nltk pydantic==1.10.8
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 29.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 73.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 103.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.6 MB/s eta 0:00:00

# %%
import gdown
from langchain.llms import OpenAI
from langchain.docstore.document import Document
import requests
#database
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
#from langchain.document_loaders import TextLoader

from langchain.prompts import PromptTemplate
import pathlib
import subprocess
import tempfile
import ipywidgets as widgets
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import re
import getpass
import os
import openai
import tiktoken

class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'


HISTORY = []

# %%
MODEL_GPT_3_5_TURBO_16K = ['gpt-3.5-turbo-16k', 0.003, 0.004]
MODEL_GPT_3_5_TURBO = ['gpt-3.5-turbo', 0.0015, 0.002]  # 4,097 tokens
MODEL_GPT_4 = ['gpt-4', 0.03, 0.06]  # 8,192 tokens
SELECT_MODEL_GPT = MODEL_GPT_3_5_TURBO

# %%
openai_key = getpass.getpass("OpenAI API Key:")
os.environ["OPENAI_API_KEY"] = openai_key
openai.api_key = openai_key
# Out:
# OpenAI API Key:··········

# %%
def insert_newlines(textstr: str, max_len: int = 170) -> str:
    words = textstr.split()
    lines = []
    current_line = ""
    for word in words:
        if len(current_line + " " + word) > max_len:
            lines.append(current_line)
            current_line = ""
        current_line += " " + word
    lines.append(current_line)
    return "\n".join(lines)

# %%
# функция для загрузки документа по ссылке из гугл драйв
def load_document_text(url: str) -> str:
    # Extract the document ID from the URL
    match_ = re.search('/document/d/([a-zA-Z0-9-_]+)', url)
    if match_ is None:
        raise ValueError('Invalid Google Docs URL')
    doc_id = match_.group(1)

    # Download the document as plain text
    response = requests.get(f'https://docs.google.com/document/d/{doc_id}/export?format=txt')
    response.raise_for_status()
    text = response.text

    return text

# %%
from langchain.text_splitter import MarkdownHeaderTextSplitter

def load_search_indexes(url: str) -> str:
    # Extract the document ID from the URL
    match_ = re.search('/document/d/([a-zA-Z0-9-_]+)', url)
    if match_ is None:
        raise ValueError('Invalid Google Docs URL')
    doc_id = match_.group(1)

    # Download the document as plain text
    response = requests.get(f'https://docs.google.com/document/d/{doc_id}/export?format=txt')
    response.raise_for_status()
    #text = response.content.decode('unicode_escape')
    text = response.text
    headers_to_split_on = [
        ("#", "Header 1"),
        ("##", "Header 2"),
        ("###", "Header 3"),
    ]

    markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
    md_header_splits = markdown_splitter.split_text(text)

    vectordateBase = FAISS.from_documents(md_header_splits, OpenAIEmbeddings())

    return vectordateBase

# %%
knowledge_base = load_search_indexes('https://docs.google.com/document/d/1eGWGl6uZQvMC3D7zJosHEJLsnouBTgym_ZBuC2EoBb0')

# %%
def _summarize_topic( dialog):
        messages = [
            {"role": "system",
             "content": "Ты - ассистент консультанта, основанный на AI. Ты умеешь профессионально суммаризировать присланные тебе диалоги консультанта и клиента. Твоя задача - суммаризировать диалог, который тебе пришел."},
            {"role": "user",
             "content": "Суммаризируй следующий диалог консультанта и клиента: " + " ".join(dialog)}
        ]

        completion = openai.ChatCompletion.create(
            model=SELECT_MODEL_GPT[0],
            messages=messages,
            temperature=0.1,  # Используем более низкую температуру для более определенной суммаризации
            max_tokens=1000  # Ограничиваем количество токенов для суммаризации
        )

        return completion.choices[0].message.content



def answer_index(topic, temp=0.1, top_similar_documents=5):
        summarize_text = ''
        if len(HISTORY) > 0:
            summarize_text = "Вот краткий обзор предыдущего диалога: " + _summarize_topic(
                [q + ' ' + (a if a is not None else '') for q, a in HISTORY])
            print(f'САММАРИ \n=== {summarize_text} \n')

        # Добавляем явное разделение между историей диалога и текущим вопросом
        input_text = summarize_text + "\n\nТекущий вопрос: " + topic

        docs = knowledge_base.similarity_search_with_score(topic, k=top_similar_documents)
        responses = []
        for i, (doc, score) in enumerate(docs):
            if score < 1: # ТУТ ТЫ МОЖЕШЬ УПРАВЛЯТЬ праметром Л2 для чанков. 0..1
                content = doc.page_content
                response = f'\n=====================Отрывок документа №{i + 1}=====================\n{content}\n'
                print(f'\n=====================Отрывок документа №{i + 1}=====================\n')
                print(f'=== score = {score}  Metadata документа ------------ {doc.metadata}')
                print(f'\n{content}\n')
                responses.append(response)


        messages = [
            {"role": "system", "content": prompt},
            {"role": "user",
             "content": f"Документ с информацией для ответа пользователю: {responses}\n\nВопрос клиента: \n{input_text}"}
        ]

        completion = openai.ChatCompletion.create(
            model=SELECT_MODEL_GPT[0],
            messages=messages,
            temperature=temp
        )

        answer = completion.choices[0].message.content

        # Добавляем вопрос пользователя и ответ системы в историю
        HISTORY.append((topic, answer if answer is not None else ''))

        return insert_newlines(answer)  # возвращает ответ

# %%
def run_dialog(system_doc_url, knowledge_base_url):

    while True:
        user_question = input('\nКлиент: ')
        if ((user_question.lower() == 'stop') or (user_question.lower() == 'стоп')):
            break
        answer = answer_index(user_question)
        print('\nМенеджер: ', answer+'\n\n')

    return

# %%
# Промпт моделей машин
prompt = load_document_text ('https://docs.google.com/document/d/1i8HA7cX4Ut-tb9rf8wOgERU7lLe66xJYscizGtSSJl0')

# %%
temperature=0.3
verbose=0
#HISTORY = [] # Убери решетку если нужно обновлять историю диалогов после запуска, если не нужно обновлять то оставь так

run_dialog(prompt, knowledge_base)
# Out:
# Клиент: Добрый день. Я первый раз в вашей компании, хотел бы понять, какие есть услуги и у вас, а главное - ваши конкурентные преимущества и отличия  от основных конкурентов, таких как BMW или Китаских производителей
#
# =====================Отрывок документа №1=====================
#
# === score = 0.37393906712532043  Metadata документа ------------ {'Header 1': 'Kia K9 2022 -  https://www.kia.ru/models/k9/desc/', 'Header 2': 'Пространство для вдохновения'}
#
# Пространство для вдохновения
# Салон Kia K9 поможет вам избавиться от вчерашней усталости и начать деньс новым вдохновением. Эргономичные удобные сиденья, роскошный интерьер,инновационный интерфейс с функцией распознавания рукописноговвода обеспечат исключительный опыт, который заинтригует и вдохновит вас.
# Фото https://cdn.kia.ru/resize/1920x960/media-data/infographics/k9/pic3.jpg
#
#
# =====================Отрывок документа №2=====================
#
# === score = 0.38431188464164734  Metadata документа ------------ {'Header 1': 'Kia Picanto 2022 -  https://www.kia.ru/models/picanto/desc/', 'Header 2': 'Вдохновляйтесь. Заряжайтесь'}
#
# Вдохновляйтесь. Заряжайтесь
# Перед вами модный автомобиль, идеальный для городских улиц и скоростных магистралей. Дерзкий дизайн, продуманный интерьер и передовые технологии безопасности воплощают собой автомобиль, способный притягивать взгляды и восхищать, куда бы вы ни отправились.
# Фото https://cdn.kia.ru/resize/1920x960/media-data/infographics/picanto-Y21/inspiration.jpg
#
#
# =====================Отрывок документа №3=====================
#
# === score = 0.38586682081222534  Metadata документа ------------ {'Header 1': 'Kia Rio 2022 -  https://www.kia.ru/models/rio/desc/', 'Header 2': 'Продолжая многолетний успех в России'}
#
# Продолжая многолетний успех в России
# Kia Rio четвертого поколения создан дизайнерами и конструкторами Kia специально для России. Он готов к разнообразным и сложным условиям эксплуатации. Он надежен и удобен. И, конечно, достаточно элегантен, чтобы не затеряться на улицах города. Взгляните на него: он словно приглашает вас сесть за руль.
# Фото https://cdn.kia.ru/resize/1920x960/media-data/infographic/file/57df23c0-9f2a-41b5-924a-dc4d1c19fbd7.jpeg
#
#
# =====================Отрывок документа №4=====================
#
# === score = 0.3873103857040405  Metadata документа ------------ {'Header 1': 'Kia K9 2022 -  https://www.kia.ru/models/k9/desc/', 'Header 2': 'Ваш новый уровень'}
#
# Ваш новый уровень
# Вы не останавливаетесь на достигнутом успехе и постоянно стремитесь к большему — продолжаете развиваться, осваиваете новые сферы, приобщаетесь к новым ценностям. Новый дизайн и передовые технологии Kia K9 — к вашим услугам.
# Фото https://cdn.kia.ru/resize/1920x960/media-data/infographics/k9/pic1.jpg
#
#
# =====================Отрывок документа №5=====================
#
# === score = 0.3896498382091522  Metadata документа ------------ {'Header 1': 'Kia Cerato 2022 -  https://www.kia.ru/models/cerato/desc/', 'Header 2': 'Магия отличного настроения в каждой поездке'}
#
# Магия отличного настроения в каждой поездке
# Займите место за рулем Kia Cerato — и он вам подарит чувство бодрости и спокойной уверенности на целый день. Этот замечательный седан обладает впечатляющими характеристиками и оснащен новейшими технологиями, но самое главное — это стильный, удобный и практичный автомобиль. В такой компании жизнь обретает новые краски.
# Фото https://cdn.kia.ru/resize/1920x960/media-data/banners/models/cerato_new/desc/first.jpg
#
#
# Менеджер:   Добрый день! Рад приветствовать вас в компании KIA. Мы предлагаем широкий спектр услуг, включая продажу автомобилей, запасных частей, сервисное обслуживание и
#  специальные предложения. Основные конкурентные преимущества KIA включают: 1. Качество и надежность: Автомобили KIA известны своим высоким качеством и надежностью. Мы
#  стремимся предоставить клиентам продукцию, которая прослужит долгое время. 2. Инновационные технологии: Мы постоянно внедряем новые технологии в наши автомобили, чтобы
#  обеспечить комфорт, безопасность и удовольствие от вождения. 3. Привлекательный дизайн: Автомобили KIA отличаются современным и стильным дизайном, который привлекает
#  взгляды и подчеркивает индивидуальность владельца. 4. Экономичность: Мы предлагаем широкий выбор автомобилей с высокой топливной эффективностью, что помогает снизить
#  расходы на топливо. 5. Привлекательные цены: Мы стремимся предложить конкурентоспособные цены на наши автомобили и услуги. Если у вас есть какие-либо конкретные вопросы
#  о наших услугах или продуктах, я с удовольствием помогу вам.
#
#
#
# Клиент: Какие конкретно вы можете порекомендовать люксовые автомобили с высоким качеством и надежными эксплуатационными характеристиками
# САММАРИ
# === Вот краткий обзор предыдущего диалога: Консультант приветствует клиента и предлагает ознакомиться с услугами компании KIA. Он также подчеркивает конкурентные преимущества KIA по сравнению с основными конкурентами, такими как BMW или китайские производители. Основные преимущества KIA включают высокое качество и надежность, инновационные технологии, привлекательный дизайн, экономичность и привлекательные цены. Консультант также обещает помочь клиенту с любыми конкретными вопросами о продуктах и услугах компании.
#
#
# =====================Отрывок документа №1=====================
#
# === score = 0.3136215806007385  Metadata документа ------------ {'Header 1': 'Kia Picanto 2022 -  https://www.kia.ru/models/picanto/desc/', 'Header 2': 'Вдохновляйтесь. Заряжайтесь'}
#
# Вдохновляйтесь. Заряжайтесь
# Перед вами модный автомобиль, идеальный для городских улиц и скоростных магистралей. Дерзкий дизайн, продуманный интерьер и передовые технологии безопасности воплощают собой автомобиль, способный притягивать взгляды и восхищать, куда бы вы ни отправились.
# Фото https://cdn.kia.ru/resize/1920x960/media-data/infographics/picanto-Y21/inspiration.jpg
#
#
# =====================Отрывок документа №2=====================
#
# === score = 0.3262381851673126  Metadata документа ------------ {'Header 1': 'Kia Carnival 2022 -  https://www.kia.ru/models/carnival/desc/', 'Header 2': 'Территория стиля и комфорта'}
#
# Территория стиля и комфорта
# Что перед вами? Роскошный и брутальный кроссовер? Солидный и практичный семейный автомобиль? Высокотехнологичное средство передвижения или просторный и комфортный пати-вэн для большой компании? Kia Carnival совмещает все это и готов удивлять вас долгие годы.
# Фото https://cdn.kia.ru/resize/1920x960/media-data/infographic/file/b32628c8-1d7d-401c-a57a-1169c5700dcf.jpeg
#
#
# =====================Отрывок документа №3=====================
#
# === score = 0.3285008370876312  Metadata документа ------------ {'Header 1': 'Kia Cerato 2022 -  https://www.kia.ru/models/cerato/desc/', 'Header 2': 'Магия отличного настроения в каждой поездке'}
#
# Магия отличного настроения в каждой поездке
# Займите место за рулем Kia Cerato — и он вам подарит чувство бодрости и спокойной уверенности на целый день. Этот замечательный седан обладает впечатляющими характеристиками и оснащен новейшими технологиями, но самое главное — это стильный, удобный и практичный автомобиль. В такой компании жизнь обретает новые краски.
# Фото https://cdn.kia.ru/resize/1920x960/media-data/banners/models/cerato_new/desc/first.jpg
#
#
# =====================Отрывок документа №4=====================
#
# === score = 0.3291948437690735  Metadata документа ------------ {'Header 1': 'Kia Rio 2022 -  https://www.kia.ru/models/rio/desc/', 'Header 2': 'Продолжая многолетний успех в России'}
#
# Продолжая многолетний успех в России
# Kia Rio четвертого поколения создан дизайнерами и конструкторами Kia специально для России. Он готов к разнообразным и сложным условиям эксплуатации. Он надежен и удобен. И, конечно, достаточно элегантен, чтобы не затеряться на улицах города. Взгляните на него: он словно приглашает вас сесть за руль.
# Фото https://cdn.kia.ru/resize/1920x960/media-data/infographic/file/57df23c0-9f2a-41b5-924a-dc4d1c19fbd7.jpeg
#
#
# =====================Отрывок документа №5=====================
#
# === score = 0.3310650587081909  Metadata документа ------------ {'Header 1': 'Kia Picanto 2022 -  https://www.kia.ru/models/picanto/desc/', 'Header 2': 'Двигатель'}
#
# Двигатель
# Эффективные двигатели.. Вы можете выбрать один из двух надежных бензиновых двигателей, обладающихвысокой эффективностью и и низким расходом топлива. Каждый из них идеальноподходит для городского режима и способен превзойти ваши ожиданияна скоростной трассе.
# Модели двигателей: 1.0 MPI
#
#
# Менеджер:   Я могу порекомендовать вам несколько моделей автомобилей KIA, которые сочетают в себе высокое качество, надежность и роскошный дизайн. Вот некоторые из них: 1. KIA
#  Stinger: Этот спортивный седан предлагает элегантный дизайн, мощный двигатель и передовые технологии. Он оснащен высокопроизводительным двигателем и имеет превосходные
#  характеристики управляемости. 2. KIA K900: Это флагманская модель KIA, которая предлагает роскошный интерьер, передовые технологии и комфортное вождение. Он оснащен
#  мощным двигателем и предлагает широкий спектр функций и опций. 3. KIA Cadenza: Этот премиальный седан предлагает роскошный интерьер, современный дизайн и передовые
#  технологии. Он обладает превосходной комфортностью и высоким уровнем безопасности. 4. KIA Telluride: Это большой и роскошный внедорожник, который предлагает просторный
#  интерьер, высокую проходимость и передовые технологии. Он оснащен мощным двигателем и предлагает широкий спектр функций для комфортного путешествия. Каждая из этих
#  моделей предлагает высокое качество, надежность и роскошный опыт вождения. Выбор зависит от ваших предпочтений и потребностей. Если у вас есть конкретные требования или
#  предпочтения, я могу помочь вам выбрать наиболее подходящую модель.
#
#
#
# Клиент: Я хотел бы выбрать самый современный автомобиль с лучшим дизайном и новейшими технологиями, но в приемлимом ценовом диапазоне. Что вы можете порекомендовать?
# САММАРИ
# === Вот краткий обзор предыдущего диалога: Консультант приветствует клиента и предлагает ознакомиться с услугами компании KIA, а также описывает основные конкурентные преимущества KIA, включая качество и надежность, инновационные технологии, привлекательный дизайн, экономичность и привлекательные цены. Клиент интересуется рекомендациями по выбору люксовых автомобилей с высоким качеством и надежностью, на что консультант предлагает несколько моделей KIA, включая KIA Stinger, KIA K900, KIA Cadenza и KIA Telluride, описывая их основные характеристики и преимущества. Консультант также предлагает помощь в выборе наиболее подходящей модели в зависимости от предпочтений и потребностей клиента.
#
#
# =====================Отрывок документа №1=====================
#
# === score = 0.27346378564834595  Metadata документа ------------ {'Header 1': 'Kia Picanto 2022 -  https://www.kia.ru/models/picanto/desc/', 'Header 2': 'Вдохновляйтесь. Заряжайтесь'}
#
# Вдохновляйтесь. Заряжайтесь
# Перед вами модный автомобиль, идеальный для городских улиц и скоростных магистралей. Дерзкий дизайн, продуманный интерьер и передовые технологии безопасности воплощают собой автомобиль, способный притягивать взгляды и восхищать, куда бы вы ни отправились.
# Фото https://cdn.kia.ru/resize/1920x960/media-data/infographics/picanto-Y21/inspiration.jpg
#
#
# =====================Отрывок документа №2=====================
#
# === score = 0.31464317440986633  Metadata документа ------------ {'Header 1': 'Kia Cerato 2022 -  https://www.kia.ru/models/cerato/desc/', 'Header 2': 'Магия отличного настроения в каждой поездке'}
#
# Магия отличного настроения в каждой поездке
# Займите место за рулем Kia Cerato — и он вам подарит чувство бодрости и спокойной уверенности на целый день. Этот замечательный седан обладает впечатляющими характеристиками и оснащен новейшими технологиями, но самое главное — это стильный, удобный и практичный автомобиль. В такой компании жизнь обретает новые краски.
# Фото https://cdn.kia.ru/resize/1920x960/media-data/banners/models/cerato_new/desc/first.jpg
#
#
# =====================Отрывок документа №3=====================
#
# === score = 0.3164156675338745  Metadata документа ------------ {'Header 1': 'Kia Rio 2022 -  https://www.kia.ru/models/rio/desc/', 'Header 2': 'Открывая новые возможности'}
#
# Открывая новые возможности
# Сплав технологий и дизайна в едином ритме с городской жизнью — это Kia Rio четвертого поколения. Технологичность и функциональность, превосходящие ожидания от этого класса. Динамика, пробуждающая желание отправиться в путь и дающая уверенность на дороге.
# Фото https://cdn.kia.ru/resize/1920x960/media-data/infographic/file/27741853-9613-4d4f-be5a-660205e62322.jpeg
#
#
# =====================Отрывок документа №4=====================
#
# === score = 0.32121434807777405  Metadata документа ------------ {'Header 1': 'Kia Carnival 2022 -  https://www.kia.ru/models/carnival/desc/', 'Header 2': 'Территория стиля и комфорта'}
#
# Территория стиля и комфорта
# Что перед вами? Роскошный и брутальный кроссовер? Солидный и практичный семейный автомобиль? Высокотехнологичное средство передвижения или просторный и комфортный пати-вэн для большой компании? Kia Carnival совмещает все это и готов удивлять вас долгие годы.
# Фото https://cdn.kia.ru/resize/1920x960/media-data/infographic/file/b32628c8-1d7d-401c-a57a-1169c5700dcf.jpeg
#
#
# =====================Отрывок документа №5=====================
#
# === score = 0.3268318474292755  Metadata документа ------------ {'Header 1': 'Kia K9 2022 -  https://www.kia.ru/models/k9/desc/', 'Header 2': 'Пространство для вдохновения'}
#
# Пространство для вдохновения
# Салон Kia K9 поможет вам избавиться от вчерашней усталости и начать деньс новым вдохновением. Эргономичные удобные сиденья, роскошный интерьер,инновационный интерфейс с функцией распознавания рукописноговвода обеспечат исключительный опыт, который заинтригует и вдохновит вас.
# Фото https://cdn.kia.ru/resize/1920x960/media-data/infographics/k9/pic3.jpg
#
#
# Менеджер:   Я могу порекомендовать вам модель KIA Seltos. Этот автомобиль сочетает в себе современный дизайн и передовые технологии, при этом остается в приемлемом ценовом
#  диапазоне. KIA Seltos оснащен различными функциями, такими как система безопасности, мультимедийная система с поддержкой смартфонов, а также различные опции двигателя и
#  трансмиссии. Вы можете получить более подробную информацию о модели KIA Seltos, включая спецификации двигателя, экономичность топлива и доступные функции, если вы
#  предоставите мне конфигурацию и модель автомобиля, которые вас интересуют.
#
#
#
# Клиент: Дай мне подробную информацию по KIA Seltos с максимальным объемомо двигателя и самыми дорогими опциями
# САММАРИ
# === Вот краткий обзор предыдущего диалога: Клиент интересуется услугами и конкурентными преимуществами компании KIA. Консультант объясняет, что компания предлагает широкий спектр услуг, включая продажу автомобилей, запасных частей, сервисное обслуживание и специальные предложения. Он также перечисляет основные конкурентные преимущества KIA, такие как качество и надежность, инновационные технологии, привлекательный дизайн, экономичность и привлекательные цены. Клиент интересуется рекомендациями по выбору люксового автомобиля с высоким качеством и надежностью. Консультант рекомендует несколько моделей KIA, включая KIA Stinger, KIA K900, KIA Cadenza и KIA Telluride, и описывает их особенности. Клиент просит рекомендацию по самому современному автомобилю с лучшим дизайном и новейшими технологиями в приемлемом ценовом диапазоне. Консультант рекомендует модель KIA Seltos, объясняя, что она сочетает в себе современный дизайн и передовые технологии, при этом остается доступной по цене. Он предлагает предоставить более подробную информацию о модели KIA Seltos, если клиент предоставит конфигурацию и модель автомобиля, которые его интересуют.
#
#
# =====================Отрывок документа №1=====================
#
# === score = 0.283230185508728  Metadata документа ------------ {'Header 1': 'Kia Mohave 2022 -  https://www.kia.ru/models/mohave/desc/', 'Header 2': 'Комплектации', 'Header 3': 'Комплектация: Kia Mohave Luxe 3.0 V6 CRDi / 249 л.с. / Дизель / Автомат, 8AT / Полный прив
ятой двери, Люк с электроприводом, Сиденья с комбинированной отделкой премиальной кожей Nappa*, Вентиляция водительского сиденья, Вентиляция переднего пассажирского сиденья, 6 посадочных мест, 2 отдельных сиденья второго ряда , Вентиляция сидений второго ряда, Боковые подушки безопасности сидений второго ряда, Дистанционное складывание сидений второго ряда со стороны багажника, Навигационная система 12,3'' с поддержкой Apple Carplay и Android Auto, Цифровая приборная панель Supervision 12.3", Камера заднего вида, Телематические сервисы Kia Connect** , Система кругового обзора с 4 камерами (SVM), Беспроводная зарядка для мобильных устройств, Премиальная аудиосистема Lexicon с 13 динамиками, сабвуфером и внешним усилителем, Управление положением переднего пассажирского сиденья со второго ряда, Интеллектуальный круиз-контроль (SCC) c функцией Stop&Go, Система предотвращения фронтального столкновения (FCA), Система предотвращения столкновения со встречным автомобилем и при перестроении (FCA-LX), Система активной помощи при объезде препятствия (ESA), Система предотвращения выезда из полосы движения (LKA), Ассистент движения в полосе (LFA), Система предотвращения столкновения с автомобилем в слепой зоне (BCA), Система предотвращения бокового столкновения при выезде с парковки задним ходом (RCCA) , Система безопасного выхода из автомобиля с блокировкой задних дверей (SEA), Система контроля внимания водителя (DAW) , Предупреждение о начале движения впередиидущего автомобиля (LVDA), Ассистент управления дальним светом (HBA)
# Технические характеристики : Тип кузова: Внедорожник; Габариты (длина/ширина/высота), мм: 4930 / 1920 / 1790 (с рейлингами); Колесная база, мм: 2895; Дорожный просвет, мм: 217; Объём багажника (VDA), л: 350; Двигатель: D6EB-5, 3.0 V6 VGT CDRi; Мощность, л.с.: 249; Крутящий момент, Н·м: 549; Тип топлива: Дизель; Рабочий объем, л: 3.0; Экологический класс: Евро-5; Коробка передач: Автомат (8AT); Привод: Полный; Время разгона 0-100 км/ч, с: 8,7; Расход топлива комбинированный, л/100 км: 9,9
# Спецификация : Код модели: ENW69CC5K; OCN: GP24; Модельный год: 2022; Год производства: 2022
#
#
# =====================Отрывок документа №3=====================
#
# === score = 0.28697991371154785  Metadata документа ------------ {'Header 1': 'Kia Mohave 2022 -  https://www.kia.ru/models/mohave/desc/', 'Header 2': 'Комплектации', 'Header 3': 'Комплектация: Kia Mohave Premium 3.0 V6 CRDi / 249 л.с. / Дизель / Автомат, 8AT / Полный привод'}
#
# Комплектация: Kia Mohave Premium 3.0 V6 CRDi / 249 л.с. / Дизель / Автомат, 8AT / Полный привод
# Цена: 6 234 900 ₽
# Стандартное оборудование : Дополнительный электрический отопитель салона, Полностью светодиодные фары , Светодиодные противотуманные фары , Светодиодные задние габаритные огни и стоп-сигналы, Полноразмерное запасное колесо, Боковые ступеньки, Рейлинги на крыше, Задний спойлер, Передние и задние брызговики, 3 ряда сидений, Передняя панель и подлокотник с отделкой искусственной кожей, Передняя панель и двери с отделкой вставками под текстуру дерева, Крепления для детского кресла ISOFIX на втором ряду сидений, Выдвижная шторка в багажнике, Дверные панели с отделкой искусственной кожей, Фронтальные подушки безопасности, Коленная подушка безопасности водителя, Передние боковые подушки безопасности, Шторки безопасности, Иммобилайзер и сигнализация, Система помощи при старте на подъёме (HAC), Система помощи при спуске с горы (DBC), Система активного управления стабилизацией (VSM), Система контроля давления в шинах (TPMS), Система экстренной связи ЭРА-ГЛОНАСС, Напоминание о пассажирах на заднем ряду (ROA), Интеллектуальная система открывания багажника c электроприводом , Электрорегулировка передних сидений , Память настроек водительского сиденья, боковых зеркал заднего вида и рулевой колонки , Рулевая колонка с электроприводом регулировки по высоте и по вылету, Электропривод складывания боковых зеркал заднего вида, Электрорегулировка поясничного подпора сиденья водителя, Электрический стояночный тормоз (EPB) с функцией автоматического удержания (Auto Hold) , Система бесключевого доступа Smart Key и запуск двигателя кнопкой , Передние и задние датчики парковки, Двойные ламинированные стёкла передних дверей, Датчики света и дождя, Двухзонный климат-контроль , Кондиционер для второго и третьего рядов сидений, Мультифункциональное рулевое колесо с отделкой кожей*, Дополнительная розетка 12V в багажном отделении, Разъёмы USB для зарядки мобильных устройств для пассажиров трех рядов сидений
# Опции комплектации : Подогрев лобового стекла в зоне стоянки стеклоочистителей, Боковые зеркала заднего вида с электрорегулировкой и подогревом, Подогрев передних сидений , Подогрев задних сидений, Подогрев рулевого колеса, Автоматически подключаемый полный привод (TOD), раздаточная коробка (2 ступени), Система адаптации к дорожным условиям (Terrain Mode Select), Самоблокирующийся дифференциал повышенного трения задней оси (LSD), Легкосплавные диски 20" с шинами 265/50 R20, Тонировка стекол задних дверей и стекла пятой двери, Люк с электроприводом , 7 посадочных мест, цельный диван второго ряда , Сиденья с комбинированной отделкой премиальной кожей Nappa*, Вентиляция водительского сиденья , Вентиляция переднего пассажирского сиденья, Навигационная система 12,3'' с поддержкой Apple Carplay и Android Auto, Цифровая приборная панель Supervision 12.3", Телематические сервисы Kia Connect** , Камера заднего вида, Система кругового обзора с 4 камерами (SVM) , Беспроводная зарядка для мобильных устройств , Премиальная аудиосистема Lexicon с 13 динамиками, сабвуфером и внешним усилителем, Управление положением переднего пассажирского сиденья со второго ряда, Интеллектуальный круиз-контроль (SCC) c функцией Stop&Go , Система предотвращения фронтального столкновения (FCA) , Система предотвращения столкновения со встречным автомобилем и при перестроении (FCA-LX), Система активной помощи при объезде препятствия (ESA), Система предотвращения выезда из полосы движения (LKA), Ассистент движения в полосе (LFA), Система предотвращения столкновения с автомобилем в слепой зоне (BCA) , Система предотвращения бокового столкновения при выезде с парковки задним ходом (RCCA), Система безопасного выхода из автомобиля с блокировкой задних дверей (SEA), Система контроля внимания водителя (DAW) , Предупреждение о начале движения впередиидущего автомобиля (LVDA), Ассистент управления дальним светом (HBA)
# Технические характеристики : Тип кузова: Внедорожник; Габариты (длина/ширина/высота), мм: 4930 / 1920 / 1790 (с рейлингами); Колесная база, мм: 2895; Дорожный просвет, мм: 217; Объём багажника (VDA), л: 350; Двигатель: D6EB-5, 3.0 V6 VGT CDRi; Мощность, л.с.: 249; Крутящий момент, Н·м: 549; Тип топлива: Дизель; Рабочий объем, л: 3.0; Экологический класс: Евро-5; Коробка передач: Автомат (8AT); Привод: Полный; Время разгона 0-100 км/ч, с: 8,7; Расход топлива комбинированный, л/100 км: 9,9
# Спецификация : Код модели: ENW79CC5K ; OCN: GP24; Модельный год: 2022; Год производства: 2022
#
#
# =====================Отрывок документа №4=====================
#
# === score = 0.2880482077598572  Metadata документа ------------ {'Header 1': 'Kia Mohave 2022 -  https://www.kia.ru/models/mohave/desc/', 'Header 2': 'Комплектации', 'Header 3': 'Комплектация: Kia Mohave Prestige 3.0 V6 CRDi / 249 л.с. / Дизель / Автомат, 8AT / Полный прив
предотвращения фронтального столкновения (FCA) , Система предотвращения выезда из полосы движения (LKA), Ассистент движения в полосе (LFA), Система предотвращения столкновения с автомобилем в слепой зоне (BCA) , Система предотвращения бокового столкновения при выезде с парковки задним ходом (RCCA), Система безопасного выхода из автомобиля с блокировкой задних дверей (SEA), Система контроля внимания водителя (DAW) , Предупреждение о начале движения впередиидущего автомобиля (LVDA), Ассистент управления дальним светом (HBA)
# Технические характеристики : Тип кузова: Внедорожник; Габариты (длина/ширина/высота), мм: 4930 / 1920 / 1790 (с рейлингами); Колесная база, мм: 2895; Дорожный просвет, мм: 217; Объём багажника (VDA), л: 350; Двигатель: D6EB-5, 3.0 V6 VGT CDRi; Мощность, л.с.: 249; Крутящий момент, Н·м: 549; Тип топлива: Дизель; Рабочий объем, л: 3.0; Экологический класс: Евро-5; Коробка передач: Автомат (8AT); Привод: Полный; Время разгона 0-100 км/ч, с: 8,7; Расход топлива комбинированный, л/100 км: 9,9
# Спецификация : Код модели: ENW79CC5K ; OCN: GP22; Модельный год: 2022; Год производства: 2022
#
#
# =====================Отрывок документа №5=====================
#
# === score = 0.28862231969833374  Metadata документа ------------ {'Header 1': 'Kia K5 2022 -  https://www.kia.ru/models/k5/desc/', 'Header 2': 'Комплектации', 'Header 3': 'Комплектация: Kia K5 Style 2.5 GDI / 194 л.с. / Бензин / Автомат, 8AT / Передний привод'}
#
# Комплектация: Kia K5 Style 2.5 GDI / 194 л.с. / Бензин / Автомат, 8AT / Передний привод
# Цена: 3 324 900 ₽
# Стандартное оборудование : Светодиодные фары , Светодиодные дневные ходовые огни , Спортивный задний бампер с диффузором , Задние сиденья со спинками, складывающимися в соотношении 60:40, Рулевое колесо и ручка селектора трансмиссии с отделкой кожей* , Фронтальные подушки безопасности, Передние боковые подушки и шторки безопасности , Система курсовой устойчивости (ESC), Система активного управления стабилизацией (VSM) , Система помощи при старте на подъёме (HAC), Система предупреждения об экстренном торможении (ESS), Система экстренной связи ЭРА-ГЛОНАСС, Система контроля давления в шинах (TPMS), Крепления для детского кресла ISOFIX, Полноразмерное легкосплавное запасное колесо , Мультифункциональное рулевое колесо , Bluetooth для подключения мобильных устройств , Система выбора режима движения (Drive Mode Select) , Круиз-контроль, Передние и задние стеклоподъёмники с электроприводом , Стеклоподъемник водителя с функцией Auto, Датчик света, Ключ с дистанционным управлением центральным замком , Аудиосистема с радио, USB разъемом (6 динамиков), Двухзонный климат-контроль, Камера заднего вида
# Опции комплектации : Легкосплавные диски 18" с шинами 235/45 R18 , Решётка радиатора спортивного дизайна , Спортивный передний бампер , Подогрев форсунок омывателя лобового стекла, Электрообогрев лобового стекла, Боковые зеркала заднего вида с электрорегулировкой и подогревом , Подогрев передних сидений, Подогрев задних сидений, Подогрев рулевого колеса, Внешние дверные ручки с отделкой хромом, Проекционные светодиодные фары , Светодиодные противотуманные фары, Светодиодные задние фонари , Сиденья с комбинированной кожаной отделкой* , Элементы интерьера с отделкой матовым хромом и чёрным глянцем , Передняя панель и двери с отделкой вставками под текстуру дерева, Дверные панели с отделкой искусственной кожей, Датчик дождя, Дефлекторы обдува для пассажиров второго ряда, Электрорегулировка сиденья водителя с функцией регулировки поясничного подпора, Передние стеклоподъёмники с функцией Auto, Передние и задние датчики парковки , Телематические сервисы Kia Connect**, Система бесключевого доступа Smart Key и запуск двигателя кнопкой, Интеллектуальная система открывания багажника, Дистанционный запуск двигателя с ключа , Салонное зеркало заднего вида с автоматическим затемнением, Электропривод складывания боковых зеркал заднего вида , Электрический стояночный тормоз (EPB) с функцией автоматического удержания (Auto Hold) , Приборная панель Supervision c цветным дисплеем 4.2'' , Навигационная система 10,25'' с поддержкой Apple Carplay и Android Auto , Премиальная аудиосистема Bose с 11 динамиками, сабвуфером и внешним усилителем , 2 разъёма USB второго ряда сидений для зарядки мобильных устройств , Беспроводная зарядка для мобильных устройств
# Технические характеристики : Город, г/км: 230; Трасса, г/км: 124; В комбинированном цикле, г/км: 163; Двигатель: 2.5 GDI; Мощность, л.с.: 194; Крутящий момент, Н·м: 246; Тип топлива: Бензин, АИ 95; Рабочий объем, л: 2.5; Рабочий объем, см3: 2497; Экологический класс: Евро-5; Коробка передач: Автомат (8AT); Привод: Передний; Время разгона 0-100 км/ч, с: 8.6; Расход топлива комбинированный, л/100 км: 7.1; Тип кузова: Седан; Габариты (длина/ширина/высота), мм: 4905 / 1860 / 1465; Колесная база, мм: 2850; Дорожный просвет, мм: 155; Объём багажника (VDA), л: 510
# Спецификация : Код модели: EXS4L9A1J; OCN: G733; Модельный год: 2022; Год производства: 2022
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-14-93f2e4e1ba43> in <cell line: 5>()
#       3 #HISTORY = [] # Убери решетку если нужно обновлять историю диалогов после запуска, если не нужно обновлять то оставь так
#       4
# ----> 5 run_dialog(prompt, knowledge_base)
#
# <ipython-input-12-e835fc593bf7> in run_dialog(system_doc_url, knowledge_base_url)
#       5         if ((user_question.lower() == 'stop') or (user_question.lower() == 'стоп')):
#       6             break
# ----> 7         answer = answer_index(user_question)
#       8         print('\nМенеджер: ', answer+'\n\n')
#       9
#
# <ipython-input-11-9f9ab8111862> in answer_index(topic, temp, top_similar_documents)
#      46         ]
#      47
# ---> 48         completion = openai.ChatCompletion.create(
#      49             model=SELECT_MODEL_GPT[0],
#      50             messages=messages,
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# --> 153         response, _, api_key = requestor.request(
#     154             "post",
#     155             url,
#
# /usr/local/lib/python3.10/dist-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     296             request_timeout=request_timeout,
#     297         )
# --> 298         resp, got_stream = self._interpret_response(result, stream)
#     299         return resp, got_stream, self.api_key
#     300
#
# /usr/local/lib/python3.10/dist-packages/openai/api_requestor.py in _interpret_response(self, result, stream)
#     698         else:
#     699             return (
# --> 700                 self._interpret_response_line(
#     701                     result.content.decode("utf-8"),
#     702                     result.status_code,
#
# /usr/local/lib/python3.10/dist-packages/openai/api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     761         stream_error = stream and "error" in resp.data
#     762         if stream_error or not 200 <= rcode < 300:
# --> 763             raise self.handle_error_response(
#     764                 rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     765             )
#
# InvalidRequestError: This model's maximum context length is 4097 tokens. However, your messages resulted in 11361 tokens. Please reduce the length of the messages.
