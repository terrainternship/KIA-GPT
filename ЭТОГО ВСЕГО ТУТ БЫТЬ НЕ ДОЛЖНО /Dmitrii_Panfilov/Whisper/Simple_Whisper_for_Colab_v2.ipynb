# %% [markdown]
# ## **🔰 Упрощенный код для Whisper [ver.2 Google Colab] 08-09-2023**

# %% [markdown]
# Полезные ссылки:
#
# - **[Запуск whisper на Windows](https://www.itworks.hu/accelerating-speech-recognition-with-whisper-and-gpus-on-windows-11/)**
#
# - **[Быстрые курсы по регулярным выражениям](https://regexlearn.com/ru/learn)**

# %%
# !ls -ahl
# Out:
# total 16K
# drwxr-xr-x 1 root root 4.0K Sep  6 13:23 .
# drwxr-xr-x 1 root root 4.0K Sep  8 15:07 ..
# drwxr-xr-x 4 root root 4.0K Sep  6 13:22 .config
# drwxr-xr-x 1 root root 4.0K Sep  6 13:23 sample_data

# %%
#@markdown Проврека выделенной видео-карты (нужна T4 или выше)
# !nvidia-smi
# !nvidia-smi --query-gpu=name --format=csv,noheader,nounits
# Out:
# Fri Sep  8 15:10:52 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Tesla T4

# %%
# Установка yt-dlp
# !pip install -q yt-dlp
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 17.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 23.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 31.9 MB/s eta 0:00:00

# %%
# Список ссылок для загрузки

urls_list = [
    "https://youtu.be/ih_B0-Y9gNE",
    "https://youtu.be/6DG5gzCXoRg?list=TLGGjOElj14_uCEyNTA4MjAyMw",
    "https://youtu.be/V1rcD1gDu9k",
    "https://www.youtube.com/embed/ih_B0-Y9gNE?iv_load_policy=3&autoplay=1&rel=0&version=3&loop=1&playlist=ih_B0-Y9gNE"
]

# %%
# Функция очистки ссылок
import re

def clean_youtube_url(url: str) -> str:
    """
    Преобразует любую ссылку на видео YouTube в формат короткой ссылки (https://youtu.be/ID_ВИДЕО).

    Параметры:
        url (str): Исходная ссылка на видео на YouTube.

    Возвращает:
        str: Короткая ссылка на видео или None, если исходная ссылка не соответствует формату YouTube.

    Пример:
        >>> clean_youtube_url("https://www.youtube.com/watch?v=dQw4w9WgXcQ")
        "https://youtu.be/dQw4w9WgXcQ"
    """

    # Регулярное выражение для поиска идентификаторов видео YouTube:
    # 1. (?:https?:\/\/)? - необязательный протокол (http или https).
    # 2. (?:www\.)? - необязательный префикс "www".
    # 3. (?:youtube\.com\/(?:watch\?v=|embed\/)|youtu\.be\/) - паттерн для длинных (стандартных и embed) и коротких ссылок YouTube.
    # 4. ([a-zA-Z0-9_-]{11}) - идентификатор видео, состоящий из 11 символов.
    pattern = r"(?:https?:\/\/)?(?:www\.)?(?:youtube\.com\/(?:watch\?v=|embed\/)|youtu\.be\/)([a-zA-Z0-9_-]{11})"

    # Поиск совпадения с помощью регулярного выражения
    match = re.search(pattern, url)
    if match:
        # Если найдено совпадение, извлекаем идентификатор видео
        video_id = match.group(1)
        return f"https://youtu.be/{video_id}"
    else:
        return None

# %%
# Создаем список "очищенных" коротких ссылок на видео YouTube.
# Все недопустимые или неподходящие ссылки будут проигнорированы.
cleaned_urls = set(filter(None, map(clean_youtube_url, urls_list)))

# Выводим результат
print(cleaned_urls)
# Out:
# {'https://youtu.be/ih_B0-Y9gNE', 'https://youtu.be/6DG5gzCXoRg', 'https://youtu.be/V1rcD1gDu9k'}

# %%
# Функция загрузки видео в формате m4a (аудиофайл) с YouTube в директоррию /content/videos/
import subprocess

def download_video(url: str) -> None:
    """
    Загружает видео с YouTube в формате m4a (аудиофайл) и сохраняет в директории /content/audios/.

    Параметры:
        url (str): Ссылка на видео на YouTube.

    Пример:
        >>> download_video("https://www.youtube.com/watch?v=dQw4w9WgXcQ")
        ...
    """

    # Команда для yt-dlp, которая:
    # 1. Использует опцию "-x" для извлечения аудио.
    # 2. Устанавливает формат аудио в "m4a".
    # 3. Определяет путь для сохранения файла.
    cmd = [
        "yt-dlp",
        "-x",
        "--audio-format", "m4a",
        "-o", "/content/audios/%(title)s.%(ext)s",
        url
    ]

    try:
        # Инициализация подпроцесса с заданной командой.
        # stdout=subprocess.PIPE позволяет читать вывод в реальном времени.
        process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)

        # Чтение вывода команды в реальном времени и его вывод на экран.
        for line in process.stdout:
            print(line.strip())

        # Ожидание завершения подпроцесса и получение кода завершения.
        return_code = process.wait()

        # Если процесс завершился с ошибкой (не нулевой код завершения), генерируем исключение.
        if return_code != 0:
            raise subprocess.CalledProcessError(return_code, cmd)

    # Обработка исключений при выполнении команды.
    except subprocess.CalledProcessError as e:
        print(f"Ошибка при обработке ссылки {url}:")
        print(str(e))

# %%
# Перебор каждой очищенной ссылки из списка cleaned_urls.
# Для каждой ссылки будет вызвана функция download_video,
# которая загрузит видео в формате m4a и сохранит его в директории /content/audios/.
for url in cleaned_urls:
    download_video(url)
# Out:
# [youtube] Extracting URL: https://youtu.be/ih_B0-Y9gNE
# [youtube] ih_B0-Y9gNE: Downloading webpage
# [youtube] ih_B0-Y9gNE: Downloading ios player API JSON
# [youtube] ih_B0-Y9gNE: Downloading android player API JSON
# [youtube] ih_B0-Y9gNE: Downloading player 7ee36b0e
# [youtube] ih_B0-Y9gNE: Downloading m3u8 information
# [info] ih_B0-Y9gNE: Downloading 1 format(s): 251
# [download] Destination: /content/audios/Новая Kia Cerato： стало круто？ ⧸ Киа Церато 2021 тест и обзор.webm
#
# [download]   0.0% of   12.02MiB at  600.22KiB/s ETA 00:20
# [download]   0.0% of   12.02MiB at    1.33MiB/s ETA 00:09
# [download]   0.1% of   12.02MiB at    2.48MiB/s ETA 00:04
# [download]   0.1% of   12.02MiB at    4.42MiB/s ETA 00:02
# [download]   0.3% of   12.02MiB at    3.10MiB/s ETA 00:03
# [download]   0.5% of   12.02MiB at    3.99MiB/s ETA 00:02
# [download]   1.0% of   12.02MiB at    5.07MiB/s ETA 00:02
# [download]   2.1% of   12.02MiB at    7.11MiB/s ETA 00:01
# [download]   4.2% of   12.02MiB at   11.07MiB/s ETA 00:01
# [download]   8.3% of   12.02MiB at   15.52MiB/s ETA 00:00
# [download]  16.6% of   12.02MiB at   15.12MiB/s ETA 00:00
# [download]  33.3% of   12.02MiB at   15.75MiB/s ETA 00:00
# [download]  66.5% of   12.02MiB at   15.66MiB/s ETA 00:00
# [download]  82.2% of   12.02MiB at   15.36MiB/s ETA 00:00
# [download]  82.3% of   12.02MiB at  732.89KiB/s ETA 00:03
# [download]  82.3% of   12.02MiB at    1.61MiB/s ETA 00:01
# [download]  82.3% of   12.02MiB at    2.89MiB/s ETA 00:00
# [download]  82.4% of   12.02MiB at    4.83MiB/s ETA 00:00
# [download]  82.5% of   12.02MiB at    3.07MiB/s ETA 00:00
# [download]  82.8% of   12.02MiB at    3.96MiB/s ETA 00:00
# [download]  83.3% of   12.02MiB at    4.82MiB/s ETA 00:00
# [download]  84.3% of   12.02MiB at    6.93MiB/s ETA 00:00
# [download]  86.4% of   12.02MiB at    9.02MiB/s ETA 00:00
# [download]  90.6% of   12.02MiB at   17.26MiB/s ETA 00:00
# [download]  98.9% of   12.02MiB at   28.14MiB/s ETA 00:00
# [download] 100.0% of   12.02MiB at   25.45MiB/s ETA 00:00
# [download] 100% of   12.02MiB in 00:00:00 at 14.05MiB/s
# [ExtractAudio] Destination: /content/audios/Новая Kia Cerato： стало круто？ ⧸ Киа Церато 2021 тест и обзор.m4a
# Deleting original file /content/audios/Новая Kia Cerato： стало круто？ ⧸ Киа Церато 2021 тест и обзор.webm (pass -k to keep)
# [youtube] Extracting URL: https://youtu.be/6DG5gzCXoRg
# [youtube] 6DG5gzCXoRg: Downloading webpage
# [youtube] 6DG5gzCXoRg: Downloading ios player API JSON
# [youtube] 6DG5gzCXoRg: Downloading android player API JSON
# [youtube] 6DG5gzCXoRg: Downloading m3u8 information
# [info] 6DG5gzCXoRg: Downloading 1 format(s): 251
# [download] Destination: /content/audios/Kia. Двигайся. Вдохновляйся.webm
#
# [download]   0.1% of    1.49MiB at  627.33KiB/s ETA 00:02
# [download]   0.2% of    1.49MiB at    1.33MiB/s ETA 00:01
# [download]   0.5% of    1.49MiB at    2.01MiB/s ETA 00:00
# [download]   1.0% of    1.49MiB at    3.73MiB/s ETA 00:00
# [download]   2.0% of    1.49MiB at    2.40MiB/s ETA 00:00
# [download]   4.1% of    1.49MiB at    3.90MiB/s ETA 00:00
# [download]   8.3% of    1.49MiB at    4.73MiB/s ETA 00:00
# [download]  16.7% of    1.49MiB at    6.76MiB/s ETA 00:00
# [download]  33.5% of    1.49MiB at   10.53MiB/s ETA 00:00
# [download]  67.1% of    1.49MiB at   17.06MiB/s ETA 00:00
# [download] 100.0% of    1.49MiB at   22.91MiB/s ETA 00:00
# [download] 100% of    1.49MiB in 00:00:00 at 11.12MiB/s
# [ExtractAudio] Destination: /content/audios/Kia. Двигайся. Вдохновляйся.m4a
# Deleting original file /content/audios/Kia. Двигайся. Вдохновляйся.webm (pass -k to keep)
# [youtube] Extracting URL: https://youtu.be/V1rcD1gDu9k
# [youtube] V1rcD1gDu9k: Downloading webpage
# [youtube] V1rcD1gDu9k: Downloading ios player API JSON
# [youtube] V1rcD1gDu9k: Downloading android player API JSON
# [youtube] V1rcD1gDu9k: Downloading m3u8 information
# [info] V1rcD1gDu9k: Downloading 1 format(s): 251
# [download] Destination: /content/audios/Новый KIA Ceed ⧸ SW 2022： БЕЗ ПАЛКИ С БАЛКОЙ. Тест-Драйв.webm
#
# [download]   0.0% of   18.49MiB at  366.99KiB/s ETA 00:51
# [download]   0.0% of   18.49MiB at  935.12KiB/s ETA 00:20
# [download]   0.0% of   18.49MiB at    1.82MiB/s ETA 00:10
# [download]   0.1% of   18.49MiB at    3.44MiB/s ETA 00:05
# [download]   0.2% of   18.49MiB at    2.55MiB/s ETA 00:07
# [download]   0.3% of   18.49MiB at    3.02MiB/s ETA 00:06
# [download]   0.7% of   18.49MiB at    4.03MiB/s ETA 00:04
# [download]   1.3% of   18.49MiB at    6.03MiB/s ETA 00:03
# [download]   2.7% of   18.49MiB at    9.59MiB/s ETA 00:01
# [download]   5.4% of   18.49MiB at   15.53MiB/s ETA 00:01
# [download]  10.8% of   18.49MiB at   15.00MiB/s ETA 00:01
# [download]  21.6% of   18.49MiB at   16.36MiB/s ETA 00:00
# [download]  43.3% of   18.49MiB at   17.02MiB/s ETA 00:00
# [download]  53.3% of   18.49MiB at   16.34MiB/s ETA 00:00
# [download]  53.3% of   18.49MiB at  397.00KiB/s ETA 00:22
# [download]  53.3% of   18.49MiB at  830.12KiB/s ETA 00:10
# [download]  53.3% of   18.49MiB at    1.52MiB/s ETA 00:05
# [download]  53.4% of   18.49MiB at    2.74MiB/s ETA 00:03
# [download]  53.5% of   18.49MiB at    2.55MiB/s ETA 00:03
# [download]  53.6% of   18.49MiB at    3.03MiB/s ETA 00:02
# [download]  54.0% of   18.49MiB at    4.01MiB/s ETA 00:02
# [download]  54.6% of   18.49MiB at    5.81MiB/s ETA 00:01
# [download]  56.0% of   18.49MiB at    9.48MiB/s ETA 00:00
# [download]  58.7% of   18.49MiB at   15.62MiB/s ETA 00:00
# [download]  64.1% of   18.49MiB at   26.90MiB/s ETA 00:00
# [download]  74.9% of   18.49MiB at   13.98MiB/s ETA 00:00
# [download]  96.6% of   18.49MiB at   14.88MiB/s ETA 00:00
# [download] 100.0% of   18.49MiB at   15.88MiB/s ETA 00:00
# [download] 100% of   18.49MiB in 00:00:01 at 14.49MiB/s
# [ExtractAudio] Destination: /content/audios/Новый KIA Ceed ⧸ SW 2022： БЕЗ ПАЛКИ С БАЛКОЙ. Тест-Драйв.m4a
# Deleting original file /content/audios/Новый KIA Ceed ⧸ SW 2022： БЕЗ ПАЛКИ С БАЛКОЙ. Тест-Драйв.webm (pass -k to keep)

# %%
# Установка whisper
# !pip install -q git+https://github.com/openai/whisper.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 20.4 MB/s eta 0:00:00
#   Building wheel for openai-whisper (pyproject.toml) ... done

# %%
import os
from typing import List

def _construct_whisper_command(input_path: str, output_dir: str) -> List[str]:
    """
    Формирование команды для программы whisper.

    Args:
    - input_path (str): Путь к исходному аудиофайлу.
    - output_dir (str): Путь к директории, где сохранить результаты транскрибации.

    Returns:
    - List[str]: Список аргументов для команды whisper.

    Команда whisper используется для автоматической транскрибации аудиозаписей.
    В данной функции мы формируем список аргументов для этой команды:
    1. `--model large-v2`: использование улучшенной большой модели (версии 2) для транскрибации.
    2. `--language ru`: указание языка речи на русском.
    3. `--device cuda`: использование графического процессора (GPU) для ускорения транскрибации.
    4. `--output_format txt`: формат вывода результатов транскрибации в текстовом файле.
    """
    return [
        'whisper',
        input_path,
        '--model', "large-v2",
        '--language', 'ru',
        '--device', 'cuda',
        '--output_format', 'all',
        '--output_dir', output_dir
    ]


def transcribe_audio_files(input_directory: str, output_directory: str) -> None:
    """
    Транскрибирование всех аудиофайлов из указанной директории с помощью whisper.

    Args:
    - input_directory (str): Директория с исходными аудиофайлами.
    - output_directory (str): Директория для сохранения результатов транскрибации.

    Для каждого файла из `input_directory` запускается процесс транскрибации.
    Результаты сохраняются в поддиректории `output_directory`, где каждая поддиректория соответствует одному аудиофайлу.
    """

    # Проверка наличия выходной директории и её создание при отсутствии
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # Формирование списка аудиофайлов с расширением .m4a
    files = [f for f in os.listdir(input_directory) if os.path.isfile(os.path.join(input_directory, f)) and f.endswith('.m4a')]

    # Для каждого аудиофайла:
    for file in files:
        input_path = os.path.join(input_directory, file)

        # Имя поддиректории формируется на основе имени файла без расширения
        subdir_name = os.path.splitext(file)[0]
        subdir_path = os.path.join(output_directory, subdir_name)

        # Информирование пользователя о текущем файле
        print(f"Транскрибирование файла: {file}...")

        # Формирование команды для whisper
        cmd = _construct_whisper_command(input_path, subdir_path)

        # Запуск процесса транскрибации и вывод результатов в реальном времени
        with subprocess.Popen(cmd, stdout=subprocess.PIPE, text=True) as process:
            for line in iter(process.stdout.readline, ''):
                print(line, end='')  # Вывод строки в реальном времени
            print(f"\nТранскрибирование файла {file} завершено.")

# %%
transcribe_audio_files('/content/audios', '/content/out')
# Out:
# Транскрибирование файла: Новый KIA Ceed ⧸ SW 2022： БЕЗ ПАЛКИ С БАЛКОЙ. Тест-Драйв.m4a...
# [00:00.000 --> 00:04.000]  Привет, друзья! У KIA Ceed обновился логотип.
# [00:04.000 --> 00:08.000]  По этому поводу мы собрали чемоданы и приехали в Ростов-на-Дону
# [00:08.000 --> 00:12.000]  для того, чтобы снять эту машину с новыми буквами.
# [00:12.000 --> 00:16.000]  Нет, под такой повод, ребята, нас сорвать с места довольно трудно.
# [00:16.000 --> 00:23.000]  А вот то, что здесь под капотом новый турбомотор 1.5 мощностью 150 лошадиных сил,
# [00:23.000 --> 00:26.000]  то, что внутри комплекс телематических систем,
# [00:26.000 --> 00:31.000]  как у BMW и Volvo, и даже покруче в некоторых местах,
# [00:31.000 --> 00:36.000]  то, что здесь фонари, от которых сносят крышу, светодиодные фары,
# [00:36.000 --> 00:40.000]  я вам сейчас все расскажу, и бамперы тоже другие.
# [00:40.000 --> 00:42.000]  Вот это все в комплексе.
# [00:42.000 --> 00:46.000]  Мы готовы, да, поснимать для вас в Ростове-на-Дону.
# [00:46.000 --> 00:49.000]  И не смотрите, что я без шапки, здесь на самом деле холодно.
# [00:49.000 --> 01:00.000]  Обновились ценники, и теперь Kia Ceed стоит от 1 миллион 565 тысяч рублей
# [01:00.000 --> 01:04.000]  и нету механической трансмиссии в принципе.
# [01:04.000 --> 01:08.000]  То есть вот это глобальное обновление Kia решила,
# [01:08.000 --> 01:13.000]  что механика для автомобилей этого сегмента уже вчерашний день.
# [01:13.000 --> 01:17.000]  То есть у вас минимальная возможность купить этот автомобиль
# [01:17.000 --> 01:24.000]  это 6-диапазонный автомат плюс мотор 1.6 гамма мощностью 128 лошадиных сил
# [01:24.000 --> 01:26.000]  и, в общем-то, неплохая комплектация.
# [01:26.000 --> 01:30.000]  Получаются усиды на минималках, потому что там есть и кондиционер,
# [01:30.000 --> 01:36.000]  и камера заднего вида, и мультимедийка 8 дюймов с Apple CarPlay,
# [01:36.000 --> 01:41.000]  и Google Android Auto, и все это еще и по воздуху беспроводным способом.
# [01:42.000 --> 01:49.000]  Но в нашем случае мы имеем самую топовую топ-версию GT Line,
# [01:49.000 --> 01:55.000]  которая стоит сейчас на минуточку 2 миллиона 110 тысяч.
# [02:02.000 --> 02:08.000]  Ребят, давайте на берегу договоримся, что мы не будем сегодня обсуждать проблему
# [02:08.000 --> 02:16.000]  обнаглевших дилеров, наценок, допов, золотых решеток, защиты радиатора и так далее.
# [02:16.000 --> 02:19.000]  Потому что смысла в этом никакого нет.
# [02:21.000 --> 02:25.000]  Машины, которые получают дилеры, это их уже собственность,
# [02:25.000 --> 02:27.000]  представительство на них повлиять никак не может.
# [02:27.000 --> 02:31.000]  Законодательство защищает бизнесменов,
# [02:31.000 --> 02:36.000]  и они могут продавать автомобили по той цене, по которой им вздумается.
# [02:36.000 --> 02:38.000]  Это их право.
# [02:38.000 --> 02:42.000]  Хотели капитализм? Вот он так выглядит.
# [02:42.000 --> 02:46.000]  Если хотите плановую экономику, она выглядит еще хуже.
# [02:46.000 --> 02:49.000]  Поэтому спрос рождает предложение.
# [02:49.000 --> 02:53.000]  Не создавайте такой спрос, чтобы возникало такое предложение.
# [02:53.000 --> 02:55.000]  Вот он единственный универсальный рецепт.
# [02:56.000 --> 02:59.000]  Список обновлений СИДа довольно большой,
# [02:59.000 --> 03:02.000]  но вот если так разбираться детально,
# [03:02.000 --> 03:07.000]  оказывается, что касается 90% этого списка топовой комплектации.
# [03:07.000 --> 03:10.000]  То есть вот того автомобиля, на котором еду я,
# [03:10.000 --> 03:16.000]  и на котором будет ездить очень маленькое количество покупателей Киа СИД.
# [03:16.000 --> 03:18.000]  Потребители Киа СИД и СИД СВ,
# [03:18.000 --> 03:21.000]  то есть того автомобиля, на котором я еду,
# [03:21.000 --> 03:23.000]  которые получили новый мотор.
# [03:23.000 --> 03:25.000]  Новый силовой агрегат 1.5 Турбо,
# [03:25.000 --> 03:30.000]  который на 10 лошадиных сил мощнее турбового мотора 1.4,
# [03:30.000 --> 03:33.000]  который стоял на топовых комплектациях раньше.
# [03:33.000 --> 03:39.000]  Вот они вкусят весь спектр обновлений,
# [03:39.000 --> 03:45.000]  потому что только топовых комплектаций касается расширения,
# [03:45.000 --> 03:50.000]  то есть там будет полный комплект всяких разных фишек, плюшек.
# [03:50.000 --> 03:54.000]  Плюс комплекс телематики Киа Коннект,
# [03:54.000 --> 03:57.000]  опять же, касается только топовых версий.
# [03:57.000 --> 04:01.000]  Полный функционал урезанный будет и у начальных.
# [04:01.000 --> 04:04.000]  Но сейчас этим удивить довольно сложно,
# [04:04.000 --> 04:06.000]  потому что, как я уже говорил,
# [04:06.000 --> 04:08.000]  этот комплект, который мы сейчас увидим,
# [04:08.000 --> 04:11.000]  полный функционал урезанный будет и у начальных.
# [04:11.000 --> 04:15.000]  Но сейчас этим удивить довольно сложно.
# [04:15.000 --> 04:19.000]  Ну, даже потребителей Hyundai Creta этим не удивишь.
# [04:19.000 --> 04:21.000]  Разгон до сотки. Режим спорт.
# [04:21.000 --> 04:23.000]  Стабилизация выключена.
# [04:23.000 --> 04:25.000]  С двух педалей. Старт.
# [04:30.000 --> 04:32.000]  Должно быть 8,6.
# [04:35.000 --> 04:36.000]  9,1.
# [04:36.000 --> 04:38.000]  Вторая попытка. Я активирую трекшн.
# [04:38.000 --> 04:40.000]  Еще раз с двух педалей. Старт.
# [04:42.000 --> 04:45.000]  Начало очень плавное. Трубоямка.
# [04:51.000 --> 04:52.000]  9,3.
# [04:52.000 --> 04:55.000]  Ну и давайте с одной педали. 3,4. Старт.
# [04:57.000 --> 05:00.000]  О, даже какая-то пробуксовочка была в начале.
# [05:02.000 --> 05:04.000]  Хотя трекшн не выключен.
# [05:05.000 --> 05:06.000]  9,6.
# [05:09.000 --> 05:13.000]  Новый логотип, новые бамперы, фары.
# [05:13.000 --> 05:15.000]  Это все прекрасно.
# [05:15.000 --> 05:18.000]  И каким-то боком здесь оказался еще и новый мотор.
# [05:18.000 --> 05:20.000]  Еще и турбированный. 1,5.
# [05:20.000 --> 05:23.000]  Тот самый, который в Европе и в Корее
# [05:23.000 --> 05:25.000]  выдает 160 лошадиных сил.
# [05:25.000 --> 05:28.000]  У нас его диафорсировали до 150,
# [05:28.000 --> 05:30.000]  чтобы он укладывался в налоги.
# [05:30.000 --> 05:32.000]  Соответственно, я так понимаю,
# [05:32.000 --> 05:35.000]  что если в правильное место приложить правильные мозги,
# [05:35.000 --> 05:39.000]  то можно вернуть те самые 160 лошадиных сил.
# [05:39.000 --> 05:42.000]  Хотя разница в десяточку...
# [05:42.000 --> 05:45.000]  Ну, я не знаю, стоит ли игра свеч слетать с гарантии
# [05:45.000 --> 05:48.000]  из-за того, что разгон этого автомобиля
# [05:48.000 --> 05:52.000]  все равно даже заявленный у хэтчбека
# [05:52.000 --> 05:55.000]  в 8,6 секунды.
# [05:58.000 --> 06:00.000]  Чем не устраивал мотор 1,4 турбо,
# [06:00.000 --> 06:03.000]  который стоял на верхних комплектациях Сиды раньше?
# [06:03.000 --> 06:07.000]  Да бог его знает, ничем, наверное, он не провинился.
# [06:07.000 --> 06:10.000]  Дело просто в том, что глобализация
# [06:10.000 --> 06:14.000]  дотянулась и до нашего рынка.
# [06:14.000 --> 06:17.000]  Под него не стали оставлять
# [06:17.000 --> 06:19.000]  какие-то специальные версии 1,4.
# [06:19.000 --> 06:22.000]  Да, собственно говоря, за что его было особо любить?
# [06:22.000 --> 06:24.000]  У него 140 лошадиных сил было.
# [06:24.000 --> 06:26.000]  Здесь 150. Объем побольше.
# [06:26.000 --> 06:29.000]  Соответственно, нагрузка на двигатель, возможно,
# [06:29.000 --> 06:31.000]  чуть-чуть поменьше.
# [06:31.000 --> 06:36.000]  Плюс топливная экономичность нового порядка.
# [06:36.000 --> 06:41.000]  Вот сейчас, кстати, 7,2 литра на сотку он расходует,
# [06:41.000 --> 06:45.000]  при том, что я толкаюсь в городских...
# [06:45.000 --> 06:48.000]  Ну, это не пробки, но такие довольно затычные,
# [06:48.000 --> 06:49.000]  много светофоров.
# [06:49.000 --> 06:53.000]  Поток городской, который неравномерно едет при этом,
# [06:53.000 --> 06:55.000]  7,1-7,2 литра.
# [06:55.000 --> 06:57.000]  Для такой динамики, в принципе,
# [06:57.000 --> 07:00.000]  очень даже неплохой показатель расхода.
# [07:08.000 --> 07:13.000]  Да, шума от двигателя все-таки больше, чем динамики.
# [07:14.000 --> 07:17.000]  В начале процесса турбоямка,
# [07:17.000 --> 07:20.000]  в середине процесса...
# [07:20.000 --> 07:26.000]  И я думаю, что во всем этом виноват в первую очередь мотор.
# [07:27.000 --> 07:31.000]  Потому как коробка передач 7,10,
# [07:31.000 --> 07:36.000]  у которой выросло КПД на 1,1%,
# [07:36.000 --> 07:42.000]  выдает теперь 94,9% коэффициента полезного действия.
# [07:42.000 --> 07:47.000]  Соответственно, это практически, переводя на русский язык,
# [07:47.000 --> 07:50.000]  коробка отдает всю себя процессу.
# [07:50.000 --> 07:54.000]  А раз так, значит, вот в этих затупах,
# [07:54.000 --> 07:57.000]  в начале ускорения до сотки,
# [07:57.000 --> 08:01.000]  и в переходных режимах виноват сам мотор.
# [08:01.000 --> 08:06.000]  Турбинка, скорее всего, которая раскручивается медленно.
# [08:08.000 --> 08:13.000]  Наша версия – это все и сразу, и в одном месте.
# [08:13.000 --> 08:17.000]  И новые фары, которые КиАсиду теперь положены,
# [08:17.000 --> 08:20.000]  со встроенными противотуманками.
# [08:20.000 --> 08:22.000]  Они полностью светодиодные.
# [08:22.000 --> 08:24.000]  Светодиодные противотуманки.
# [08:24.000 --> 08:27.000]  Я вот сейчас прямо в них тычу пальцем.
# [08:27.000 --> 08:30.000]  Вот это лампа дальнего ближнего света.
# [08:30.000 --> 08:37.000]  И трехрисочные, не знаю, как их обозвать, огоньки ДХО.
# [08:40.000 --> 08:42.000]  Новые буковки КиА здесь.
# [08:42.000 --> 08:48.000]  Новый шрифт, который обозначает СИД, комьюнити, юруп.
# [08:48.000 --> 08:51.000]  И вот на букву Е придумайте, какой эпитет.
# [08:51.000 --> 08:53.000]  Вот это дизайн, значит.
# [08:53.000 --> 08:57.000]  Появились вот такие свето-возвращающие элементы.
# [08:57.000 --> 09:02.000]  Миди-рисочек, сатиновый хром по низу бампера.
# [09:02.000 --> 09:07.000]  И, что любопытно, на версии Универсал, то есть SW, которая,
# [09:07.000 --> 09:10.000]  тоже появилась версия GT-Line.
# [09:10.000 --> 09:13.000]  В нашем случае она стоит на 17-х колесах,
# [09:13.000 --> 09:16.000]  но SW была бы на 16-х.
# [09:16.000 --> 09:18.000]  Это говорит о...
# [09:18.000 --> 09:20.000]  О многом говорит это.
# [09:21.000 --> 09:34.000]  ДИНАМИЧНАЯ МУЗЫКА
# [09:34.000 --> 09:38.000]  Немножко жестковата подвеска, но не пробивает.
# [09:38.000 --> 09:39.000]  Не пробивает.
# [09:39.000 --> 09:43.000]  В городе, по крайней мере, ростовские дорожки
# [09:43.000 --> 09:45.000]  для этого автомобиля норм.
# [09:45.000 --> 09:49.000]  Я сейчас рельсы, видите, преодолеваю поперек.
# [09:50.000 --> 09:52.000]  Ды-ды-ды-ды.
# [09:52.000 --> 09:54.000]  Ну, немножко жестковато.
# [09:54.000 --> 09:56.000]  Но, опять же, все...
# [09:56.000 --> 10:00.000]  Учитывайте еще профиль шин, 17-е колеса.
# [10:00.000 --> 10:03.000]  Минималке будут 15-е штамповки.
# [10:03.000 --> 10:07.000]  Вот та версия, которая за полтора миллиона с хвостом.
# [10:07.000 --> 10:09.000]  15-е диски, стальные.
# [10:09.000 --> 10:13.000]  16-е литье начинается только с комплектации
# [10:13.000 --> 10:16.000]  премиум, по-моему, да?
# [10:16.000 --> 10:18.000]  Или люкс.
# [10:19.000 --> 10:23.000]  Настройки подвески, похоже, остались теми же самыми.
# [10:23.000 --> 10:26.000]  Несмотря на то, что силовой агрегат
# [10:26.000 --> 10:28.000]  изменил вес наверняка,
# [10:28.000 --> 10:30.000]  но, видимо, не так существенно,
# [10:30.000 --> 10:32.000]  чтобы надо было копаться
# [10:32.000 --> 10:34.000]  в настройках подвески.
# [10:34.000 --> 10:36.000]  Я помню еще первый сид,
# [10:36.000 --> 10:38.000]  тот, который был очень красивый,
# [10:38.000 --> 10:40.000]  зализанный весь,
# [10:40.000 --> 10:42.000]  который как раз получил ту самую
# [10:42.000 --> 10:45.000]  престижную дизайнерскую премию Red Dot.
# [10:45.000 --> 10:47.000]  Выглядел он потрясающе.
# [10:47.000 --> 10:49.000]  Ехал он очень страшно.
# [10:49.000 --> 10:53.000]  У него была вот такая килевая раскачка.
# [10:53.000 --> 10:56.000]  Причем, если ты попадал в резонанс
# [10:56.000 --> 10:58.000]  с изгибом дороги,
# [10:58.000 --> 11:00.000]  то возникал риск.
# [11:00.000 --> 11:01.000]  Ну, я вот, по крайней мере,
# [11:01.000 --> 11:03.000]  пугался пару раз,
# [11:03.000 --> 11:05.000]  что машина вот-вот улетит с этой дороги,
# [11:05.000 --> 11:08.000]  потому что заканчивалось сцепление с ней
# [11:08.000 --> 11:10.000]  прямо на глазах.
# [11:10.000 --> 11:13.000]  То поколение, которое сейчас
# [11:13.000 --> 11:15.000]  претерпевает рестайлинг,
# [11:15.000 --> 11:18.000]  уже подвеска полностью избавилась
# [11:18.000 --> 11:19.000]  от этих косяков.
# [11:19.000 --> 11:21.000]  Она едет не прям вот жесть,
# [11:21.000 --> 11:24.000]  как хорошо, остро и весело,
# [11:24.000 --> 11:26.000]  впечатляюще, но едет правильно.
# [11:31.000 --> 11:34.000]  Разделяю нытья в комментариях,
# [11:34.000 --> 11:37.000]  что балка усида, многорычажка усида.
# [11:37.000 --> 11:39.000]  Это, во-первых, появилось не сейчас,
# [11:39.000 --> 11:41.000]  не с этим обновлением.
# [11:41.000 --> 11:43.000]  Уже была усида.
# [11:43.000 --> 11:44.000]  Это градация.
# [11:44.000 --> 11:47.000]  Нижние комплектации балка полузависимая сзади,
# [11:47.000 --> 11:50.000]  верхние комплектации с турбомотором многорычажка.
# [11:50.000 --> 11:52.000]  То же самое у Шкоды Октавии.
# [11:52.000 --> 11:54.000]  Абсолютно та же ситуация.
# [11:54.000 --> 11:57.000]  Низы потребляют балку и экономят,
# [11:57.000 --> 12:00.000]  потому как многорычажка дороже в обслуживании,
# [12:00.000 --> 12:02.000]  она сложнее,
# [12:02.000 --> 12:04.000]  там больше узлов, которые требует
# [12:04.000 --> 12:06.000]  вмешательства обслуживания.
# [12:06.000 --> 12:08.000]  Соответственно, за сервис ты потом тоже
# [12:08.000 --> 12:12.000]  платишь больше, чем вот этот самый балочник.
# [12:14.000 --> 12:17.000]  Где реализовать потенциал многорычажной подвески?
# [12:17.000 --> 12:21.000]  На серпантинах Самары или Москвы?
# [12:21.000 --> 12:23.000]  Ну, я не видел людей,
# [12:23.000 --> 12:26.000]  которые как-то вот прям проявляют
# [12:26.000 --> 12:28.000]  свои драйверские навыки
# [12:28.000 --> 12:30.000]  за рулем KIA Ceed на этих самых
# [12:30.000 --> 12:32.000]  посковских или самарских серпантинах.
# [12:32.000 --> 12:35.000]  Ну, потому что никто не проявляет, во-первых,
# [12:35.000 --> 12:37.000]  а во-вторых, нет этих серпантинов.
# [12:37.000 --> 12:42.000]  Мы ездим, как правило, овощим по направлениям.
# [12:44.000 --> 12:46.000]  Ух ты ж!
# [12:46.000 --> 12:50.000]  Недостаточная поворачиваемость вылезла.
# [12:50.000 --> 12:53.000]  Дорожка мокренькая,
# [12:53.000 --> 12:55.000]  и поехали мы наружу.
# [12:55.000 --> 12:57.000]  Стабилизация, конечно, вмешалась,
# [12:57.000 --> 13:00.000]  машину поймала, но...
# [13:00.000 --> 13:01.000]  Ёлы-палы.
# [13:01.000 --> 13:03.000]  Это вот многорычажка, ребята.
# [13:03.000 --> 13:05.000]  Поэтому сильно завидовать
# [13:05.000 --> 13:07.000]  саморазвитию,
# [13:07.000 --> 13:09.000]  а не саморазвитию,
# [13:09.000 --> 13:11.000]  это вот многорычажка, ребята.
# [13:11.000 --> 13:14.000]  Поэтому сильно завидовать тем,
# [13:14.000 --> 13:18.000]  у кого топовая комплектация с турбомотором,
# [13:18.000 --> 13:20.000]  можно им завидовать по той причине,
# [13:20.000 --> 13:22.000]  что у них другая отдача мотора,
# [13:22.000 --> 13:24.000]  другой характер,
# [13:24.000 --> 13:26.000]  ну и, собственно говоря, экономичность
# [13:26.000 --> 13:28.000]  этого двигателя другая.
# [13:29.000 --> 13:32.000]  Многорычажка в нашей топовой версии
# [13:32.000 --> 13:34.000]  это не прям вот благо-благо.
# [13:34.000 --> 13:36.000]  Машина, надо сказать,
# [13:36.000 --> 13:38.000]  не слишком остро реагирует
# [13:38.000 --> 13:40.000]  на поворот руля.
# [13:40.000 --> 13:42.000]  Есть маленькое запаздывание.
# [13:42.000 --> 13:44.000]  Такое ощущение, что пока вся эта
# [13:44.000 --> 13:46.000]  кинематическая схема
# [13:46.000 --> 13:49.000]  поймет, примет мою команду
# [13:49.000 --> 13:50.000]  и начнет ее исполнять,
# [13:50.000 --> 13:53.000]  проходят, ну, какие-то доли, секунды.
# [13:53.000 --> 13:55.000]  Я их улавливаю.
# [13:56.000 --> 13:58.000]  Леха, где ты здесь увидел крыло?
# [13:58.000 --> 14:00.000]  Я-то знаю, что это крыло,
# [14:00.000 --> 14:02.000]  потому что нам показывали рисуночек.
# [14:02.000 --> 14:04.000]  Тут даже перышки были нарисованы.
# [14:04.000 --> 14:06.000]  Но это же здоровая
# [14:06.000 --> 14:08.000]  пластмассовая хрень,
# [14:08.000 --> 14:10.000]  которую вставили в угол бампера.
# [14:10.000 --> 14:12.000]  Мне даже больше понравилась
# [14:12.000 --> 14:14.000]  версия не GT-Line-овская.
# [14:14.000 --> 14:16.000]  Там вот так
# [14:16.000 --> 14:18.000]  трезубец такой торчит
# [14:18.000 --> 14:20.000]  вперед. Они говорят, что это стрела,
# [14:20.000 --> 14:22.000]  хотя стрела, которая, по-моему,
# [14:22.000 --> 14:24.000]  попала в автомобиль.
# [14:27.000 --> 14:29.000]  48 светодиодных ячеек.
# [14:29.000 --> 14:31.000]  Они отвечают за все.
# [14:31.000 --> 14:33.000]  Стоп-сигнал, габарит.
# [14:33.000 --> 14:35.000]  Вот здесь 3 ячеечки
# [14:35.000 --> 14:37.000]  и там еще 3 штуки. Это задний ход.
# [14:37.000 --> 14:39.000]  И обратите внимание,
# [14:39.000 --> 14:41.000]  впервые в линейке
# [14:41.000 --> 14:43.000]  автомобилей Kia появились
# [14:43.000 --> 14:45.000]  динамические указатели поворота.
# [14:45.000 --> 14:47.000]  И они, по-моему, решили оторваться
# [14:47.000 --> 14:49.000]  за все предыдущие,
# [14:49.000 --> 14:51.000]  на которых этого не было.
# [15:03.000 --> 15:05.000]  Сейчас можно немножко про шум поговорить.
# [15:05.000 --> 15:07.000]  Я слышу
# [15:07.000 --> 15:09.000]  подвывание мотора,
# [15:09.000 --> 15:11.000]  но это вторично
# [15:11.000 --> 15:13.000]  после того, что я слышу
# [15:13.000 --> 15:15.000]  шум колесных арок. Мы обуто
# [15:15.000 --> 15:17.000]  сейчас в шине Michelin Alpine 5.
# [15:17.000 --> 15:19.000]  То есть это фрикционки.
# [15:19.000 --> 15:21.000]  Это сами по себе мягкие шины.
# [15:21.000 --> 15:23.000]  Должны быть
# [15:23.000 --> 15:25.000]  очень тихими, но при этом
# [15:25.000 --> 15:27.000]  я их слышу. Я их слышу
# [15:27.000 --> 15:29.000]  постоянно. А если здесь будут шипы,
# [15:29.000 --> 15:31.000]  то я, скорее всего,
# [15:31.000 --> 15:33.000]  потону в грохоте шипов.
# [15:33.000 --> 15:35.000]  И очень странно, что корейцы
# [15:35.000 --> 15:37.000]  ничего не сделали с колесными
# [15:37.000 --> 15:39.000]  арками при обновлении.
# [15:39.000 --> 15:41.000]  Вот сейчас опять была недостаточная
# [15:41.000 --> 15:43.000]  поворачивка.
# [15:45.000 --> 15:47.000]  Типичный язвительный
# [15:47.000 --> 15:49.000]  вопрос от вас,
# [15:49.000 --> 15:51.000]  что сделала Kia,
# [15:51.000 --> 15:53.000]  чтобы упростить
# [15:53.000 --> 15:55.000]  автомобиль и потом брать
# [15:55.000 --> 15:57.000]  с вас больше денег. Но на самом
# [15:57.000 --> 15:59.000]  деле я вижу, что появились
# [15:59.000 --> 16:01.000]  здесь такие штуки, как
# [16:01.000 --> 16:03.000]  вот в максимальной опять же версии
# [16:03.000 --> 16:05.000]  сиденье водителя с памятью.
# [16:05.000 --> 16:07.000]  Такого раньше не было.
# [16:07.000 --> 16:09.000]  Беспроводная зарядка.
# [16:09.000 --> 16:11.000]  Такого раньше не было.
# [16:11.000 --> 16:13.000]  Кресла новые
# [16:13.000 --> 16:15.000]  с кожа замша.
# [16:15.000 --> 16:17.000]  Это опять же не было.
# [16:17.000 --> 16:19.000]  Но это версия GT Line Sport.
# [16:19.000 --> 16:21.000]  Плюс вот эта стекляшечка
# [16:21.000 --> 16:23.000]  черная, которой раньше не было.
# [16:23.000 --> 16:25.000]  Да и пофигу. Ну и
# [16:25.000 --> 16:27.000]  панель мультимедийная.
# [16:27.000 --> 16:29.000]  Мультимедийная панель 10.25 дюймов.
# [16:29.000 --> 16:31.000]  Это ну
# [16:31.000 --> 16:33.000]  также считайте как на той же
# [16:33.000 --> 16:35.000]  Skoda Octavia в хорошей комплектации.
# [16:35.000 --> 16:37.000]  И 12.3
# [16:37.000 --> 16:39.000]  дюйма приборная панель.
# [16:39.000 --> 16:41.000]  В максимальной версии
# [16:41.000 --> 16:43.000]  мультимедийки с вот этой большой диагональю
# [16:43.000 --> 16:45.000]  10.25
# [16:45.000 --> 16:47.000]  у вас обязательно
# [16:47.000 --> 16:49.000]  проводное соединение
# [16:49.000 --> 16:51.000]  смартфона для того, чтобы
# [16:51.000 --> 16:53.000]  получить здесь Apple CarPlay
# [16:53.000 --> 16:55.000]  или Google Android Auto.
# [16:55.000 --> 16:57.000]  Причем в минимальных версиях
# [16:57.000 --> 16:59.000]  с диагональю 8 дюймов
# [16:59.000 --> 17:01.000]  это все делается по
# [17:01.000 --> 17:03.000]  беспроводному соединению.
# [17:03.000 --> 17:05.000]  Как они так
# [17:05.000 --> 17:07.000]  не могут договориться? Странно.
# [17:07.000 --> 17:09.000]  Но мне кажется в этом
# [17:09.000 --> 17:11.000]  случае обладатели машин
# [17:11.000 --> 17:13.000]  менее дорогих находятся
# [17:13.000 --> 17:15.000]  в более привилегированном
# [17:15.000 --> 17:17.000]  положении. Если можно
# [17:17.000 --> 17:19.000]  так сказать. Ну картинка у них чуть поменьше
# [17:19.000 --> 17:21.000]  здесь, да. У них
# [17:21.000 --> 17:23.000]  кстати и приборочка
# [17:23.000 --> 17:25.000]  будет традиционной. То есть там
# [17:25.000 --> 17:27.000]  будет жидкокристаллический дисплей посередине
# [17:27.000 --> 17:29.000]  цветной и два
# [17:29.000 --> 17:31.000]  стандартных циферблата. То что
# [17:31.000 --> 17:33.000]  у нас приборная
# [17:33.000 --> 17:35.000]  панель Supervision 12
# [17:35.000 --> 17:37.000]  с лишним дюймов
# [17:37.000 --> 17:39.000]  жидкокристаллическая
# [17:39.000 --> 17:41.000]  это касается только
# [17:41.000 --> 17:43.000]  топовых комплектаций GT Line
# [17:43.000 --> 17:45.000]  GT Line Plus. Про телематику
# [17:45.000 --> 17:47.000]  Kia Connect мы пытались вам рассказать
# [17:47.000 --> 17:49.000]  на Kia Cerato, но в итоге
# [17:49.000 --> 17:51.000]  успешно загубили съемку.
# [17:51.000 --> 17:53.000]  Поэтому дубль два.
# [17:53.000 --> 17:55.000]  Но сначала покажу старое
# [17:55.000 --> 17:57.000]  доброе, как это можно делать
# [17:57.000 --> 17:59.000]  с ключика. То есть с ключика
# [17:59.000 --> 18:01.000]  вы можете запускать
# [18:01.000 --> 18:03.000]  двигатель
# [18:03.000 --> 18:05.000]  дистанционно. Да,
# [18:05.000 --> 18:07.000]  вот оно работает. Телематикой
# [18:07.000 --> 18:09.000]  вы можете то же самое проделывать из
# [18:09.000 --> 18:11.000]  любой точки мира. Вы можете
# [18:11.000 --> 18:13.000]  запускать мотор,
# [18:13.000 --> 18:15.000]  настраивать климатическую
# [18:15.000 --> 18:17.000]  установку на определенную температуру,
# [18:17.000 --> 18:19.000]  выставлять показания
# [18:19.000 --> 18:21.000]  обогрева руля, можете открывать
# [18:21.000 --> 18:23.000]  закрывать окна, смотреть где
# [18:23.000 --> 18:25.000]  автомобиль, смотреть, чекать
# [18:25.000 --> 18:27.000]  все системы, было ли вторжение
# [18:27.000 --> 18:29.000]  в автомобиль, он должен вам push
# [18:29.000 --> 18:31.000]  уведомления присылать. Можете делать
# [18:31.000 --> 18:33.000]  практически все.
# [18:33.000 --> 18:35.000]  Опаньки, неверный пароль.
# [18:35.000 --> 18:37.000]  Черт побери, какая
# [18:37.000 --> 18:39.000]  хорошая штука
# [18:39.000 --> 18:41.000]  этот телекоммуникационный
# [18:41.000 --> 18:43.000]  сервис Kia Connect.
# [18:43.000 --> 18:45.000]  Рекомендую!
# [18:45.000 --> 18:49.000]  В комплексе систем
# [18:49.000 --> 18:51.000]  DriveWise не могу сказать, что есть какая-то
# [18:51.000 --> 18:53.000]  совершенно новая, невиданная,
# [18:53.000 --> 18:55.000]  фантастическая
# [18:55.000 --> 18:57.000]  система, но
# [18:57.000 --> 18:59.000]  просто здесь их много.
# [18:59.000 --> 19:01.000]  Здесь их много и есть парочка
# [19:01.000 --> 19:03.000]  таких, которые реально
# [19:03.000 --> 19:05.000]  нужны, но у конкурентов,
# [19:05.000 --> 19:07.000]  к примеру, на той же Skoda Octavia
# [19:07.000 --> 19:09.000]  только
# [19:09.000 --> 19:11.000]  предупреждение, если ты
# [19:11.000 --> 19:13.000]  перестраиваешься в левую полосу,
# [19:13.000 --> 19:15.000]  там движется автомобиль в солипой зоне,
# [19:15.000 --> 19:17.000]  здесь она тебе упирается,
# [19:17.000 --> 19:19.000]  не дает поворачивать.
# [19:19.000 --> 19:21.000]  Это раз. И еще одна
# [19:21.000 --> 19:23.000]  система полезная, когда
# [19:23.000 --> 19:25.000]  ты выезжаешь с парковки задним ходом,
# [19:25.000 --> 19:27.000]  кто-то пересекает тебе траекторию движения,
# [19:27.000 --> 19:29.000]  сид оттормаживается
# [19:29.000 --> 19:31.000]  сам.
# [19:31.000 --> 19:33.000]  Та же самая Octavia только предупреждает.
# [19:33.000 --> 19:35.000]  Ну, а все остальное,
# [19:35.000 --> 19:37.000]  в принципе, это все в автомобильном мире
# [19:37.000 --> 19:39.000]  есть. Просто такое количество
# [19:39.000 --> 19:41.000]  систем
# [19:41.000 --> 19:43.000]  оно встречается
# [19:43.000 --> 19:45.000]  не часто. Ну, вот в той же
# [19:45.000 --> 19:47.000]  Octavia их много, но, опять же,
# [19:47.000 --> 19:49.000]  вот я сказал, есть отличия.
# [19:49.000 --> 19:51.000]  В общем, все,
# [19:51.000 --> 19:53.000]  что сделали с Ceed'ом с этим
# [19:53.000 --> 19:55.000]  обновлением, исключая внешний
# [19:55.000 --> 19:57.000]  вид, это само собой, это должно
# [19:57.000 --> 19:59.000]  быть, да, это бросается в
# [19:59.000 --> 20:01.000]  глаза и продает автомобиль в первую
# [20:01.000 --> 20:03.000]  очередь. Но,
# [20:03.000 --> 20:05.000]  если вникать в суть,
# [20:05.000 --> 20:07.000]  то, мне кажется,
# [20:07.000 --> 20:09.000]  все, что сделали с топовыми комплектациями,
# [20:09.000 --> 20:11.000]  это скорее демонстрация
# [20:11.000 --> 20:13.000]  возможностей, силы
# [20:13.000 --> 20:15.000]  и направления движения компании
# [20:15.000 --> 20:17.000]  Kia вот в сторону телематики,
# [20:17.000 --> 20:19.000]  активных систем, управления.
# [20:19.000 --> 20:21.000]  Я бы обратил еще особое
# [20:21.000 --> 20:23.000]  внимание на то, что они сделали
# [20:23.000 --> 20:25.000]  с комплектациями начальными.
# [20:25.000 --> 20:27.000]  То есть вот то, что они сделали версию
# [20:27.000 --> 20:29.000]  за полтора миллиона с автоматической коробкой
# [20:29.000 --> 20:31.000]  передач, механику исключили полностью
# [20:31.000 --> 20:33.000]  и начальная версия,
# [20:33.000 --> 20:35.000]  она очень неплохо укомплектована.
# [20:35.000 --> 20:37.000]  Там и подогревы сидений,
# [20:37.000 --> 20:39.000]  там и мультимедийная
# [20:39.000 --> 20:41.000]  система с Apple CarPlay, Google Android
# [20:41.000 --> 20:43.000]  Auto и
# [20:43.000 --> 20:45.000]  собственно,
# [20:45.000 --> 20:47.000]  что там, кондиционер есть еще, да,
# [20:47.000 --> 20:49.000]  камера заднего вида. Мне кажется,
# [20:49.000 --> 20:51.000]  это все сделано для того, чтобы
# [20:51.000 --> 20:53.000]  двинуть Kia Ceed в
# [20:53.000 --> 20:55.000]  CarSharing, сделать его
# [20:55.000 --> 20:57.000]  ближе к массам. То есть, чтобы
# [20:57.000 --> 20:59.000]  вы там распробовали этот автомобиль,
# [20:59.000 --> 21:01.000]  потом шли в салон и покупали
# [21:01.000 --> 21:03.000]  уже версию подороже
# [21:03.000 --> 21:05.000]  с расширенным функционалом.
# [21:05.000 --> 21:07.000]  И вот это
# [21:07.000 --> 21:09.000]  интересно, это правильно,
# [21:09.000 --> 21:11.000]  это такая, ну,
# [21:11.000 --> 21:13.000]  довольно хитрая корейская
# [21:13.000 --> 21:15.000]  стратегия.
# [21:15.000 --> 21:17.000]  Вот, нам от этого
# [21:17.000 --> 21:19.000]  точно не хуже,
# [21:19.000 --> 21:21.000]  а даже наоборот.
# [21:21.000 --> 21:23.000]  Все на сегодня про Kia Ceed.
# [21:23.000 --> 21:25.000]  О, прощай мой голос.
# [21:25.000 --> 21:27.000]  Подпишитесь на канал,
# [21:27.000 --> 21:29.000]  лайк поставите, нам будет приятно
# [21:29.000 --> 21:31.000]  и ловите новые видео.
# [21:31.000 --> 21:33.000]  Пока!
#
# Транскрибирование файла Новый KIA Ceed ⧸ SW 2022： БЕЗ ПАЛКИ С БАЛКОЙ. Тест-Драйв.m4a завершено.
# Транскрибирование файла: Новая Kia Cerato： стало круто？ ⧸ Киа Церато 2021 тест и обзор.m4a...
# [00:00.000 --> 00:10.880]  Привет друзья! Что нового в обновленном KIA Cerato? Самое главное это логотип. Да,
# [00:10.880 --> 00:16.280]  Cerato первым на российском рынке примерил вот эту вот обновленную эмблему. Теперь такое угловатое
# [00:16.280 --> 00:23.240]  написание букв, стильное, современное и нету никакого старорежимного овала. Она везде и эта
# [00:23.240 --> 00:28.880]  эмблема постепенно начнет появляться и на всех других машинах марки, но первым ее носителем стал
# [00:28.960 --> 00:36.760]  именно Cerato. Новые фары, фирменная такая светодиодная подпись из шести пунктиров, в базовой
# [00:36.760 --> 00:42.280]  комплектации будут естественно галогенки, ходовой огонь останется светодиодным и будет линзованный
# [00:42.280 --> 00:49.200]  ближний дальний свет с галогеном. Противотуманки тоже светодиодные, стильно они оформлены,
# [00:49.200 --> 00:55.400]  вписаны в бампер очень изящно, бампер естественно тоже новый. У нас здесь комплектация GT-Line,
# [00:55.560 --> 01:01.280]  приспортивленная, у нее черные и красные акценты. Здесь не очень выделяется, потому что сама
# [01:01.280 --> 01:07.040]  машина красная, но если бы она была какого-то другого цвета, то вот эти вот штуки красными все
# [01:07.040 --> 01:13.040]  равно бы остались, равно как и глянцевые вставки на бампере и черные глянцевые корпуса зеркал.
# [01:13.040 --> 01:19.400]  В профиль практически ничего не поменялось, разве что новые цвета и узоры литых дисков. Кстати
# [01:19.440 --> 01:27.800]  говоря, литые диски появляются только в четвертой снизу комплектации Prestige. Это будут 16-дюймовые
# [01:27.800 --> 01:34.520]  колеса, а в максималке колеса стоят диаметром 17 дюймов. Вот сзади еще атрибуты контрастной
# [01:34.520 --> 01:39.960]  отделки комплектации GT-Line. Черный приклеенный спойлер, антенна плавник тоже черного цвета. Короче
# [01:39.960 --> 01:44.400]  говоря, комплектацию GT-Line выгодно брать не в черном цвете и не в красном, тогда вот эти вот
# [01:44.520 --> 01:52.360]  контрастные элементы отделки будут видны и подчеркнут характер комплектации. Задние фонари
# [01:52.360 --> 01:57.880]  перекликаются по узору с фарами, те же шесть пунктиров, но полностью светодиодными они становятся
# [01:57.880 --> 02:02.840]  только в дорогих версиях. В базе, как и в случае с фарами, здесь будут стоять лампы накаливания.
# [02:02.840 --> 02:09.840]  Ну и вот интересное такое решение, но интересное оно со знаком минус. В этих здоровенных
# [02:09.920 --> 02:14.840]  двухсекционных фонарях нашлось место только габариткам, стоп-сигналам, ну и задним
# [02:14.840 --> 02:23.840]  противотуманкам. Фонари заднего хода в бампере, ну ладно, допустим это решение хорошее внизу и с
# [02:23.840 --> 02:28.560]  угла. Когда включите заднюю передачу, они вам худо-бедно будут пространство подсвечивать. Да,
# [02:28.560 --> 02:34.720]  на всех Cerato стоит вместе с мультимедийной системой камера заднего вида, есть парктроник,
# [02:34.720 --> 02:39.640]  но лишняя подсветка не будет. Но вот то, что здесь расположены поворотники, это решение
# [02:40.240 --> 02:46.760]  плохое. Потому что в плотном потоке, в пробке, даже когда вы едете на легковушке, они очень часто
# [02:46.760 --> 02:52.120]  выпадают из вашего поля зрения. Если высокий кроссовер или тем более внедорожник, ну сами понимаете,
# [02:52.120 --> 02:56.440]  попробуйте набрать в пробке такую дистанцию, чтобы вот эти поворотники было видно. Да перед
# [02:56.440 --> 03:03.600]  вами мигом еще один Cerato влезет и опять вы ничего не увидите. Но вот с изменением этого решения
# [03:03.720 --> 03:09.840]  теперь уже ждать только до смены поколения. Компания Kia очень хочет популяризовать разные
# [03:09.840 --> 03:15.680]  цифровые сервисы. Именно поэтому мультимедийка с поддержкой Android и Apple входит в базовую
# [03:15.680 --> 03:21.000]  комплектацию Cerato. А начиная с комплектации Prestige, на которую приходится наибольший
# [03:21.000 --> 03:26.440]  спрос, на машину ставят уже некоторые системы активной безопасности. Они называются DriveWise у
# [03:26.440 --> 03:32.360]  Kia. Ну в частности будет ассистент выезда с парковки задним ходом, автоматическое переключение
# [03:32.360 --> 03:38.080]  дальнего света на ближний и обратно, система удержания в полосе. А вот адаптивный круиз
# [03:38.080 --> 03:44.440]  появится только вот в таком Cerato, который вы видите за мной. Это топовая версия GT Line Plus.
# [03:44.440 --> 03:50.000]  И еще одна штука, которая тоже появляется в комплектации Prestige, и Cerato стал ее первым
# [03:50.000 --> 03:54.800]  носителем на российском рынке. Это фирменная телематика через мобильное приложение, которое
# [03:54.800 --> 04:00.720]  называется Kia Connect. Скачиваете мобильное приложение на смартфон, синхронизируете с машиной и
# [04:00.760 --> 04:08.280]  получаете доступ ко всей информации. Запас хода, местоположение машины, статус дверей открытой
# [04:08.280 --> 04:13.120]  или закрытой. Но самое главное, можно дистанционно запустить двигатель, выставить температуру
# [04:13.120 --> 04:18.840]  климат-контроля, включить или выключить обогревы. То есть, к моменту своего прихода после ночевки
# [04:18.840 --> 04:25.440]  или после работы, вы получаете абсолютно готовую к поездке машину с комфортным микроклиматом внутри.
# [04:25.520 --> 04:33.240]  Чем это отличается от дистанционного запуска, который и так есть на Kia? Вот он, клавиши на брелоке.
# [04:33.240 --> 04:38.480]  Но брелок срабатывает только когда машина находится от вас в зоне прямой видимости. 100 метров,
# [04:38.480 --> 04:46.280]  ну 150. А с приложением Kia Connect, пожалуйста, хоть из Америки машину, стоящую во дворе в Москве.
# [04:46.280 --> 04:52.640]  Так что штука удобная. Базовая комплектация Classic стоит миллион четыреста. Прибавка в полсотни
# [04:52.640 --> 04:58.080]  тысяч, но более-менее адекватна. Механическую коробку передач можно получить в трех первых
# [04:58.080 --> 05:03.040]  комплектациях. Это Classic, Comfort и Luxe. Максимальный спрос, как я уже сказал, приходится на версию
# [05:03.040 --> 05:08.680]  Prestige. Там уже только автомат с мотором 1.6 или с двухлитровым. Стоят такие машины миллион
# [05:08.680 --> 05:14.360]  шестьсот тридцать тысяч или миллион шестьсот восемьдесят пять. Соответственно. Ну а максимальные
# [05:14.360 --> 05:19.840]  версии GT Line и GT Line Plus это уже миллион семьсот пятьдесят, миллион восемьсот тридцать. Относительно
# [05:19.840 --> 05:26.400]  предшественника самый дорогой Cerato прибавил больше сотни тысяч. Но что поделать, увы, таковы
# [05:26.400 --> 05:33.720]  реалии и практически все модели сейчас, проходя рестайлинг или меняя поколение, дорожают на
# [05:33.720 --> 05:39.400]  сопоставимые суммы. Но Cerato все равно остается одним из самых выгодных, самых дешевых предложений
# [05:39.400 --> 05:45.320]  в классе. У нас здесь машина в максимальной комплектации GT Line, точнее GT Line Plus. Этих
# [05:45.320 --> 05:51.560]  версий две. Просто Line и Line Plus. Но у обеих внутри будет руль с подрезанной нижней хордой,
# [05:51.560 --> 05:57.280]  педали с металлическими накладками, сидение с развитой боковой поддержкой. Но в зависимости,
# [05:57.280 --> 06:02.760]  опять-таки, от уровня GT Line, это будет либо комбинированный отдел к сидению, либо,
# [06:02.760 --> 06:09.480]  вот как у нас, совсем крутая, полностью кожаная с перфорированными лицевыми частями. Если вы
# [06:09.480 --> 06:16.800]  смотрели до сих пор в новостях об обновленном Cerato фотографии корейской версии, а, собственно,
# [06:16.800 --> 06:23.160]  только они до сих пор и были, то вы несколько разочаруетесь. Цифровая комбинация приборов здесь
# [06:23.160 --> 06:28.680]  так и не появилась, остались аналоговые. Лично я против этого ничего не имею, потому что считаю,
# [06:28.680 --> 06:36.200]  что приборка Kia, она практически идеальна на сегодня. Она отлично читается, у нее отлично все
# [06:36.200 --> 06:40.960]  продумано и скомпоновано на центральном дисплее. Он бывает побольше, поменьше, опять-таки,
# [06:40.960 --> 06:48.080]  в зависимости от комплектации. Но вот аналоговые шкалы, 4 штуки, они здесь останутся. Мне нравится,
# [06:48.080 --> 06:53.440]  но кто-то может быть разочарован. И тоже, что не то, что было обещано, ходили слухи, что может
# [06:53.440 --> 07:01.560]  появиться, мультимедийка с увеличенным до 10,3 дюйма дисплеем. Нет, стоит только 8-дюймовая. Но!
# [07:01.680 --> 07:06.600]  Расстроятся из-за этого только те, кто хотел купить дорогие комплектации, потому что, естественно,
# [07:06.600 --> 07:12.200]  этот большой дисплей был бы в дорогих версиях. А вот те, кто будет покупать машины попроще,
# [07:12.200 --> 07:16.400]  наоборот, обрадуются. Потому что, если раньше в минимальных версиях не было никакого цветного
# [07:16.400 --> 07:22.560]  тачскрина, то теперь вот такой 8-дюймовый стоит во всех машинах без исключения, вне зависимости
# [07:22.560 --> 07:30.120]  от комплектации. У Cerato 8 дюймов цветной монитор. В нем зашита поддержка протоколов Apple, Apple
# [07:30.160 --> 07:40.000]  CarPlay и Android Auto, причем по беспроводной технологии. Не знаю, пробовал это на Kia Rio рестайлинговом,
# [07:40.000 --> 07:45.360]  там система достаточно часто отваливалась. Тут вот мы уже изрядно времени не проехали,
# [07:45.360 --> 07:50.760]  но вроде ничего, все работает. Ну, надеюсь, протокол усовершенствовали и он стал надежнее.
# [07:50.760 --> 07:58.680]  Ну и обновка. И в Apple, и в Android появилась. С недавних пор они поддерживают навигацию Яндекса.
# [07:58.800 --> 08:05.640]  Правда, есть один нюанс. Если в вашем смартфоне Яндекс.Авто или в мультимедийке, которая базируется
# [08:05.640 --> 08:11.720]  на операционке Яндекс.Авто, Яндекс.Навигатор бесплатный, то вот здесь за него придется платить.
# [08:11.720 --> 08:18.480]  Ну, как платить? Нужно активировать подписку Яндекс.Плюс. Стоит она 200 рублей, и то только с
# [08:18.480 --> 08:26.720]  четвертого месяца. Первые три месяца бесплатно, потом 200 рублей в месяц. И вы получите не только
# [08:26.760 --> 08:35.320]  Яндекс.Карты и Яндекс.Навигатор. Это уже не только автомобильная тема, там масса плюшек вот
# [08:35.320 --> 08:42.560]  этих яндексовских кэшбэки, бонусы, Яндекс.Музыка и прочее, прочее, прочее. Короче говоря, если вы
# [08:42.560 --> 08:50.280]  человек такой современный всеми этими яндексовскими штуками пользуетесь, эта штука наверняка у вас
# [08:50.280 --> 08:55.920]  уже есть, так что лишних денег никаких вы платить не будете. Просто вот этот нюанс нужно иметь в
# [08:55.920 --> 09:06.080]  виду. Ну, что, ну, вот что-то с тачскрином тут не так, потому что, потому что не хочет он работать
# [09:06.080 --> 09:12.840]  как мультитач. Вот на нажатие реагирует нормально, а вот мультитач здесь не работает. Приходится
# [09:12.840 --> 09:20.320]  вот плюс-минусом карту масштабировать. Но, короче говоря, есть мультимедийки уже и поживее,
# [09:20.320 --> 09:28.280]  и современнее. В общем от KIA как-то я этого не ожидал. Да, комплекс систем помощи водителю,
# [09:28.280 --> 09:33.520]  он уже появляется в комплектации Prestige, правда не в полном наборе. Адаптивный круиз будет
# [09:33.520 --> 09:40.040]  только вот в самой топовой версии GT-Line Plus, а в версиях попроще будет удержание в полосе,
# [09:40.040 --> 09:46.000]  ассистент выезда с парковки задним ходом. Ну, в общем, такой минимальный набор, который тоже
# [09:46.080 --> 09:52.160]  делает жизнь легче. Климат-контроль тут, правда, попроще, чем в остальных моделях KIA и
# [09:52.160 --> 09:58.480]  Hyundai. Знаете, у них есть такая фишка включить автоматический режим в одной из трех интенсивностей.
# [09:58.480 --> 10:04.000]  Нормальная, экономичная или, наоборот, быстрая. Ну, вот тут режим авто только один. Зато климат
# [10:04.000 --> 10:09.720]  двухзонный, потому что, например, на кроссовере KIA SELTOS, который стоит примерно те же денег,
# [10:09.720 --> 10:16.560]  что и Serato, климат однозонный, и он за это заслуживает как бы некоторые минусы в сравнительных
# [10:16.560 --> 10:23.360]  тестах. В целом, в общем, Serato остался машиной удобной, достаточно просторной для передних
# [10:23.360 --> 10:30.840]  пассажиров, для задних. Багажник, объем 502 литра. Да, это седан, так что накладываются свои
# [10:30.840 --> 10:38.360]  ограничения по трансформации, но в общем и целом, как семейную машину, Serato использовать можно.
# [10:39.040 --> 10:44.720]  Как вы уже, наверное, могли догадаться из того, что я рассказал о машине, на ходу рестайлинговый
# [10:44.720 --> 10:50.720]  KIA Serato относительно предшественника не поменялся. Все потому что, если у Elantra это была смена
# [10:50.720 --> 10:56.840]  поколения с доработкой ходовой части, с заменой двигателей на новое семейство Smart Stream,
# [10:56.840 --> 11:03.280]  то здесь ничего не поменялось. Моторы 1.6, 2 литра, коробки передач, сеступенчатая механика и
# [11:03.280 --> 11:13.000]  автомат, все осталось прежнее. Ручку можно поставить только с младшим двигателем, а двухлитровый
# [11:13.000 --> 11:19.680]  идет исключительно с автоматом. Ну и это, на мой взгляд, самый оптимальный вариант, потому что все-таки
# [11:19.680 --> 11:27.200]  1.6 мотор с ручкой это вариант так уже малопопулярный. На механическую коробку передач у предыдущего
# [11:27.240 --> 11:35.280]  Serato приходилось всего 5% продаж. Поэтому то, что на Elantra после смены поколения версии с механикой
# [11:35.280 --> 11:42.120]  вообще убрали из гаммы, это, в принципе, шаг логичный. Компания ничего не потеряла. И вообще
# [11:42.120 --> 11:49.920]  удивительно в этом свете, что у Serato эту версию оставили. Но, впрочем, можно предположить, что сделали
# [11:49.960 --> 11:58.000]  это ради хорошей рекламной стартовой цены. 1.6 с автоматом все-таки едет не слишком бодро, особенно
# [11:58.000 --> 12:03.800]  если вы даже только с водителем в салоне это чувствуете, а посадите еще кого-то, положите в багажник,
# [12:03.800 --> 12:11.480]  уже будет грустновато. Так что вот 2 литра с автоматом оптимальный выбор. В принципе, хватает
# [12:11.480 --> 12:18.880]  запаса тяги и в городе, и на трассе. Хотя машина, разумеется, не самолет. Если хотите действительно
# [12:18.880 --> 12:28.480]  шустрый характер получить, то вам к дилеру Skoda. Вот там 1.4 turbo, те же 150 сил, тоже классический
# [12:28.480 --> 12:34.400]  автомат, правда, восьмиступенчатый. И вот Octavia едет уже, конечно, гораздо интереснее. Но и стоит
# [12:34.400 --> 12:43.880]  дороже. Если не спеша и размеренно ездить по городу и в особо стоячие пробки не попадать, то расход
# [12:43.880 --> 12:51.440]  будет варьироваться около 10-10,5 литров на сотню. В принципе, двигатель достаточно экономичный,
# [12:51.440 --> 13:02.040]  и 1.6 есть не намного меньше. В целом, энергоемкость подвески, степень ее жесткости, они оптимальны.
# [13:02.040 --> 13:08.440]  Хотелось бы чуточку помягче, но в целом мне эта машина нравится по работе своей ходовой части.
# [13:08.560 --> 13:15.240]  Интересный нюанс. Дело в том, что для активации ограничителя скорости нужно долго подержать
# [13:15.240 --> 13:21.160]  клавишу включения круиза, и тогда вместо круиза появится ограничитель скорости. Непонятно,
# [13:21.160 --> 13:27.840]  почему корейцы умолчали об этой штуке, но вот такой лайфхак, пасхальное яйцо, если угодно,
# [13:27.840 --> 13:34.040]  можно эту функцию найти. Может быть здесь что-то еще спрятано, просто нашелся пока только
# [13:34.080 --> 13:40.280]  ограничитель скорости. Прием заказов на Kia Cerato и продажи уже стартовали. Если интересно,
# [13:40.280 --> 13:45.320]  отправляйтесь к дилеру на тест-драйв, на просмотр. У меня же на этом все. Друзья, оставайтесь с
# [13:45.320 --> 13:50.520]  нами, не забывайте подписываться на наш YouTube канал, ставить лайки, смотрите наши тесты,
# [13:50.520 --> 13:56.680]  премьеры и презентации. Счастливо и будьте здоровы! Читайте в сентябрьском выпуске журнала
# [13:56.680 --> 14:02.640]  «За рулем». Разрядился аккумулятор, а помочь некому? Все равно заведем. Hyundai Tucson,
# [14:02.640 --> 14:10.080]  Toyota RAV4 и Nissan X-Trail. Корея против Японии. Зимние шипованные шины, выбираем надежные и выгодные.
# [14:10.080 --> 14:20.560]  Передний привод за 1.6 млн. Gileon, Coolray или Arkana. Вторые руки, Audi Q5. Новый Kia Seltos или
# [14:20.560 --> 14:25.680]  трехлетний Hyundai Santa Fe за те же деньги. Самые дешевые кроссоверы на вторичке.
# [14:25.800 --> 14:34.880]  Выбираем БУ, Lada Priora. Советские довоенные концепт-кары, таких вы не видели. Это и многое
# [14:34.880 --> 14:38.200]  другое читайте в сентябрьском выпуске журнала «За рулем».
#
# Транскрибирование файла Новая Kia Cerato： стало круто？ ⧸ Киа Церато 2021 тест и обзор.m4a завершено.
# Транскрибирование файла: Kia. Двигайся. Вдохновляйся.m4a...
# [00:00.000 --> 00:13.200]  Что заставляет нас двигаться вперёд? Поиск чего-то нового или возможности,
# [00:13.200 --> 00:21.360]  которые ждут где-то далеко? Только в движении понимаешь, что главное — это не цель,
# [00:21.360 --> 00:35.440]  а вдохновение, которое находишь на пути к ней. Оно покажет, что действительно важно.
# [00:40.640 --> 00:46.120]  Откроет новые впечатления и неизведанные чувства.
# [00:46.120 --> 00:55.040]  Иногда для этого нужно пройти путь в сотни и тысячи километров.
# [00:59.240 --> 01:02.760]  А иногда достаточно сделать лишь шаг.
# [01:07.400 --> 01:14.800]  Вдохновение укажет, куда двигаться дальше. Чтобы ты смог создать что-то новое,
# [01:16.120 --> 01:20.320]  и вдохновить остальных.
#
# Транскрибирование файла Kia. Двигайся. Вдохновляйся.m4a завершено.

# %%
# !ls -ahl /content/audios
# Out:
# total 44M
# drwxr-xr-x 2 root root 4.0K Sep  8 15:13  .
# drwxr-xr-x 1 root root 4.0K Sep  8 15:13  ..
# -rw-r--r-- 1 root root 2.2M Oct 25  2021 'Kia. Двигайся. Вдохновляйся.m4a'
# -rw-r--r-- 1 root root  16M Sep 20  2021 'Новая Kia Cerato： стало круто？ ⧸ Киа Церато 2021 тест и обзор.m4a'
# -rw-r--r-- 1 root root  26M Sep 16  2022 'Новый KIA Ceed ⧸ SW 2022： БЕЗ ПАЛКИ С БАЛКОЙ. Тест-Драйв.m4a'

# %%
# !ls -ahl /content/out
# Out:
# total 20K
# drwxr-xr-x 5 root root 4.0K Sep  8 15:32  .
# drwxr-xr-x 1 root root 4.0K Sep  8 15:13  ..
# drwxr-xr-x 2 root root 4.0K Sep  8 15:33 'Kia. Двигайся. Вдохновляйся'
# drwxr-xr-x 2 root root 4.0K Sep  8 15:31 'Новая Kia Cerato： стало круто？ ⧸ Киа Церато 2021 тест и обзор'
# drwxr-xr-x 2 root root 4.0K Sep  8 15:23 'Новый KIA Ceed ⧸ SW 2022： БЕЗ ПАЛКИ С БАЛКОЙ. Тест-Драйв'
