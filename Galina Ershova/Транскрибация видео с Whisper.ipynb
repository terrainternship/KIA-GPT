# %% [markdown]
# ## **🔰 Упрощенный код для Whisper [ver.2 Google Colab] 08-09-2023**

# %%
# !ls -ahl
# Out:
# total 16K
# drwxr-xr-x 1 root root 4.0K Sep 11 13:22 .
# drwxr-xr-x 1 root root 4.0K Sep 12 17:09 ..
# drwxr-xr-x 4 root root 4.0K Sep 11 13:21 .config
# drwxr-xr-x 1 root root 4.0K Sep 11 13:22 sample_data

# %%
#@markdown Проврека выделенной видео-карты (нужна T4 или выше)
# !nvidia-smi
# !nvidia-smi --query-gpu=name --format=csv,noheader,nounits
# Out:
# Tue Sep 12 17:09:51 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Tesla T4

# %%
# Установка yt-dlp
# !pip install -q yt-dlp
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 17.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 32.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 17.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 48.7 MB/s eta 0:00:00

# %%
# Функция очистки ссылок
import re

def clean_youtube_url(url: str) -> str:
    """
    Преобразует любую ссылку на видео YouTube в формат короткой ссылки (https://youtu.be/ID_ВИДЕО).

    Параметры:
        url (str): Исходная ссылка на видео на YouTube.

    Возвращает:
        str: Короткая ссылка на видео или None, если исходная ссылка не соответствует формату YouTube.

    Пример:
        >>> clean_youtube_url("https://www.youtube.com/watch?v=dQw4w9WgXcQ")
        "https://youtu.be/dQw4w9WgXcQ"
    """

    # Регулярное выражение для поиска идентификаторов видео YouTube:
    # 1. (?:https?:\/\/)? - необязательный протокол (http или https).
    # 2. (?:www\.)? - необязательный префикс "www".
    # 3. (?:youtube\.com\/(?:watch\?v=|embed\/)|youtu\.be\/) - паттерн для длинных (стандартных и embed) и коротких ссылок YouTube.
    # 4. ([a-zA-Z0-9_-]{11}) - идентификатор видео, состоящий из 11 символов.
    pattern = r"(?:https?:\/\/)?(?:www\.)?(?:youtube\.com\/(?:watch\?v=|embed\/)|youtu\.be\/)([a-zA-Z0-9_-]{11})"

    # Поиск совпадения с помощью регулярного выражения
    match = re.search(pattern, url)
    if match:
        # Если найдено совпадение, извлекаем идентификатор видео
        video_id = match.group(1)
        return f"https://youtu.be/{video_id}"
    else:
        return None

# %%
# Список ссылок для загрузки

urls_list = [

"https://youtu.be/YYSED9790dE?si=lx6rHxDT-Fz5O2rW",
"https://youtu.be/W9kGG0-xpx4?si=bYDsbGmeZ8q7DXjx",
"https://youtu.be/RW7aZQqN2as?si=grqmAH38yaqAvShh",
"https://youtu.be/BNMuN8Hvdx4?si=LibOi-HbL3sI-b6A",
"https://youtu.be/jTX-C5ymcwM?si=19qZsCY7bzvjzfsz",
"https://youtu.be/_VbRAQRFkO0?si=Ptbg5zs0IpEX2Scw"

]

# %%
# Создаем список "очищенных" коротких ссылок на видео YouTube.
# Все недопустимые или неподходящие ссылки будут проигнорированы.
cleaned_urls = set(filter(None, map(clean_youtube_url, urls_list)))

# Выводим результат
print(cleaned_urls)
# Out:
# {'https://youtu.be/BNMuN8Hvdx4', 'https://youtu.be/W9kGG0-xpx4', 'https://youtu.be/jTX-C5ymcwM', 'https://youtu.be/YYSED9790dE', 'https://youtu.be/RW7aZQqN2as', 'https://youtu.be/_VbRAQRFkO0'}

# %%
# Функция загрузки видео в формате m4a (аудиофайл) с YouTube в директоррию /content/videos/
import subprocess

def download_video(url: str) -> None:
    """
    Загружает видео с YouTube в формате m4a (аудиофайл) и сохраняет в директории /content/audios/.

    Параметры:
        url (str): Ссылка на видео на YouTube.

    Пример:
        >>> download_video("https://www.youtube.com/watch?v=dQw4w9WgXcQ")
        ...
    """

    # Команда для yt-dlp, которая:
    # 1. Использует опцию "-x" для извлечения аудио.
    # 2. Устанавливает формат аудио в "m4a".
    # 3. Определяет путь для сохранения файла.
    cmd = [
        "yt-dlp",
        "-x",
        "--audio-format", "m4a",
        "-o", "/content/audios/%(title)s.%(ext)s",
        url
    ]

    try:
        # Инициализация подпроцесса с заданной командой.
        # stdout=subprocess.PIPE позволяет читать вывод в реальном времени.
        process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)

        # Чтение вывода команды в реальном времени и его вывод на экран.
        for line in process.stdout:
            print(line.strip())

        # Ожидание завершения подпроцесса и получение кода завершения.
        return_code = process.wait()

        # Если процесс завершился с ошибкой (не нулевой код завершения), генерируем исключение.
        if return_code != 0:
            raise subprocess.CalledProcessError(return_code, cmd)

    # Обработка исключений при выполнении команды.
    except subprocess.CalledProcessError as e:
        print(f"Ошибка при обработке ссылки {url}:")
        print(str(e))

# %%
# Перебор каждой очищенной ссылки из списка cleaned_urls.
# Для каждой ссылки будет вызвана функция download_video,
# которая загрузит видео в формате m4a и сохранит его в директории /content/audios/.
for url in cleaned_urls:
    download_video(url)
# Out:
# [youtube] Extracting URL: https://youtu.be/BNMuN8Hvdx4
# [youtube] BNMuN8Hvdx4: Downloading webpage
# [youtube] BNMuN8Hvdx4: Downloading ios player API JSON
# [youtube] BNMuN8Hvdx4: Downloading android player API JSON
# [youtube] BNMuN8Hvdx4: Downloading m3u8 information
# [info] BNMuN8Hvdx4: Downloading 1 format(s): 251
# [download] Destination: /content/audios/Новый Kia Sorento ｜ Замена щеток стеклоочистителей.webm
#
# [download]   0.1% of    1.57MiB at  263.31KiB/s ETA 00:06
# [download]   0.2% of    1.57MiB at  679.17KiB/s ETA 00:02
# [download]   0.4% of    1.57MiB at    1.40MiB/s ETA 00:01
# [download]   0.9% of    1.57MiB at    2.69MiB/s ETA 00:00
# [download]   1.9% of    1.57MiB at    1.23MiB/s ETA 00:01
# [download]   3.9% of    1.57MiB at    1.71MiB/s ETA 00:00
# [download]   7.9% of    1.57MiB at    2.15MiB/s ETA 00:00
# [download]  15.8% of    1.57MiB at    2.98MiB/s ETA 00:00
# [download]  31.8% of    1.57MiB at    4.59MiB/s ETA 00:00
# [download]  63.6% of    1.57MiB at    7.44MiB/s ETA 00:00
# [download] 100.0% of    1.57MiB at   10.38MiB/s ETA 00:00
# [download] 100% of    1.57MiB in 00:00:00 at 3.50MiB/s
# [ExtractAudio] Destination: /content/audios/Новый Kia Sorento ｜ Замена щеток стеклоочистителей.m4a
# Deleting original file /content/audios/Новый Kia Sorento ｜ Замена щеток стеклоочистителей.webm (pass -k to keep)
# [youtube] Extracting URL: https://youtu.be/W9kGG0-xpx4
# [youtube] W9kGG0-xpx4: Downloading webpage
# [youtube] W9kGG0-xpx4: Downloading ios player API JSON
# [youtube] W9kGG0-xpx4: Downloading android player API JSON
# [youtube] W9kGG0-xpx4: Downloading m3u8 information
# [info] W9kGG0-xpx4: Downloading 1 format(s): 251
# [download] Destination: /content/audios/Новый Kia Sorento ｜ Возможности трансформации салона.webm
#
# [download]   0.1% of    1.63MiB at  215.60KiB/s ETA 00:07
# [download]   0.2% of    1.63MiB at  502.07KiB/s ETA 00:03
# [download]   0.4% of    1.63MiB at  993.17KiB/s ETA 00:01
# [download]   0.9% of    1.63MiB at    1.80MiB/s ETA 00:00
# [download]   1.9% of    1.63MiB at    1.29MiB/s ETA 00:01
# [download]   3.8% of    1.63MiB at    1.76MiB/s ETA 00:00
# [download]   7.6% of    1.63MiB at    2.12MiB/s ETA 00:00
# [download]  15.3% of    1.63MiB at    3.01MiB/s ETA 00:00
# [download]  30.6% of    1.63MiB at    4.63MiB/s ETA 00:00
# [download]  61.3% of    1.63MiB at    7.55MiB/s ETA 00:00
# [download] 100.0% of    1.63MiB at   10.80MiB/s ETA 00:00
# [download] 100% of    1.63MiB in 00:00:00 at 2.70MiB/s
# [ExtractAudio] Destination: /content/audios/Новый Kia Sorento ｜ Возможности трансформации салона.m4a
# Deleting original file /content/audios/Новый Kia Sorento ｜ Возможности трансформации салона.webm (pass -k to keep)
# [youtube] Extracting URL: https://youtu.be/jTX-C5ymcwM
# [youtube] jTX-C5ymcwM: Downloading webpage
# [youtube] jTX-C5ymcwM: Downloading ios player API JSON
# [youtube] jTX-C5ymcwM: Downloading android player API JSON
# [youtube] jTX-C5ymcwM: Downloading m3u8 information
# [info] jTX-C5ymcwM: Downloading 1 format(s): 251
# [download] Destination: /content/audios/Новый Kia Sorento ｜ Автоматическая система полного привода.webm
#
# [download]   0.1% of    1.18MiB at  130.71KiB/s ETA 00:09
# [download]   0.2% of    1.18MiB at  334.68KiB/s ETA 00:03
# [download]   0.6% of    1.18MiB at  702.36KiB/s ETA 00:01
# [download]   1.2% of    1.18MiB at    1.34MiB/s ETA 00:00
# [download]   2.6% of    1.18MiB at    1.05MiB/s ETA 00:01
# [download]   5.2% of    1.18MiB at    1.25MiB/s ETA 00:00
# [download]  10.5% of    1.18MiB at    1.68MiB/s ETA 00:00
# [download]  21.1% of    1.18MiB at    2.55MiB/s ETA 00:00
# [download]  42.3% of    1.18MiB at    4.04MiB/s ETA 00:00
# [download]  84.8% of    1.18MiB at    6.69MiB/s ETA 00:00
# [download] 100.0% of    1.18MiB at    7.60MiB/s ETA 00:00
# [download] 100% of    1.18MiB in 00:00:00 at 3.39MiB/s
# [ExtractAudio] Destination: /content/audios/Новый Kia Sorento ｜ Автоматическая система полного привода.m4a
# Deleting original file /content/audios/Новый Kia Sorento ｜ Автоматическая система полного привода.webm (pass -k to keep)
# [youtube] Extracting URL: https://youtu.be/YYSED9790dE
# [youtube] YYSED9790dE: Downloading webpage
# [youtube] YYSED9790dE: Downloading ios player API JSON
# [youtube] YYSED9790dE: Downloading android player API JSON
# [youtube] YYSED9790dE: Downloading player de91d1cf
# [youtube] YYSED9790dE: Downloading m3u8 information
# [info] YYSED9790dE: Downloading 1 format(s): 251
# [download] Destination: /content/audios/Новый Kia Sorento ｜ Датчики и радары.webm
#
# [download]   0.1% of    1.37MiB at  272.09KiB/s ETA 00:05
# [download]   0.2% of    1.37MiB at  678.51KiB/s ETA 00:02
# [download]   0.5% of    1.37MiB at    1.38MiB/s ETA 00:00
# [download]   1.1% of    1.37MiB at    2.67MiB/s ETA 00:00
# [download]   2.2% of    1.37MiB at    1.28MiB/s ETA 00:01
# [download]   4.5% of    1.37MiB at    1.74MiB/s ETA 00:00
# [download]   9.1% of    1.37MiB at    2.17MiB/s ETA 00:00
# [download]  18.2% of    1.37MiB at    3.02MiB/s ETA 00:00
# [download]  36.4% of    1.37MiB at    4.62MiB/s ETA 00:00
# [download]  73.0% of    1.37MiB at    7.52MiB/s ETA 00:00
# [download] 100.0% of    1.37MiB at    9.47MiB/s ETA 00:00
# [download] 100% of    1.37MiB in 00:00:00 at 2.32MiB/s
# [ExtractAudio] Destination: /content/audios/Новый Kia Sorento ｜ Датчики и радары.m4a
# Deleting original file /content/audios/Новый Kia Sorento ｜ Датчики и радары.webm (pass -k to keep)
# [youtube] Extracting URL: https://youtu.be/RW7aZQqN2as
# [youtube] RW7aZQqN2as: Downloading webpage
# [youtube] RW7aZQqN2as: Downloading ios player API JSON
# [youtube] RW7aZQqN2as: Downloading android player API JSON
# [youtube] RW7aZQqN2as: Downloading m3u8 information
# [info] RW7aZQqN2as: Downloading 1 format(s): 251
# [download] Destination: /content/audios/Новый Kia Sorento ｜ Система Terrain Mode.webm
#
# [download]   0.1% of    1.40MiB at  160.31KiB/s ETA 00:08
# [download]   0.2% of    1.40MiB at  431.51KiB/s ETA 00:03
# [download]   0.5% of    1.40MiB at  934.17KiB/s ETA 00:01
# [download]   1.0% of    1.40MiB at    1.83MiB/s ETA 00:00
# [download]   2.2% of    1.40MiB at    1.06MiB/s ETA 00:01
# [download]   4.4% of    1.40MiB at    1.25MiB/s ETA 00:01
# [download]   8.9% of    1.40MiB at    1.65MiB/s ETA 00:00
# [download]  17.8% of    1.40MiB at    2.49MiB/s ETA 00:00
# [download]  35.6% of    1.40MiB at    3.96MiB/s ETA 00:00
# [download]  71.3% of    1.40MiB at    5.66MiB/s ETA 00:00
# [download] 100.0% of    1.40MiB at    7.86MiB/s ETA 00:00
# [download] 100% of    1.40MiB in 00:00:00 at 2.46MiB/s
# [ExtractAudio] Destination: /content/audios/Новый Kia Sorento ｜ Система Terrain Mode.m4a
# Deleting original file /content/audios/Новый Kia Sorento ｜ Система Terrain Mode.webm (pass -k to keep)
# [youtube] Extracting URL: https://youtu.be/_VbRAQRFkO0
# [youtube] _VbRAQRFkO0: Downloading webpage
# [youtube] _VbRAQRFkO0: Downloading ios player API JSON
# [youtube] _VbRAQRFkO0: Downloading android player API JSON
# [youtube] _VbRAQRFkO0: Downloading m3u8 information
# [info] _VbRAQRFkO0: Downloading 1 format(s): 251
# [download] Destination: /content/audios/Новый Kia Sorento ｜ Дизайн и технологии.webm
#
# [download]   0.0% of    5.43MiB at  183.80KiB/s ETA 00:30
# [download]   0.1% of    5.43MiB at  494.24KiB/s ETA 00:11
# [download]   0.1% of    5.43MiB at    1.02MiB/s ETA 00:05
# [download]   0.3% of    5.43MiB at    2.00MiB/s ETA 00:02
# [download]   0.6% of    5.43MiB at    2.76MiB/s ETA 00:01
# [download]   1.1% of    5.43MiB at    1.82MiB/s ETA 00:02
# [download]   2.3% of    5.43MiB at    2.24MiB/s ETA 00:02
# [download]   4.6% of    5.43MiB at    3.11MiB/s ETA 00:01
# [download]   9.2% of    5.43MiB at    4.75MiB/s ETA 00:01
# [download]  18.4% of    5.43MiB at    7.67MiB/s ETA 00:00
# [download]  36.8% of    5.43MiB at   12.82MiB/s ETA 00:00
# [download]  73.7% of    5.43MiB at   12.88MiB/s ETA 00:00
# [download] 100.0% of    5.43MiB at   16.92MiB/s ETA 00:00
# [download] 100% of    5.43MiB in 00:00:00 at 10.26MiB/s
# [ExtractAudio] Destination: /content/audios/Новый Kia Sorento ｜ Дизайн и технологии.m4a
# Deleting original file /content/audios/Новый Kia Sorento ｜ Дизайн и технологии.webm (pass -k to keep)

# %%
# Установка whisper
# !pip install -q git+https://github.com/openai/whisper.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 13.7 MB/s eta 0:00:00
#   Building wheel for openai-whisper (pyproject.toml) ... done

# %%
import os
from typing import List

def _construct_whisper_command(input_path: str, output_dir: str) -> List[str]:
    """
    Формирование команды для программы whisper.

    Args:
    - input_path (str): Путь к исходному аудиофайлу.
    - output_dir (str): Путь к директории, где сохранить результаты транскрибации.

    Returns:
    - List[str]: Список аргументов для команды whisper.

    Команда whisper используется для автоматической транскрибации аудиозаписей.
    В данной функции мы формируем список аргументов для этой команды:
    1. `--model large-v2`: использование улучшенной большой модели (версии 2) для транскрибации.
    2. `--language ru`: указание языка речи на русском.
    3. `--device cuda`: использование графического процессора (GPU) для ускорения транскрибации.
    4. `--output_format txt`: формат вывода результатов транскрибации в текстовом файле.
    """
    return [
        'whisper',
        input_path,
        '--model', "large-v2",
        '--language', 'ru',
        '--device', 'cuda',
        '--output_format', 'all',
        '--output_dir', output_dir
    ]


def transcribe_audio_files(input_directory: str, output_directory: str) -> None:
    """
    Транскрибирование всех аудиофайлов из указанной директории с помощью whisper.

    Args:
    - input_directory (str): Директория с исходными аудиофайлами.
    - output_directory (str): Директория для сохранения результатов транскрибации.

    Для каждого файла из `input_directory` запускается процесс транскрибации.
    Результаты сохраняются в поддиректории `output_directory`, где каждая поддиректория соответствует одному аудиофайлу.
    """

    # Проверка наличия выходной директории и её создание при отсутствии
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # Формирование списка аудиофайлов с расширением .m4a
    files = [f for f in os.listdir(input_directory) if os.path.isfile(os.path.join(input_directory, f)) and f.endswith('.m4a')]

    # Для каждого аудиофайла:
    for file in files:
        input_path = os.path.join(input_directory, file)

        # Имя поддиректории формируется на основе имени файла без расширения
        subdir_name = os.path.splitext(file)[0]
        subdir_path = os.path.join(output_directory, subdir_name)

        # Информирование пользователя о текущем файле
        print(f"Транскрибирование файла: {file}...")

        # Формирование команды для whisper
        cmd = _construct_whisper_command(input_path, subdir_path)

        # Запуск процесса транскрибации и вывод результатов в реальном времени
        with subprocess.Popen(cmd, stdout=subprocess.PIPE, text=True) as process:
            for line in iter(process.stdout.readline, ''):
                print(line, end='')  # Вывод строки в реальном времени
            print(f"\nТранскрибирование файла {file} завершено.")

# %%
transcribe_audio_files('/content/audios', '/content/out')
# Out:
# Транскрибирование файла: Новый Kia Sorento ｜ Замена щеток стеклоочистителей.m4a...
# [00:00.000 --> 00:21.600]  Для того, чтобы дворники лобового стекла работали эффективно, Вам нужно следить за состоянием
# [00:21.600 --> 00:25.960]  щеток стеклоочистителя и периодически протирать их. Если щетки стеклоочистителя
# [00:26.300 --> 00:28.560]  начинают оставлять полосы или больше не очищают стекло
# [00:28.560 --> 00:33.540]  должным образом, их нужно будет заменить. При замене стеклоочистителей выключите двигатель.
# [00:33.540 --> 00:38.120]  Поднимите переключатель режимов стеклоочистителя в верхнее положение и удерживайте
# [00:38.120 --> 00:40.920]  его в течение двух секунд для перехода в сервисный режим.
# [00:40.920 --> 00:46.160]  Со стеклоочистителями в верхнем положении поднимите привод стеклоочистителя,
# [00:46.160 --> 00:50.820]  откройте кронштейн щетки стеклоочистителя и потяните ее вниз, чтобы отсоединить.
# [00:50.820 --> 01:02.700]  установите новую щетку в обратном порядке. При замене заднего стеклоочистителя используйте
# [01:02.700 --> 01:09.380]  тот же метод для переключения его в сервисный режим. Поднимите привод стеклоочистителя,
# [01:09.380 --> 01:13.780]  поднимите и потяните щетку, чтобы отсоединить ее, а затем замените ее новой.
# [01:13.780 --> 01:20.220]  После замены щеток стеклоочистителей включите двигатель и приведите в действие
# [01:20.220 --> 01:27.180]  дворники один раз, чтобы убедиться, что они работают правильно. Чисто и уверенно сделайте
# [01:27.180 --> 01:31.180]  процесс вождения более безопасным с новыми щетками стеклоочистителя.
#
# Транскрибирование файла Новый Kia Sorento ｜ Замена щеток стеклоочистителей.m4a завершено.
# Транскрибирование файла: Новый Kia Sorento ｜ Возможности трансформации салона.m4a...
# [00:00.000 --> 00:19.800]  Попрощайтесь с тесными, неудобными задними сидениями.
# [00:19.800 --> 00:23.040]  Второй и третий ряды нового Sorento обладают уникальным
# [00:23.040 --> 00:25.560]  простором и эргономичностью.
# [00:25.560 --> 00:28.160]  USB-зарядные устройства на спинках сидений первого
# [00:28.160 --> 00:31.620]  ряда и на центральной консоли дадут возможность пассажирам
# [00:31.620 --> 00:35.840]  зарядить свои гаджеты в любой момент.
# [00:35.840 --> 00:38.100]  Попасть на третий ряд стало проще благодаря кнопке
# [00:38.100 --> 00:41.000]  складывания сидений второго ряда и вспомогательной
# [00:41.000 --> 00:42.000]  ручки.
# [00:42.000 --> 00:46.720]  Третий ряд сидений оборудован креплениями для детских
# [00:46.720 --> 00:53.000]  кресел.
# [00:53.000 --> 00:56.240]  Потяните рычаг складывания спинки сидения, и оно моментально
# [00:56.240 --> 01:02.080]  сложится.
# [01:02.080 --> 01:04.980]  Потяните за ремни на спинках сидений третьего ряда, чтобы
# [01:04.980 --> 01:11.840]  разложить или сложить сидения.
# [01:11.840 --> 01:14.220]  Различные конфигурации салона идеально подойдут
# [01:14.220 --> 01:17.160]  как для семейного путешествия, так и для перевозки небольших
# [01:17.160 --> 01:18.160]  грузов.
# [01:18.160 --> 01:20.480]  Объем багажника при сложенном втором и третьем рядах
# [01:20.480 --> 01:22.440]  составляет 2100 литров.
# [01:22.440 --> 01:25.640]  Кнопки складывания сидений из багажника позволят легко
# [01:26.040 --> 01:28.160]  трансформировать салон при перевозке габаритных
# [01:28.160 --> 01:29.160]  грузов.
# [01:29.160 --> 01:32.680]  Наслаждайтесь новыми эргономичными креслами второго и третьего
# [01:32.680 --> 01:33.000]  ряда.
#
# Транскрибирование файла Новый Kia Sorento ｜ Возможности трансформации салона.m4a завершено.
# Транскрибирование файла: Новый Kia Sorento ｜ Датчики и радары.m4a...
# [00:00.000 --> 00:06.000]  Работа систем активной безопасности Вашего Соренто полностью зависит от датчиков и радаров.
# [00:06.000 --> 00:10.000]  Поэтому нужно поддерживать их чистоту и работоспособность.
# [00:10.000 --> 00:16.000]  Соренто оснащен множеством камер, датчиков и радаров, измеряющих расстояние до препятствий.
# [00:16.000 --> 00:22.000]  Если датчики покрыты снегом, грязью или плотным слоем другого вещества, их возможности могут быть ограничены.
# [00:22.000 --> 00:27.840]  Соренто оснащен множеством камер, датчиков и радаров, измеряющих расстояние до препятствий.
# [00:27.840 --> 00:42.440]  Если датчики покрыты снегом, грязью или плотным слоем другого вещества,
# [00:42.440 --> 00:44.680]  их возможности могут быть ограничены.
# [00:44.680 --> 00:53.560]  Для корректной работы датчики и радар должны быть чистыми.
# [00:53.560 --> 01:06.400]  Если после очистки система все еще не работает нормально, рекомендуется отвезти
# [01:06.400 --> 01:12.160]  автомобиль в ближайший сервисный центр для диагностики. Чистый автомобиль — это
# [01:12.160 --> 01:16.200]  безопасный автомобиль. Не забывайте держать свой Соренто в чистоте.
#
# Транскрибирование файла Новый Kia Sorento ｜ Датчики и радары.m4a завершено.
# Транскрибирование файла: Новый Kia Sorento ｜ Автоматическая система полного привода.m4a...
# [00:00.000 --> 00:18.560]  Грунтовая дорога, сильный дождь, гололёд и крутые
# [00:18.560 --> 00:22.260]  повороты — это не повод для беспокойства.
# [00:22.260 --> 00:24.500]  При движении в нормальных условиях автоматическая
# [00:24.500 --> 00:27.160]  система полного привода использует в основном передние
# [00:27.160 --> 00:28.160]  колеса.
# [00:28.160 --> 00:31.400]  Эти системы постоянно анализируют состояние дорожного покрытия
# [00:31.400 --> 00:32.400]  и сцепления.
# [00:32.400 --> 00:34.840]  Если они обнаруживают грунтовую дорогу, мокрое
# [00:34.840 --> 00:40.360]  дорожное полотно, гололёд, крутой поворот или крутой
# [00:40.360 --> 00:44.440]  склон, то мощность автоматически распределяется между колесами,
# [00:44.440 --> 00:46.940]  чтобы максимизировать сцепление с дорожным покрытием
# [00:46.940 --> 00:50.960]  и устойчивость автомобиля на дороге.
# [00:50.960 --> 00:53.240]  Если вы нажмете кнопку «МОД» на рулевом колесе
# [00:53.240 --> 00:55.960]  и выберете график отображения работы полного привода,
# [00:55.960 --> 00:58.220]  то вы можете проверить распределение крутящего
# [00:58.220 --> 01:00.600]  момента в режиме реального времени.
# [01:00.600 --> 01:03.480]  Регулируя распределение крутящего момента в соответствии
# [01:03.480 --> 01:06.600]  с дорожной ситуацией, система полного привода помогает
# [01:06.600 --> 01:09.760]  сделать процесс вождения более безопасным и комфортным.
#
# Транскрибирование файла Новый Kia Sorento ｜ Автоматическая система полного привода.m4a завершено.
# Транскрибирование файла: Новый Kia Sorento ｜ Система Terrain Mode.m4a...
# [00:00.000 --> 00:22.940]  Система выбора режимов движения Terrain Mode позволит
# [00:22.940 --> 00:29.040]  вам всегда держать ситуацию под контролем.
# [00:29.040 --> 00:32.320]  Система Terrain Mode адаптирует работу полного привода,
# [00:32.320 --> 00:35.000]  двигателя, трансмиссии и распределения тормозных
# [00:35.000 --> 00:44.240]  усилий для езды в различных дорожных условиях.
# [00:44.240 --> 00:46.840]  Нажмите на селектор Terrain Mode и выберите один из трех
# [00:46.840 --> 00:47.840]  режимов.
# [00:47.840 --> 00:56.440]  Режим Snow предотвращает проскальзывание колес
# [00:56.440 --> 01:01.280]  идеален для езды по заснеженным дорогам.
# [01:01.280 --> 01:04.520]  Режим Mud позволяет двигаться более уверенно по дорогам
# [01:04.520 --> 01:10.040]  с мокрым грунтовым покрытием.
# [01:10.040 --> 01:13.640]  Режим Sand поддерживает высокую отдачу крутящего момента,
# [01:13.640 --> 01:16.440]  чтобы снизить риск завязнуть в песке.
# [01:16.440 --> 01:19.480]  Также данный режим добавит уверенности при движении
# [01:19.480 --> 01:21.200]  по гравийным дорогам.
# [01:21.200 --> 01:24.440]  С системой выбора режимов движения Terrain Mode вы всегда
# [01:24.440 --> 01:27.360]  будете чувствовать себя уверенно на любом дорожном
# [01:27.360 --> 01:27.880]  покрытии.
#
# Транскрибирование файла Новый Kia Sorento ｜ Система Terrain Mode.m4a завершено.
# Транскрибирование файла: Новый Kia Sorento ｜ Дизайн и технологии.m4a...
# [00:00.000 --> 00:06.920]  Давайте с вами посмотрим на дизайн и основные элементы нового Sorento.
# [00:06.920 --> 00:12.200]  В первую очередь стоит отметить стильный и харизматичный облик автомобиля. В особенности
# [00:12.200 --> 00:17.040]  решетку радиатора и фары в виде тигриных глаз, которые делают автомобиль визуально
# [00:17.040 --> 00:20.840]  более широким и монументальным. Аэродинамические элементы бампера
# [00:20.840 --> 00:26.960]  придают автомобилю спортивности. Гармонично вписывающиеся в большие колесные арки 20-дюймовые
# [00:26.960 --> 00:32.240]  колеса. Стремительные линии кузова, наклон передней стойки и линии капота придают
# [00:32.240 --> 00:40.080]  автомобилю спортивный и динамичный облик. Боковые зеркала заднего вида помогают улучшить
# [00:40.080 --> 00:48.960]  обзорность. Стеклоочиститель скрыт за спойлером. Вертикально расположенные задние фонари
# [00:48.960 --> 00:53.800]  делают автомобиль визуально более широким и атлетичным. Харизматичная задняя часть
# [00:53.800 --> 00:58.560]  автомобиля привлекает взгляд геометрическими формами и обилием острых горизонтальных и
# [00:58.560 --> 01:03.480]  вертикальных структурных линий. Вы можете легко открыть или закрыть крышку багажника.
# [01:03.480 --> 01:10.880]  Отрегулировать высоту открывания дверцы багажника очень просто. Нажав кнопку и удерживая
# [01:10.880 --> 01:24.080]  ее в течение трех секунд, Вы сохраните настройку. Или же Вы можете воспользоваться меню
# [01:24.080 --> 01:29.080]  «Двери» в мультимедийной системе, чтобы настроить высоту и скорость открытия двери багажника.
# [01:29.080 --> 01:37.360]  Оказавшись внутри, Вы сразу же заметите прогрессивный дизайн и передовые технологии.
# [01:37.360 --> 01:43.800]  Цифровая приборная панель с множеством настроек и темоформления. Интуитивно
# [01:43.800 --> 01:54.480]  понятный интерфейс мультимедийной системы. Атмосферная подсветка Mood Lamp создает комфортную
# [01:54.480 --> 01:59.720]  утонченную атмосферу в салоне, позволяет выбрать один из множества цветов интерьерной подсветки.
# [01:59.840 --> 02:11.960]  Попробуйте настроить профиль водителя. Настройки мультимедия, настройки сидений,
# [02:11.960 --> 02:16.880]  подсветки, проекционного дисплея и наружных зеркал могут быть сохранены в профиле.
# [02:16.880 --> 02:23.560]  Вы можете выбрать один из режимов движения Drive Mode. Выбирайте между четырьмя режимами
# [02:23.560 --> 02:30.040]  Comfort, Eco, Sport, Smart. Режим Comfort для комфортного и мягкого стиля вождения.
# [02:30.040 --> 02:36.600]  Eco режим для более экономичного стиля вождения и снижения расхода. Спортивный режим идеально
# [02:36.600 --> 02:41.600]  подходит для динамичного вождения. И Smart режим, который адаптирует системы автомобиля
# [02:41.600 --> 02:49.000]  под Ваш стиль вождения. Система выбора режимов движения по различным покрытиям Terrain Mode
# [02:49.000 --> 02:53.960]  управляет полным приводом, двигателем, трансмиссией и распределением тормозных усилий.
# [02:53.960 --> 02:59.680]  Помогает улучшить проходимость по снегу, грязи и песку. Система Terrain Mode управляет работой
# [02:59.680 --> 03:04.400]  двигателя, трансмиссии, полного привода и тормозной системы, чтобы обеспечить максимальную
# [03:04.400 --> 03:08.480]  проходимость и устойчивость автомобиля в различных дорожных условиях. Электронный
# [03:08.480 --> 03:13.960]  селектор коробки передач позволяет легким движением руки переключать режимы работы трансмиссии.
# [03:20.000 --> 03:32.600]  Новый Kia Sorento оснащен камерами, радаром, передними и задними датчиками парковки и
# [03:32.600 --> 03:37.560]  другими передовыми технологиями, которые помогут Вам безопасно управлять автомобилем.
# [03:37.560 --> 03:48.640]  Sorento обладает просторным салоном с множеством опций. Вы сразу заметите
# [03:48.760 --> 03:54.640]  щедрое пространство для ног и роскошную обивку сидений из кожи Nappa, USB-порты в спинке сидения
# [03:54.640 --> 04:03.000]  для удобной зарядки телефона со второго ряда. Для хранения личных вещей предусмотрено
# [04:03.000 --> 04:11.040]  множество мест. Нажмите кнопку на нижней или верхней части сидения второго ряда,
# [04:11.040 --> 04:15.960]  и сидение автоматически сдвинется вперед для легкого доступа к третьему ряду.
# [04:16.080 --> 04:23.760]  Вспомогательная ручка делает доступ к третьему ряду еще более комфортным.
# [04:23.760 --> 04:31.760]  На третьем ряду сидений предусмотрено крепление детских кресел. Кнопка складывания сидений из
# [04:31.760 --> 04:37.480]  багажника позволит одним движением подготовить салон автомобиля для перевозки крупногабаритных вещей.
# [04:45.960 --> 04:54.080]  Теперь Вы можете комфортно и безопасно отправиться в путешествие на своем новом Sorento.
#
# Транскрибирование файла Новый Kia Sorento ｜ Дизайн и технологии.m4a завершено.

# %%
# !ls -ahl /content/audios
# Out:
# total 17M
# drwxr-xr-x 3 root root 4.0K Sep 12 18:08  .
# drwxr-xr-x 1 root root 4.0K Sep 12 18:06  ..
# drwxr-xr-x 2 root root 4.0K Sep 12 18:07  .ipynb_checkpoints
# -rw-r--r-- 1 root root 1.6M Oct 28  2020 'Новый Kia Sorento ｜ Автоматическая система полного привода.m4a'
# -rw-r--r-- 1 root root 2.3M Oct 28  2020 'Новый Kia Sorento ｜ Возможности трансформации салона.m4a'
# -rw-r--r-- 1 root root 1.8M Oct 28  2020 'Новый Kia Sorento ｜ Датчики и радары.m4a'
# -rw-r--r-- 1 root root 6.8M Oct 27  2020 'Новый Kia Sorento ｜ Дизайн и технологии.m4a'
# -rw-r--r-- 1 root root 2.1M Oct 28  2020 'Новый Kia Sorento ｜ Замена щеток стеклоочистителей.m4a'
# -rw-r--r-- 1 root root 2.0M Oct 28  2020 'Новый Kia Sorento ｜ Система Terrain Mode.m4a'

# %%
# !ls -ahl /content/out
# Out:
# total 96K
# drwxr-xr-x 24 root root 4.0K Sep 12 18:22  .
# drwxr-xr-x  1 root root 4.0K Sep 12 18:06  ..
# drwxr-xr-x  2 root root 4.0K Sep 12 18:22  .ipynb_checkpoints
# drwxr-xr-x  2 root root 4.0K Sep 12 17:30 'Kia K5 ｜ Ассистент движения в полосе'
# drwxr-xr-x  2 root root 4.0K Sep 12 17:34 'Kia K5 ｜ Безопасная парковка'
# drwxr-xr-x  2 root root 4.0K Sep 12 17:45 'Kia K5 ｜ Замена батарейки в Smart Key'
# drwxr-xr-x  2 root root 4.0K Sep 12 17:40 'Kia K5 ｜ Замена салонного фильтра'
# drwxr-xr-x  2 root root 4.0K Sep 12 17:43 'Kia K5 ｜ Интеллектуальный круиз-контроль'
# drwxr-xr-x  2 root root 4.0K Sep 12 17:29 'Kia K5 ｜ Камеры для контроля слепых зон с отображением на панель приборов'
# drwxr-xr-x  2 root root 4.0K Sep 12 17:46 'Kia K5 ｜ Камеры кругового обзора'
# drwxr-xr-x  2 root root 4.0K Sep 12 17:21 'Kia K5 ｜ Монитор кругового обзора'
# drwxr-xr-x  2 root root 4.0K Sep 12 17:31 'Kia K5 ｜ Система безопасного выхода'
# drwxr-xr-x  2 root root 4.0K Sep 12 17:19 'Kia K5 ｜ Система контроля внимания водителя'
# drwxr-xr-x  2 root root 4.0K Sep 12 17:38 'Kia K5 ｜ Система предотвращения выезда из полосы движения'
# drwxr-xr-x  2 root root 4.0K Sep 12 17:24 'Kia K5 ｜ Система предотвращения столкновения при выезде с парковки задним ходом'
# drwxr-xr-x  2 root root 4.0K Sep 12 17:26 'Kia K5 ｜ Система предотвращения фронтальных столкновений'
# drwxr-xr-x  2 root root 4.0K Sep 12 17:41 'Kia K5 ｜ Системы защиты детей'
# drwxr-xr-x  2 root root 4.0K Sep 12 17:36 'Краш-тесты Kia K5 ｜ K5 safety test'
# drwxr-xr-x  2 root root 4.0K Sep 12 18:17 'Новый Kia Sorento ｜ Автоматическая система полного привода'
# drwxr-xr-x  2 root root 4.0K Sep 12 18:13 'Новый Kia Sorento ｜ Возможности трансформации салона'
# drwxr-xr-x  2 root root 4.0K Sep 12 18:15 'Новый Kia Sorento ｜ Датчики и радары'
# drwxr-xr-x  2 root root 4.0K Sep 12 18:21 'Новый Kia Sorento ｜ Дизайн и технологии'
# drwxr-xr-x  2 root root 4.0K Sep 12 18:11 'Новый Kia Sorento ｜ Замена щеток стеклоочистителей'
# drwxr-xr-x  2 root root 4.0K Sep 12 18:18 'Новый Kia Sorento ｜ Система Terrain Mode'

# %%
# !zip -r /content/out.zip /content/out
# Out:
# updating: content/out/ (stored 0%)
# updating: content/out/Kia K5 ｜ Камеры кругового обзора/ (stored 0%)
# updating: content/out/Kia K5 ｜ Камеры кругового обзора/Kia K5 ｜ Камеры кругового обзора.vtt (deflated 58%)
# updating: content/out/Kia K5 ｜ Камеры кругового обзора/Kia K5 ｜ Камеры кругового обзора.json (deflated 85%)
# updating: content/out/Kia K5 ｜ Камеры кругового обзора/Kia K5 ｜ Камеры кругового обзора.txt (deflated 58%)
# updating: content/out/Kia K5 ｜ Камеры кругового обзора/Kia K5 ｜ Камеры кругового обзора.tsv (deflated 55%)
# updating: content/out/Kia K5 ｜ Камеры кругового обзора/Kia K5 ｜ Камеры кругового обзора.srt (deflated 60%)
# updating: content/out/Kia K5 ｜ Ассистент движения в полосе/ (stored 0%)
# updating: content/out/Kia K5 ｜ Ассистент движения в полосе/Kia K5 ｜ Ассистент движения в полосе.vtt (deflated 60%)
# updating: content/out/Kia K5 ｜ Ассистент движения в полосе/Kia K5 ｜ Ассистент движения в полосе.srt (deflated 62%)
# updating: content/out/Kia K5 ｜ Ассистент движения в полосе/Kia K5 ｜ Ассистент движения в полосе.tsv (deflated 57%)
# updating: content/out/Kia K5 ｜ Ассистент движения в полосе/Kia K5 ｜ Ассистент движения в полосе.txt (deflated 61%)
# updating: content/out/Kia K5 ｜ Ассистент движения в полосе/Kia K5 ｜ Ассистент движения в полосе.json (deflated 85%)
# updating: content/out/Kia K5 ｜ Система предотвращения столкновения при выезде с парковки задним ходом/ (stored 0%)
# updating: content/out/Kia K5 ｜ Система предотвращения столкновения при выезде с парковки задним ходом/Kia K5 ｜ Система предотвращения столкновения при выезде с парковки задним ходом.tsv (deflated 60%)
# updating: content/out/Kia K5 ｜ Система предотвращения столкновения при выезде с парковки задним ходом/Kia K5 ｜ Система предотвращения столкновения при выезде с парковки задним ходом.txt (deflated 64%)
# updating: content/out/Kia K5 ｜ Система предотвращения столкновения при выезде с парковки задним ходом/Kia K5 ｜ Система предотвращения столкновения при выезде с парковки задним ходом.srt (deflated 63%)
# updating: content/out/Kia K5 ｜ Система предотвращения столкновения при выезде с парковки задним ходом/Kia K5 ｜ Система предотвращения столкновения при выезде с парковки задним ходом.vtt (deflated 61%)
# updating: content/out/Kia K5 ｜ Система предотвращения столкновения при выезде с парковки задним ходом/Kia K5 ｜ Система предотвращения столкновения при выезде с парковки задним ходом.json (deflated 85%)
# updating: content/out/Kia K5 ｜ Система безопасного выхода/ (stored 0%)
# updating: content/out/Kia K5 ｜ Система безопасного выхода/Kia K5 ｜ Система безопасного выхода.tsv (deflated 56%)
# updating: content/out/Kia K5 ｜ Система безопасного выхода/Kia K5 ｜ Система безопасного выхода.vtt (deflated 57%)
# updating: content/out/Kia K5 ｜ Система безопасного выхода/Kia K5 ｜ Система безопасного выхода.srt (deflated 58%)
# updating: content/out/Kia K5 ｜ Система безопасного выхода/Kia K5 ｜ Система безопасного выхода.json (deflated 84%)
# updating: content/out/Kia K5 ｜ Система безопасного выхода/Kia K5 ｜ Система безопасного выхода.txt (deflated 58%)
# updating: content/out/Kia K5 ｜ Интеллектуальный круиз-контроль/ (stored 0%)
# updating: content/out/Kia K5 ｜ Интеллектуальный круиз-контроль/Kia K5 ｜ Интеллектуальный круиз-контроль.srt (deflated 65%)
# updating: content/out/Kia K5 ｜ Интеллектуальный круиз-контроль/Kia K5 ｜ Интеллектуальный круиз-контроль.txt (deflated 64%)
# updating: content/out/Kia K5 ｜ Интеллектуальный круиз-контроль/Kia K5 ｜ Интеллектуальный круиз-контроль.json (deflated 86%)
# updating: content/out/Kia K5 ｜ Интеллектуальный круиз-контроль/Kia K5 ｜ Интеллектуальный круиз-контроль.vtt (deflated 64%)
# updating: content/out/Kia K5 ｜ Интеллектуальный круиз-контроль/Kia K5 ｜ Интеллектуальный круиз-контроль.tsv (deflated 62%)
# updating: content/out/Kia K5 ｜ Безопасная парковка/ (stored 0%)
# updating: content/out/Kia K5 ｜ Безопасная парковка/Kia K5 ｜ Безопасная парковка.srt (deflated 63%)
# updating: content/out/Kia K5 ｜ Безопасная парковка/Kia K5 ｜ Безопасная парковка.json (deflated 86%)
# updating: content/out/Kia K5 ｜ Безопасная парковка/Kia K5 ｜ Безопасная парковка.vtt (deflated 61%)
# updating: content/out/Kia K5 ｜ Безопасная парковка/Kia K5 ｜ Безопасная парковка.tsv (deflated 59%)
# updating: content/out/Kia K5 ｜ Безопасная парковка/Kia K5 ｜ Безопасная парковка.txt (deflated 61%)
# updating: content/out/Краш-тесты Kia K5 ｜ K5 safety test/ (stored 0%)
# updating: content/out/Краш-тесты Kia K5 ｜ K5 safety test/Краш-тесты Kia K5 ｜ K5 safety test.srt (deflated 66%)
# updating: content/out/Краш-тесты Kia K5 ｜ K5 safety test/Краш-тесты Kia K5 ｜ K5 safety test.vtt (deflated 65%)
# updating: content/out/Краш-тесты Kia K5 ｜ K5 safety test/Краш-тесты Kia K5 ｜ K5 safety test.tsv (deflated 64%)
# updating: content/out/Краш-тесты Kia K5 ｜ K5 safety test/Краш-тесты Kia K5 ｜ K5 safety test.txt (deflated 66%)
# updating: content/out/Краш-тесты Kia K5 ｜ K5 safety test/Краш-тесты Kia K5 ｜ K5 safety test.json (deflated 86%)
# updating: content/out/Kia K5 ｜ Замена батарейки в Smart Key/ (stored 0%)
# updating: content/out/Kia K5 ｜ Замена батарейки в Smart Key/Kia K5 ｜ Замена батарейки в Smart Key.srt (deflated 62%)
# updating: content/out/Kia K5 ｜ Замена батарейки в Smart Key/Kia K5 ｜ Замена батарейки в Smart Key.tsv (deflated 57%)
# updating: content/out/Kia K5 ｜ Замена батарейки в Smart Key/Kia K5 ｜ Замена батарейки в Smart Key.json (deflated 85%)
# updating: content/out/Kia K5 ｜ Замена батарейки в Smart Key/Kia K5 ｜ Замена батарейки в Smart Key.vtt (deflated 60%)
# updating: content/out/Kia K5 ｜ Замена батарейки в Smart Key/Kia K5 ｜ Замена батарейки в Smart Key.txt (deflated 60%)
# updating: content/out/Kia K5 ｜ Системы защиты детей/ (stored 0%)
# updating: content/out/Kia K5 ｜ Системы защиты детей/Kia K5 ｜ Системы защиты детей.txt (deflated 64%)
# updating: content/out/Kia K5 ｜ Системы защиты детей/Kia K5 ｜ Системы защиты детей.tsv (deflated 62%)
# updating: content/out/Kia K5 ｜ Системы защиты детей/Kia K5 ｜ Системы защиты детей.srt (deflated 63%)
# updating: content/out/Kia K5 ｜ Системы защиты детей/Kia K5 ｜ Системы защиты детей.vtt (deflated 63%)
# updating: content/out/Kia K5 ｜ Системы защиты детей/Kia K5 ｜ Системы защиты детей.json (deflated 85%)
# updating: content/out/Kia K5 ｜ Система предотвращения выезда из полосы движения/ (stored 0%)
# updating: content/out/Kia K5 ｜ Система предотвращения выезда из полосы движения/Kia K5 ｜ Система предотвращения выезда из полосы движения.srt (deflated 65%)
# updating: content/out/Kia K5 ｜ Система предотвращения выезда из полосы движения/Kia K5 ｜ Система предотвращения выезда из полосы движения.vtt (deflated 64%)
# updating: content/out/Kia K5 ｜ Система предотвращения выезда из полосы движения/Kia K5 ｜ Система предотвращения выезда из полосы движения.tsv (deflated 61%)
# updating: content/out/Kia K5 ｜ Система предотвращения выезда из полосы движения/Kia K5 ｜ Система предотвращения выезда из полосы движения.txt (deflated 64%)
# updating: content/out/Kia K5 ｜ Система предотвращения выезда из полосы движения/Kia K5 ｜ Система предотвращения выезда из полосы движения.json (deflated 87%)
# updating: content/out/Kia K5 ｜ Камеры для контроля слепых зон с отображением на панель приборов/ (stored 0%)
# updating: content/out/Kia K5 ｜ Камеры для контроля слепых зон с отображением на панель приборов/Kia K5 ｜ Камеры для контроля слепых зон с отображением на панель приборов.json (deflated 84%)
# updating: content/out/Kia K5 ｜ Камеры для контроля слепых зон с отображением на панель приборов/Kia K5 ｜ Камеры для контроля слепых зон с отображением на панель приборов.txt (deflated 58%)
# updating: content/out/Kia K5 ｜ Камеры для контроля слепых зон с отображением на панель приборов/Kia K5 ｜ Камеры для контроля слепых зон с отображением на панель приборов.tsv (deflated 54%)
# updating: content/out/Kia K5 ｜ Камеры для контроля слепых зон с отображением на панель приборов/Kia K5 ｜ Камеры для контроля слепых зон с отображением на панель приборов.srt (deflated 59%)
# updating: content/out/Kia K5 ｜ Камеры для контроля слепых зон с отображением на панель приборов/Kia K5 ｜ Камеры для контроля слепых зон с отображением на панель приборов.vtt (deflated 57%)
# updating: content/out/Kia K5 ｜ Монитор кругового обзора/ (stored 0%)
# updating: content/out/Kia K5 ｜ Монитор кругового обзора/Kia K5 ｜ Монитор кругового обзора.vtt (deflated 60%)
# updating: content/out/Kia K5 ｜ Монитор кругового обзора/Kia K5 ｜ Монитор кругового обзора.json (deflated 85%)
# updating: content/out/Kia K5 ｜ Монитор кругового обзора/Kia K5 ｜ Монитор кругового обзора.srt (deflated 62%)
# updating: content/out/Kia K5 ｜ Монитор кругового обзора/Kia K5 ｜ Монитор кругового обзора.tsv (deflated 60%)
# updating: content/out/Kia K5 ｜ Монитор кругового обзора/Kia K5 ｜ Монитор кругового обзора.txt (deflated 63%)
# updating: content/out/Kia K5 ｜ Замена салонного фильтра/ (stored 0%)
# updating: content/out/Kia K5 ｜ Замена салонного фильтра/Kia K5 ｜ Замена салонного фильтра.vtt (deflated 59%)
# updating: content/out/Kia K5 ｜ Замена салонного фильтра/Kia K5 ｜ Замена салонного фильтра.json (deflated 85%)
# updating: content/out/Kia K5 ｜ Замена салонного фильтра/Kia K5 ｜ Замена салонного фильтра.txt (deflated 60%)
# updating: content/out/Kia K5 ｜ Замена салонного фильтра/Kia K5 ｜ Замена салонного фильтра.srt (deflated 61%)
# updating: content/out/Kia K5 ｜ Замена салонного фильтра/Kia K5 ｜ Замена салонного фильтра.tsv (deflated 57%)
# updating: content/out/Kia K5 ｜ Система предотвращения фронтальных столкновений/ (stored 0%)
# updating: content/out/Kia K5 ｜ Система предотвращения фронтальных столкновений/Kia K5 ｜ Система предотвращения фронтальных столкновений.txt (deflated 65%)
# updating: content/out/Kia K5 ｜ Система предотвращения фронтальных столкновений/Kia K5 ｜ Система предотвращения фронтальных столкновений.vtt (deflated 63%)
# updating: content/out/Kia K5 ｜ Система предотвращения фронтальных столкновений/Kia K5 ｜ Система предотвращения фронтальных столкновений.tsv (deflated 62%)
# updating: content/out/Kia K5 ｜ Система предотвращения фронтальных столкновений/Kia K5 ｜ Система предотвращения фронтальных столкновений.json (deflated 86%)
# updating: content/out/Kia K5 ｜ Система предотвращения фронтальных столкновений/Kia K5 ｜ Система предотвращения фронтальных столкновений.srt (deflated 64%)
# updating: content/out/Kia K5 ｜ Система контроля внимания водителя/ (stored 0%)
# updating: content/out/Kia K5 ｜ Система контроля внимания водителя/Kia K5 ｜ Система контроля внимания водителя.tsv (deflated 60%)
# updating: content/out/Kia K5 ｜ Система контроля внимания водителя/Kia K5 ｜ Система контроля внимания водителя.json (deflated 85%)
# updating: content/out/Kia K5 ｜ Система контроля внимания водителя/Kia K5 ｜ Система контроля внимания водителя.srt (deflated 62%)
# updating: content/out/Kia K5 ｜ Система контроля внимания водителя/Kia K5 ｜ Система контроля внимания водителя.vtt (deflated 61%)
# updating: content/out/Kia K5 ｜ Система контроля внимания водителя/Kia K5 ｜ Система контроля внимания водителя.txt (deflated 63%)
#   adding: content/out/.ipynb_checkpoints/ (stored 0%)
#   adding: content/out/Новый Kia Sorento ｜ Автоматическая система полного привода/ (stored 0%)
#   adding: content/out/Новый Kia Sorento ｜ Автоматическая система полного привода/Новый Kia Sorento ｜ Автоматическая система полного привода.json (deflated 85%)
#   adding: content/out/Новый Kia Sorento ｜ Автоматическая система полного привода/Новый Kia Sorento ｜ Автоматическая система полного привода.tsv (deflated 57%)
#   adding: content/out/Новый Kia Sorento ｜ Автоматическая система полного привода/Новый Kia Sorento ｜ Автоматическая система полного привода.vtt (deflated 60%)
#   adding: content/out/Новый Kia Sorento ｜ Автоматическая система полного привода/Новый Kia Sorento ｜ Автоматическая система полного привода.txt (deflated 60%)
#   adding: content/out/Новый Kia Sorento ｜ Автоматическая система полного привода/Новый Kia Sorento ｜ Автоматическая система полного привода.srt (deflated 61%)
#   adding: content/out/Новый Kia Sorento ｜ Возможности трансформации салона/ (stored 0%)
#   adding: content/out/Новый Kia Sorento ｜ Возможности трансформации салона/Новый Kia Sorento ｜ Возможности трансформации салона.txt (deflated 61%)
#   adding: content/out/Новый Kia Sorento ｜ Возможности трансформации салона/Новый Kia Sorento ｜ Возможности трансформации салона.tsv (deflated 58%)
#   adding: content/out/Новый Kia Sorento ｜ Возможности трансформации салона/Новый Kia Sorento ｜ Возможности трансформации салона.json (deflated 85%)
#   adding: content/out/Новый Kia Sorento ｜ Возможности трансформации салона/Новый Kia Sorento ｜ Возможности трансформации салона.srt (deflated 62%)
#   adding: content/out/Новый Kia Sorento ｜ Возможности трансформации салона/Новый Kia Sorento ｜ Возможности трансформации салона.vtt (deflated 61%)
#   adding: content/out/Новый Kia Sorento ｜ Дизайн и технологии/ (stored 0%)
#   adding: content/out/Новый Kia Sorento ｜ Дизайн и технологии/Новый Kia Sorento ｜ Дизайн и технологии.srt (deflated 65%)
#   adding: content/out/Новый Kia Sorento ｜ Дизайн и технологии/Новый Kia Sorento ｜ Дизайн и технологии.tsv (deflated 63%)
#   adding: content/out/Новый Kia Sorento ｜ Дизайн и технологии/Новый Kia Sorento ｜ Дизайн и технологии.txt (deflated 65%)
#   adding: content/out/Новый Kia Sorento ｜ Дизайн и технологии/Новый Kia Sorento ｜ Дизайн и технологии.vtt (deflated 64%)
#   adding: content/out/Новый Kia Sorento ｜ Дизайн и технологии/Новый Kia Sorento ｜ Дизайн и технологии.json (deflated 85%)
#   adding: content/out/Новый Kia Sorento ｜ Замена щеток стеклоочистителей/ (stored 0%)
#   adding: content/out/Новый Kia Sorento ｜ Замена щеток стеклоочистителей/Новый Kia Sorento ｜ Замена щеток стеклоочистителей.srt (deflated 65%)
#   adding: content/out/Новый Kia Sorento ｜ Замена щеток стеклоочистителей/Новый Kia Sorento ｜ Замена щеток стеклоочистителей.vtt (deflated 64%)
#   adding: content/out/Новый Kia Sorento ｜ Замена щеток стеклоочистителей/Новый Kia Sorento ｜ Замена щеток стеклоочистителей.json (deflated 86%)
#   adding: content/out/Новый Kia Sorento ｜ Замена щеток стеклоочистителей/Новый Kia Sorento ｜ Замена щеток стеклоочистителей.txt (deflated 67%)
#   adding: content/out/Новый Kia Sorento ｜ Замена щеток стеклоочистителей/Новый Kia Sorento ｜ Замена щеток стеклоочистителей.tsv (deflated 64%)
#   adding: content/out/Новый Kia Sorento ｜ Датчики и радары/ (stored 0%)
#   adding: content/out/Новый Kia Sorento ｜ Датчики и радары/Новый Kia Sorento ｜ Датчики и радары.tsv (deflated 63%)
#   adding: content/out/Новый Kia Sorento ｜ Датчики и радары/Новый Kia Sorento ｜ Датчики и радары.json (deflated 86%)
#   adding: content/out/Новый Kia Sorento ｜ Датчики и радары/Новый Kia Sorento ｜ Датчики и радары.vtt (deflated 64%)
#   adding: content/out/Новый Kia Sorento ｜ Датчики и радары/Новый Kia Sorento ｜ Датчики и радары.srt (deflated 65%)
#   adding: content/out/Новый Kia Sorento ｜ Датчики и радары/Новый Kia Sorento ｜ Датчики и радары.txt (deflated 66%)
#   adding: content/out/Новый Kia Sorento ｜ Система Terrain Mode/ (stored 0%)
#   adding: content/out/Новый Kia Sorento ｜ Система Terrain Mode/Новый Kia Sorento ｜ Система Terrain Mode.vtt (deflated 57%)
#   adding: content/out/Новый Kia Sorento ｜ Система Terrain Mode/Новый Kia Sorento ｜ Система Terrain Mode.tsv (deflated 54%)
#   adding: content/out/Новый Kia Sorento ｜ Система Terrain Mode/Новый Kia Sorento ｜ Система Terrain Mode.json (deflated 84%)
#   adding: content/out/Новый Kia Sorento ｜ Система Terrain Mode/Новый Kia Sorento ｜ Система Terrain Mode.txt (deflated 56%)
#   adding: content/out/Новый Kia Sorento ｜ Система Terrain Mode/Новый Kia Sorento ｜ Система Terrain Mode.srt (deflated 59%)

# %%
from google.colab import files
files.download("/content/out.zip")

# %%
#import os

directory = '/content/out'
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    if os.path.isfile(f):
        print(f)

# %%
#создаем папку для вывода текстовый файлов с заголовками для БД
os.mkdir("/content/out_txt2")

# %%
#Пройдемся по всем файлам каталога out и найдем текстовые
#Преобразуем файл следующим образом
#1. Из названия файла сформируем его заголовок (заменив символ '|' на точку)
#2. Добавим заловок в начало, оформив в "#"
#3. Из содержимого файла уберу символы переноса строк (все равно оцифровывать)
directory = '/content/out'
directory_final = '/content/out_txt'

for root, dirs, files in os.walk(directory):
    for file in files:
        if file.endswith('.txt'):
             TextHeader = file.replace( " ｜ ", '. ')

             with open (os.path.join(root, file )  , 'r') as f:
                old_data = f.read()
             #print(old_data)
             #new_data = f"#{TextHeader}#\n {old_data}"
             #print(new_data)
             print(f"{directory_final}/{file}")
             with open (f"{directory_final}/{file}" , 'w') as f:
                f.write(f"#{file.replace( ' ｜ ', '. ')}#\n{old_data}" )
# Out:
# /content/out_txt/Kia K5 ｜ Камеры кругового обзора.txt
# /content/out_txt/Новый Kia Sorento ｜ Автоматическая система полного привода.txt
# /content/out_txt/Kia K5 ｜ Ассистент движения в полосе.txt
# /content/out_txt/Kia K5 ｜ Система предотвращения столкновения при выезде с парковки задним ходом.txt
# /content/out_txt/Kia K5 ｜ Система безопасного выхода.txt
# /content/out_txt/Kia K5 ｜ Интеллектуальный круиз-контроль.txt
# /content/out_txt/Новый Kia Sorento ｜ Возможности трансформации салона.txt
# /content/out_txt/Новый Kia Sorento ｜ Дизайн и технологии.txt
# /content/out_txt/Kia K5 ｜ Безопасная парковка.txt
# /content/out_txt/Краш-тесты Kia K5 ｜ K5 safety test.txt
# /content/out_txt/Kia K5 ｜ Замена батарейки в Smart Key.txt
# /content/out_txt/Новый Kia Sorento ｜ Замена щеток стеклоочистителей.txt
# /content/out_txt/Kia K5 ｜ Системы защиты детей.txt
# /content/out_txt/Kia K5 ｜ Система предотвращения выезда из полосы движения.txt
# /content/out_txt/Новый Kia Sorento ｜ Датчики и радары.txt
# /content/out_txt/Kia K5 ｜ Камеры для контроля слепых зон с отображением на панель приборов.txt
# /content/out_txt/Kia K5 ｜ Монитор кругового обзора.txt
# /content/out_txt/Новый Kia Sorento ｜ Система Terrain Mode.txt
# /content/out_txt/Kia K5 ｜ Замена салонного фильтра.txt
# /content/out_txt/Kia K5 ｜ Система предотвращения фронтальных столкновений.txt
# /content/out_txt/Kia K5 ｜ Система контроля внимания водителя.txt

# %%
# !zip -r /content/out_txt.zip /content/out_txt
# Out:
# updating: content/out_txt/ (stored 0%)
# updating: content/out_txt/Kia K5 ｜ Камеры для контроля слепых зон с отображением на панель приборов.txt (deflated 60%)
# updating: content/out_txt/Kia K5 ｜ Системы защиты детей.txt (deflated 63%)
# updating: content/out_txt/Kia K5 ｜ Система предотвращения фронтальных столкновений.txt (deflated 66%)
# updating: content/out_txt/Kia K5 ｜ Система предотвращения столкновения при выезде с парковки задним ходом.txt (deflated 65%)
# updating: content/out_txt/Kia K5 ｜ Камеры кругового обзора.txt (deflated 58%)
# updating: content/out_txt/Kia K5 ｜ Интеллектуальный круиз-контроль.txt (deflated 65%)
# updating: content/out_txt/Kia K5 ｜ Система предотвращения выезда из полосы движения.txt (deflated 64%)
# updating: content/out_txt/Kia K5 ｜ Замена салонного фильтра.txt (deflated 59%)
# updating: content/out_txt/Краш-тесты Kia K5 ｜ K5 safety test.txt (deflated 66%)
# updating: content/out_txt/Kia K5 ｜ Система безопасного выхода.txt (deflated 58%)
# updating: content/out_txt/Kia K5 ｜ Система контроля внимания водителя.txt (deflated 63%)
# updating: content/out_txt/Kia K5 ｜ Ассистент движения в полосе.txt (deflated 61%)
# updating: content/out_txt/Kia K5 ｜ Замена батарейки в Smart Key.txt (deflated 58%)
# updating: content/out_txt/Kia K5 ｜ Монитор кругового обзора.txt (deflated 63%)
# updating: content/out_txt/Kia K5 ｜ Безопасная парковка.txt (deflated 61%)
#   adding: content/out_txt/Новый Kia Sorento ｜ Настройка открытия крышки багажника.txt (deflated 63%)
#   adding: content/out_txt/Новый Kia Sorento ｜ Возможности трансформации салона.txt (deflated 60%)
#   adding: content/out_txt/Новый Kia Carnival ｜ Интеллектуальный доступ.txt (deflated 73%)
#   adding: content/out_txt/Новый Kia Sorento ｜ Дизайн и технологии.txt (deflated 65%)
#   adding: content/out_txt/Новый Kia Sorento ｜ Система Terrain Mode.txt (deflated 56%)
#   adding: content/out_txt/Новый Kia Sorento ｜ Автоматическая система полного привода.txt (deflated 59%)
#   adding: content/out_txt/Новый Kia Carnival ｜ 7-местная компоновка.txt (deflated 67%)
#   adding: content/out_txt/Новый Kia Carnival ｜ Обзор модели.txt (deflated 72%)
#   adding: content/out_txt/Новый Kia Carnival ｜ 8-местная компоновка.txt (deflated 72%)
#   adding: content/out_txt/Новый Kia Sorento ｜ Первая настройка автомобиля.txt (deflated 65%)
#   adding: content/out_txt/Новый Kia Sorento ｜ Замена щеток стеклоочистителей.txt (deflated 66%)
#   adding: content/out_txt/Новый Kia Sorento ｜ Датчики и радары.txt (deflated 64%)

# %%
from google.colab import files
files.download("/content/out_txt.zip")

# %%
#Собираем все файлы из директории в один
import fileinput, glob, os

# каталог текстовых файлов
path = '/content/out_txt'
# паттерн поиска файлов по расширению
pattern = '*.txt'

glob_path = os.path.join(path, pattern)
list_files = glob.glob(glob_path)
# расширение нового файла установим как '.all'
new_file = '/content/video_database.txt'

if list_files:
    # открываем список файлов 'list_files' на чтение
    # и новый общий файл 'new_file' на запись
    with fileinput.FileInput(files=list_files) as fr, open(new_file, 'w') as fw:
        # читаем данные построчно
        for line in fr:
            # определяем первую строку нового файла
            if fr.isfirstline():
                # название читаемого файла
                file_name = fr.filename()
                # дописываем строку с названием файла
                #fw.write(f'\n {file_name}\n')
                fw.write(f'\n')
            # если нужно, то здесь обрабатываем каждую строку 'line'
            # после обработки дописываем в общий файл
            #fw.write(line)
            fw.write(f"{line.replace( '.txt', '. ')}")
