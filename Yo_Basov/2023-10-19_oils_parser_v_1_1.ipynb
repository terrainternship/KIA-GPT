# %%
# ЧЕРНОВОЙ ВАРИАНТ ФОРМИРОВАНИЯ ДИАЛОГОВ для ИНКОРПОРИРОВАНИЯ из ТАБЛИЦ МАСЕЛ

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import datetime
import numpy as np
import openpyxl
import re
import requests
import threading, time
import json
import os

from bs4 import BeautifulSoup

# %%
def savetxt(dir, name, text):
  if not os.path.exists('result'): os.mkdir('result')
  if not os.path.exists('result/'+dir): os.mkdir('result/'+dir)
  with open('result/'+dir+'/'+name,'w',encoding='utf-8') as f:
    f.write(text)
  return True

def resulttotext(r):
  if r is not None:
    return r.text+'.'
  else:
    return ''

def parser(soup):
    text = ''
    pages = soup.findAll('div', class_='g-padding')
    if pages is None:
      print(soup.find('title').text.split(' – ')[0])
      print(soup)
    else:
      for page in pages:
        if page.find('div',class_='faq') is not None:
          text += page.find('div',class_='faq').text
        else:
          content = page.select('div[class*="text-"]')
          text += ''.join(i.text+'\n' for i in content)
    return text

# %%
# Pars page whith models

pagemodels = requests.get('https://www.kia.ru/models/').text
modellinks = []

html = ''.join(line.strip() for line in pagemodels.split("\n"))
soup = BeautifulSoup(html, "html.parser")

cards_list = soup.find_all('div', class_='car-card')

for card in cards_list:
  modellinks.append('https://www.kia.ru'+ str(card.a['href']))

# %%
def getmodelsoup(url):
  model = requests.get(url).text
  html = ''.join(line.strip() for line in model.split("\n"))
  return BeautifulSoup(html, "html.parser")

modeldict = {}

for i in modellinks:
  modeldict[i] = getmodelsoup(i)

# %%
def stringstolist(div):
  '''Превращаем блок в список строк'''
  lis = []
  try:
    for string in div.strings:
      if string not in [' ','']:
        lis.append(string.text)
  except:
    lis = ['']
  return lis


def parsermodel(soup):
  text = ''

  # Обрабатываю по id basic
  basic = soup.select('div[id*="basic_"]')
  for div in basic:
    # Перевожу строки в список, для удобного обращиния
    textlist = stringstolist(div)
    try:
      img = div.find('img')['data-src']
    except:
      img = ''
    text += f'## {textlist[0]}\n{". ".join(textlist[1:])}\nФото {img}\n\n'

  # Обрабатываю по id dizain
  dizain = soup.select('div[id*="dizain_"]')
  for div in dizain:
    if len(div['id'].split('_')) > 2: continue # Пропускаем внутренние блоки
    # Перевожу строки в список, для удобного обращиния
    textlist = stringstolist(div)[:-1]
    text += f'## {textlist[0]}\n{". ".join(textlist[1:3])}\n'
    for t in textlist[3:]:
      text += t+'. '
    text = text[:-2]+'\n\n'

  # Обрабатываю по id eksterer
  eksterer = soup.select('div[id*="eksterer_"]')
  for div in eksterer:
    if len(div['id'].split('_')) > 2: continue # Пропускаем внутренние блоки
    # Перевожу строки в список, для удобного обращиния
    textlist = stringstolist(div)[:-1]
    text += f'## {textlist[0]}\n{". ".join(textlist[1:3])}\n'
    for t in textlist[3:]:
      text += t+'. '
    text = text[:-2]+'\n\n'

  # Обрабатываю по id interer
  interer = soup.select('div[id*="interer_"]')
  for div in interer:
    if len(div['id'].split('_')) > 2: continue # Пропускаем внутренние блоки
    # Перевожу строки в список, для удобного обращиния
    textlist = stringstolist(div)[:-1]
    text += f'## {textlist[0]}\n{". ".join(textlist[1:3])}\n'
    for t in textlist[3:]:
      text += t+'. '
    text = text[:-2]+'\n\n'

  # Обрабатываю по id style
  style = soup.select('div[id*="style_"]')
  for div in style:
    if len(div['id'].split('_')) > 2: continue # Пропускаем внутренние блоки
    # Перевожу строки в список, для удобного обращиния
    textlist = stringstolist(div)[:-1]
    text += f'## {textlist[0]}\n{". ".join(textlist[1:3])}\n'
    for t in textlist[3:]:
      text += t+'. '
    text = text[:-2]+'\n\n'

  # Обрабатываю по id multimedia
  multimedia = soup.select('div[id*="multimedia_"]')
  for div in multimedia:
    if len(div['id'].split('_')) > 2: continue # Пропускаем внутренние блоки
    # Перевожу строки в список, для удобного обращиния
    textlist = stringstolist(div)[:-1]
    text += f'## {textlist[0]}\n{". ".join(textlist[1:3])}\n'
    for t in textlist[3:]:
      text += t+'. '
    text = text[:-2]+'\n\n'

  # Обрабатываю по id tehnologii
  tehnologii = soup.select('div[id*="tehnologii_"]')
  for div in tehnologii:
    if len(div['id'].split('_')) > 2: continue # Пропускаем внутренние блоки
    # Перевожу строки в список, для удобного обращиния
    textlist = stringstolist(div)[:-1]
    text += f'## {textlist[0]}\n{". ".join(textlist[1:3])}\n'
    for t in textlist[3:]:
      text += t+'. '
    text = text[:-2]+'\n\n'

  # Обрабатываю по id bezopasnost
  bezopasnost = soup.select('div[id*="bezopasnost_"]')
  for div in bezopasnost:
    if len(div['id'].split('_')) > 2: continue # Пропускаем внутренние блоки
    # Перевожу строки в список, для удобного обращиния
    textlist = stringstolist(div)[:-1]
    text += f'## {textlist[0]}\n{". ".join(textlist[1:3])}\n'
    for t in textlist[3:]:
      text += t+'. '
    text = text[:-2]+'\n\n'

  # Обрабатываю по id teplye_opcii
  teplye_opcii = soup.select('div[id*="teplye_opcii_"]')
  for div in teplye_opcii:
    if len(div['id'].split('_')) > 3: continue # Пропускаем внутренние блоки
    # Перевожу строки в список, для удобного обращиния
    textlist = stringstolist(div)[:-1]
    text += f'## {textlist[0]}\n{". ".join(textlist[1:3])}\n'
    for t in textlist[3:]:
      text += t+'. '
    text = text[:-2]+'\n\n'

  # Обрабатываю по id komfort
  komfort = soup.select('div[id*="komfort_"]')
  for div in komfort:
    if len(div['id'].split('_')) > 2: continue # Пропускаем внутренние блоки
    # Перевожу строки в список, для удобного обращиния
    textlist = stringstolist(div)[:-1]
    text += f'## {textlist[0]}\n{". ".join(textlist[1:3])}\n'
    for t in textlist[3:]:
      text += t+'. '
    text = text[:-2]+'\n\n'

  # Обрабатываю по id vmestimost
  vmestimost = soup.select('div[id*="vmestimost_"]')
  for div in vmestimost:
    if len(div['id'].split('_')) > 2: continue # Пропускаем внутренние блоки
    # Перевожу строки в список, для удобного обращиния
    textlist = stringstolist(div)[:-1]
    text += f'## {textlist[0]}\n{". ".join(textlist[1:3])}\n'
    for t in textlist[3:]:
      text += t+'. '
    text = text[:-2]+'\n\n'

  # Обрабатываю по id dvigatel
  dvigatel = soup.select('div[id*="dvigatel_"]')
  for div in dvigatel:
    if len(div['id'].split('_')) > 2: continue # Пропускаем внутренние блоки
    # Перевожу строки в список, для удобного обращиния
    textlist = stringstolist(div)[:-1]
    text += f'## {textlist[0]}\n{". ".join(textlist[1:3])}\n'
    text += 'Модели двигателей: '
    ul = div.find('ul')
    for t in stringstolist(ul):
      text += t+', '
    text = text[:-2]+'\n\n'

  return text

def parseroptions(url):
  text = '## Комплектации\n'
  links = []
  url = url.replace('desc','options')
  suop = getmodelsoup(url)
  ahrefs = suop.findAll('div',class_='config__variants__slide')
  for a in ahrefs:
    cont = a.find('li').text
    url = a.find('a')
    option = getmodelsoup('https://www.kia.ru'+url['href'])
    titel = option.find('title').text
    text += f'### Комплектация: {titel}\nЦена: {cont}\n'
    info = option.findAll('div', class_="info-section")

    for i in info:
      t2 = i.find('div', class_="info-section__header").text
      text += t2 + ': '
      if t2.strip() == 'Технические характеристики' or t2.strip() == 'Спецификация':
        dl = i.findAll('dl')
        for j in dl:
          text += j.find('dt').text + ': ' + j.find('dd').text + '; '
      else:
        li = i.findAll('li')
        for j in li:
          text += j.text + ', '
      text = text[:-2] + '\n'

  return text

def resultsmodel(link):

  print(link)
  name = modeldict[link].find('title').text.split(' – ')[0]
  name = name.replace('/','-')
  text = f'#  {name} - [link {link}]\n'
  text += parsermodel(modeldict[link])
  text += parseroptions(link)
  savetxt('models', name+'.txt', text)
  print('Done '+ name)


threads = []
# Добавляю потоки с функцией сохранения в файл в список потоков
for link in modellinks:
  threads.append(threading.Thread(target=resultsmodel, args=(link,)))

# %%
# Технологии

def parserabout(soup):
    text = '## '
    pages = soup.find('div', class_='articles-detail__technology-txt')
    if pages is None:
      print(soup.find('title').text.split(' – ')[0])
      print(soup)
    else:
        content = pages.select('div[class*="text-"]')
        text += ''.join(i.text+'\n' for i in content)
    return text

url = "https://www.kia.ru/ajax/page/technologies/more?limit=45&page=1"

headers = {
    "Referer": "https://www.kia.ru/about/technologies/",  # Example Referer header
}

response = requests.get(url, headers=headers)
json_data = response.text

data = json.loads(json_data)

ids = [tech['id'] for tech in data['content']['technologies']]

static_url = 'https://www.kia.ru/about/technologies/'
urls = []

for id in ids:
    urls.append(static_url+id)

def resultsabout(link):

  print(link)
  content = requests.get(link)
  if content.status_code == 200:
    #constructor-block
    text = ''
    html = ''.join(line.strip() for line in content.text.split("\n"))
    soup = BeautifulSoup(html, "html.parser")
    name = soup.find('title').text.split(' – ')[0]
    text += parserabout(soup)
  savetxt('about', name.replace('/','-')+'.txt', text)
  print('Done '+ name)
print(urls)
for link in urls:

# Добавляю потоки с функцией сохранения в файл в список потоков
  threads.append(threading.Thread(target=resultsabout, args=(link,)))
# Out:
json_data = response.text
data = json.loads(json_data)
all_article_list = []

for article in data["content"]["media_center"]["magazine"]:
    code = article["code"]
    all_article_list.append(static_url + code + '/')

url = "https://www.kia.ru/ajax/page/mediacenter/news/more?limit=100&page=1"
static_url = "https://www.kia.ru/press/news/"
response = requests.get(url=url, headers=HEADERS)
json_data = response.text
data = json.loads(json_data)
all_article_list = []

for article in data["content"]["media_center"]["news"]:
    code = article["code"]
    all_article_list.append(static_url + code + '/')

def resultspress(link):

  print(link)
  content = requests.get(link)
  if content.status_code == 200:
    #constructor-block
    text = ''
    html = ''.join(line.strip() for line in content.text.split("\n"))
    soup = BeautifulSoup(html, "html.parser")
    name = soup.find('title').text.split(' – ')[0]
    head_press = soup.h1.text.strip() #заголовок статьи
    all_img_list, all_img = [], ""
    try:
      [all_img_list.append(img.find("img").attrs.get("src")) for img in soup.find_all("div", class_="articles-detail__content__offset")]  # все фото из статьи
      for img in all_img_list:
        all_img += img + ","
    except:
      all_img = ""

    try:
      date_press = soup.select_one("div.articles-detail__date").text.strip()  # дата статьи
      for val in soup.find_all("div", class_="g-container"):
        for child in val.children:
          if date_press in child.text:
            text += f"## {head_press}>\n"
            text += child.text.replace("\xa0", " ")
            text += f"\nФотографии из статьи: {all_img[:-1]}\n\n"
    except:
      for val in soup.find_all("div", class_="g-container"):
        for child in val.children:
          if child.find("h1") is not None and child.find("h1") != -1:
            text += f"## {head_press}\n"
            text += child.text.replace("\xa0", " ")
            text += f"\nФотографии из статьи: {all_img[:-1]}\n\n"
    if text != '':
      savetxt('press', name.replace('/','-')+'.txt', text)
      print('Done '+ name)
#threads = []
for link in all_article_list:
  threads.append(threading.Thread(target=resultspress, args=(link,)))

# %%
 # Start all threads
for x in threads:
  x.start()
  time.sleep(0.5)

 # Wait for all of them to finish
for x in threads:
  x.join()
# Out:
# https://www.kia.ru/models/picanto/desc/
# https://www.kia.ru/models/rio/desc/
# https://www.kia.ru/models/rio-x/desc/
# https://www.kia.ru/models/ceed/desc/
# https://www.kia.ru/models/ceed_sw/desc/
# https://www.kia.ru/models/cerato/desc/
# https://www.kia.ru/models/k5/desc/
# https://www.kia.ru/models/stinger/desc/
# https://www.kia.ru/models/k9/desc/
# https://www.kia.ru/models/soul/desc/
# https://www.kia.ru/models/seltos/desc/
# https://www.kia.ru/models/sportage/desc/
# https://www.kia.ru/models/sorento/desc/
# https://www.kia.ru/models/mohave/desc/
# Done Kia K9 2022
# https://www.kia.ru/models/carnival/desc/
# https://www.kia.ru/about/technologies/f4960620-1702-457a-99df-485f60ceeee9
# https://www.kia.ru/about/technologies/f55ce731-dbc8-4137-88ea-ffef208a8d0e
# https://www.kia.ru/about/technologies/b8b0ad36-deda-450d-86df-ed9eda0e7059
# https://www.kia.ru/about/technologies/882bec53-f5f1-43fa-a21e-093c17153c85
# Done Kia Connect
# https://www.kia.ru/about/technologies/adb18898-32da-42e6-afe6-1f85838971f7
# Done Hyundai Motor Group запускает проект помощи маломобильным гражданам EnableLA в Лос-Анджелесе
# https://www.kia.ru/press/news/311/
# Done В Сеуле открылось интерактивное пространство Kia360
# https://www.kia.ru/press/news/310/
# Done Kia представила электрический шоу-кар  Soul EV Boardmasters Edition
# https://www.kia.ru/press/news/309/
# Done В России предложена новая шестиместная версия внедорожника Kia Mohave
# Done Система контроля внимания водителя (DAW)
# https://www.kia.ru/press/news/308/
# Done Владельцам автомобилей Kia станет удобнее пользоваться сервисами Яндекс
# https://www.kia.ru/press/news/307/
# Done Kia Russia & CIS объявляет результаты продаж в России в июле 2021 года
# https://www.kia.ru/press/news/306/
# Done Kia объявляет итоги мировых продаж за июль 2021 года
# https://www.kia.ru/press/news/305/
# Done В Калининграде началось производство обновленного седана Kia Cerato
# https://www.kia.ru/press/news/304/
# Done Kia Russia & CIS продолжает сотрудничество с Центром реабилитации детей-инвалидов «Семь-Я»
# https://www.kia.ru/press/news/303/
# Done Обновленный Kia Cerato сертифицирован для российского рынка
# https://www.kia.ru/press/news/302/
# Done В Корее представлена гибридная версия Kia Sportage пятого поколения
# https://www.kia.ru/press/news/301/
# Done Почетный председатель правления Hyundai Motor Group Чонг Монг Ку включен в Автомобильный зал славы
# https://www.kia.ru/press/news/300/
# Done Kia объявляет итоги мировых продаж за июнь 2021 года
# https://www.kia.ru/press/news/299/
# Done В Европе представлен обновленный Kia Ceed
# https://www.kia.ru/press/news/297/
# Done Kia предложила в Корее представительскую версию кроссвэна Carnival
# https://www.kia.ru/press/news/296/
# Done Новый Kia Sportage пользуется рекордным спросом в Корее
# https://www.kia.ru/press/news/295/
# https://www.kia.ru/press/news/294/
# Done Мировая премьера пятого поколения кроссовера Kia Sportage
# Done Kia Russia & CIS объявляет результаты продаж в России в июне 2021 года
# https://www.kia.ru/press/news/291/
# Done Kia Russia & CIS начинает процесс трансформации бренда в России и странах СНГ
# https://www.kia.ru/press/news/290/
# Done Kia Europe и Uber объявляют о партнерстве в области электрического транспорта
# https://www.kia.ru/press/news/289/
# Done Kia удостоена шести наград конкурса «Автомобиль года в России
# https://www.kia.ru/press/news/293/
# Done Kia объявляет итоги мировых продаж за май 2021 года
# https://www.kia.ru/press/news/288/
# Done Мировые продажи Kia превысили 50 миллионов автомобилей
# https://www.kia.ru/press/news/287/
# Done Вдохновляющий дизайн Kia Sportage пятого поколения
# https://www.kia.ru/press/news/286/
# Done Kia объявляет результаты продаж в России в мае 2021 года
# https://www.kia.ru/press/news/285/
# Done В Корее состоялась премьера флагманского седана Kia K9
# Done Kia Sorento получил новый бензиновый двигатель V6 3,5 л

# %%
url = "https://www.kia.ru/kiaflex/"
response = requests.get(url=url, headers=HEADERS).text
html = ''.join(line.strip() for line in response.split("\n"))
soup = BeautifulSoup(html, "html.parser")

savetxt('kiaflex', 'kiaflex.txt', '# '+parser(soup))
# Out:
# True

# %%
#Тест ассортимента

base_url = "https://www.kia.ru/ajax/page/accessories/filter?sort=sort&order=desc&page=1"


headers = {
    "Referer": "https://www.kia.ru/service/accessories/",  # Example Referer header
}

bigdata = []


start_page = 1

while True:
    current_url = base_url + str(start_page)
    response = requests.get(current_url, headers=headers)
    json_data = response.text
    data = json.loads(json_data)
    if len(data['content']['accessories']) == 0: break



    for tech in data['content']['accessories']:
      bigdata.append(tech)

    start_page += 1

text = '# Аксесуары\n'
for i in bigdata:
  if i['material'] == '':
    i['material'] = {}
    i['material']['name'] = ''
  text += f'## Наименование: {i["name"].strip()}, Фото: https://cdn.kia.ru/resize/1295x632{i["image"]},'
  text += f'Артикул: {i["article"]}, Материал: {i["material"]["name"].strip()}.\n{i["text"]}'
  if i['technical_features'] is not None:
    html = ''.join(line.strip() for line in i['technical_features'].split("\n"))
    soup = BeautifulSoup(html, "html.parser")
    technical_features = '. '.join(soup.strings)
  text += technical_features + '\n'
savetxt('accessories', 'accessories.txt', text)
# Out:
# True

# %%
# Test oil page
oil_res = {}
headers={"Referer": 'https://www.kia.ru/'}

json_data = json.loads(requests.get('https://www.kia.ru/ajax/decoder/model_lines',
                         headers={"Referer": 'https://www.kia.ru/'}).text)
model_lines = list(json_data['content']['model_lines'])
print(datetime.datetime.now())
for id in model_lines:
  try:
    model_line_id = id['id']
    json_data = json.loads(requests.get('https://www.kia.ru/ajax/decoder/years',
                              params={'model_line_id': model_line_id},
                              headers=headers).text)
    years = list(json_data['content']['years'])
    for year in years:
        year = year['id']
        json_data = json.loads(requests.get('https://www.kia.ru/ajax/decoder/models',
                                params={'model_line_id': model_line_id, 'year': year},
                                headers=headers).text)
        models = list(json_data['content']['models'])
        for model in models:
          model_id = model['id']
          json_data = json.loads(requests.get('https://www.kia.ru/ajax/decoder/complectations',
                                params={'model_id': model_id},
                                headers=headers).text)
          complectations = list(json_data['content']['complectations'])
          for complectation in complectations:
            complectation_id = complectation['id']
            json_data = json.loads(
                          requests.get('https://www.kia.ru/ajax/page/oils/complectations/'+complectation_id,
                          headers=headers).text)
            oils = list(json_data['content']['oils'])
            car = json_data['content']['car']
            if oils != []:
              for oil in oils:
                com_name = car['model']['model_line']['name'] + ' '
                com_name += car['model']['generation']['name'] +'/ '+str(year)+'/ '
                com_name += car['model']['carcass']['name'] + '/ '
                com_name += str(car['modification']['engine']['engine_volume']) + ' '
                com_name += car['modification']['engine']['engine_type'] + '/ '
                com_name += car['modification']['engine']['fuel_type'] + '/ '
                com_name += car['modification']['transmission']['drive'] + '/ '
                com_name += car['modification']['transmission']['gearbox'] + '/ '

                if not oil['name'] in oil_res.keys():
                  oil_res[oil['name']] = [oil['description'],com_name]
                else:
                  oil_res[oil['name']] += [com_name]
  except Exception as e:
    print(e)
print(oil_res)
print(datetime.datetime.now())
# Out:
# 2023-10-13 20:40:15.333119
# list indices must be integers or slices, not str
# {'REPSOL ELITE EVOLUTION LONG LIFE C3/SN 5W30': ['Предназначено для использования в высокофорсированных бензиновых и дизельных двигателях, оборудованных сажевым фильтром. Благодаря высокому качеству, данное масло выделяется низким образованием отложений. Снижает трение, защищает двигатель от износа и имеет большую стойкость к окислению, что позволяет сохранять все свойства в течение длительного срока.', 'Carnival KA4/ 2022/ кроссвэн (7 мест)/ 2.2 CRDi/ Дизель/ Передний/ Автомат/ ', '
# S-OIL 7 GOLD #9 C3 5W-30 Предназначено для использования в высокофорсированных бензиновых и дизельных двигателях, оборудованных сажевым фильтром или трехкомпонентным нейтрализатором. Благодаря синтетическому базовому маслу высокой степени очистки, сохраняет свои свойства в течение длительного срока. Превосходные очищающие свойства препятствуют образованию нагара и отложений в двигателе.
# S-OIL 7 RED #9 SP 5W-40 Предназначено для использования во всех бензиновых двигателях, включая двигатели с турбонаддувом и системой непосредственного впрыска топлива. Предотвращает возникновение проблем, связанных с ранним зажиганием на низких оборотах в двигателях T-GDI. Обеспечивает превосходные эксплуатационные характеристики, благодаря стабильным свойствам базового масла и высокой степени его очистки и повышенную прочность масляной пленки в рабочем состоянии. Новейший пакет присадок препятствует образованию нагара и отложений в двигателе.

# %%
# !echo "# Технологии" > database.txt
# !cat result/about/*.txt >> database.txt
# !cat result/press/*.txt >> database.txt
# !cat result/models/*.txt >> database.txt
# !cat result/kiaflex/*.txt >> database.txt
# !cat result/accessories/*.txt >> database.txt
# !zip -r result.zip result database.txt
# !zip database.zip database.txt
# Out:
#   adding: result/ (stored 0%)
#   adding: result/press/ (stored 0%)
#   adding: result/press/Kia EV6 признан «Автомобилем года» по версии журнала «What Car?».txt (deflated 65%)
#   adding: result/press/На заводе «Автотор» началось производство  Kia Sportage пятого поколения.txt (deflated 64%)
#   adding: result/press/Kia Russia & CIS начинает процесс трансформации бренда в России и странах СНГ.txt (deflated 70%)
#   adding: result/press/Kia EV6 удостоен титула Car of the Year 2022 в Европе.txt (deflated 64%)
#   adding: result/press/Kia объявляет результаты мировых продаж за ноябрь 2021 года.txt (deflated 60%)
#   adding: result/press/В Сеуле открылось интерактивное пространство Kia360.txt (deflated 69%)
#   adding: result/press/Kia завоевала две награды премии «Внедорожник года 2021».txt (deflated 67%)
#   adding: result/press/Kia Russia & CIS объявляет результаты продаж в России в январе 2022 года.txt (deflated 61%)
#   adding: result/press/Сервис подписки Kia Flex стал доступен в Ростове-на-Дону и Челябинске.txt (deflated 63%)
#   adding: result/press/Kia объявляет итоги мировых продаж за май 2021 года.txt (deflated 61%)
#   adding: result/press/Kia Russia & CIS объявляет результаты продаж в России в июле 2021 года.txt (deflated 60%)
#   adding: result/press/Мировая премьера нового Kia Niro состоялась на автосалоне Mobility Show в Сеуле.txt (deflated 66%)
#   adding: result/press/На заводе «Автотор» началось производство обновленного Kia Cerato по полному циклу.txt (deflated 67%)
#   adding: result/press/Стартовали продажи Kia К5 2022-го модельного года.txt (deflated 66%)
#   adding: result/press/Электрический кроссовер Kia EV6 установил рекорд Гиннесса в США.txt (deflated 59%)
#   adding: result/press/На рынке США представлен Kia Sportage PHEV.txt (deflated 67%)
#   adding: result/press/Стартовали продажи обновленного Kia Ceed.txt (deflated 66%)
#   adding: result/press/«Движение, которое помогает»: Kia присоединяется к проекту «Доброшрифт».txt (deflated 63%)
#   adding: result/press/Мировая премьера пятого поколения кроссовера Kia Sportage.txt (deflated 72%)
#   adding: result/press/Три модели Kia вошли в число лидеров рейтинга остаточной стоимости «Автостат».txt (deflated 65%)
#   adding: result/press/Kia удостоена шести наград конкурса «Автомобиль года в России.txt (deflated 68%)
#   adding: result/press/Мировые продажи Kia превысили 50 миллионов автомобилей.txt (deflated 62%)
#   adding: result/press/Рамный внедорожник Kia Mohave 2022-го модельного года стал доступен для заказа.txt (deflated 66%)
#   adding: result/press/Новый Kia Sportage пользуется рекордным спросом в Корее.txt (deflated 59%)
#   adding: result/press/Продажи обновленного Kia Cerato в России начнутся 8 сентября.txt (deflated 60%)
#   adding: result/press/Kia EV6 получил награду «Кроссовер года» по версии TopGear.com.txt (deflated 62%)
#   adding: result/press/Знаменитый дизайнер Петер Шрайер стал героем книги «Истоки и крылья».txt (deflated 63%)
#   adding: result/press/Электрические модели Kia будут представлены на автосалоне IAA Mobility в Мюнхене.txt (deflated 60%)
#   adding: result/press/Kia предложила в Корее представительскую версию кроссвэна Carnival.txt (deflated 63%)
#   adding: result/press/Kia объявляет итоги мировых продаж за июль 2021 года.txt (deflated 61%)
#   adding: result/press/Hyundai Motor Group запускает проект помощи маломобильным гражданам EnableLA в Лос-Анджелесе.txt (deflated 64%)
#   adding: result/press/Kia Russia & CIS объявляет результаты продаж в России в августе 2021 года.txt (deflated 62%)
#   adding: result/press/Kia представила электрический шоу-кар  Soul EV Boardmasters Edition.txt (deflated 66%)
#   adding: result/press/В Корее представлена гибридная версия Kia Sportage пятого поколения.txt (deflated 63%)
#   adding: result/press/Вдохновляющий дизайн Kia Sportage пятого поколения.txt (deflated 69%)
#   adding: result/press/Новая модель Kia получит название Carens.txt (deflated 59%)
#   adding: result/press/На российский рынок выходит городской купе-кроссовер XCeed 2022-го модельного года.txt (deflated 68%)
#   adding: result/press/Kia публикует первые изображения нового поколения кроссовера Niro.txt (deflated 62%)
#   adding: result/press/Kia приняла участие в благотворительном футбольном матче в пользу Фонда Хабенского.txt (deflated 65%)
#   adding: result/press/В России предложена новая шестиместная версия внедорожника Kia Mohave.txt (deflated 65%)
#   adding: result/press/Kia запустила чатбот в WhatsApp для клиентов сервиса.txt (deflated 59%)
#   adding: result/press/Стартовали продажи Kia Rio 2022-го модельного года.txt (deflated 63%)
#   adding: result/press/Электромобиль Kia EV6 вошел в шорт-лист конкурса Car of the Year 2022 в Европе.txt (deflated 59%)
#   adding: result/press/Kia Russia & CIS объявляет результаты продаж в России в сентябре 2021 года.txt (deflated 62%)
#   adding: result/press/Kia Russia & CIS продолжает сотрудничество с Центром реабилитации детей-инвалидов «Семь-Я».txt (deflated 62%)
#   adding: result/press/Hyundai Motor Group представляет Factory Safety Service Robot.txt (deflated 69%)
#   adding: result/press/Kia Sorento получил новый бензиновый двигатель V6 3,5 л.txt (deflated 61%)
#   adding: result/press/Hyundai Motor Group представляет на форуме Hydrogen Wave стратегию популяризации водородной энергии до 2040 года.txt (deflated 75%)
#   adding: result/press/Kia представляет кроссвэн Carnival  2022-го модельного года.txt (deflated 64%)
#   adding: result/press/Санг Гвон Джонг назначен президентом Kia Russia & CIS.txt (deflated 67%)
#   adding: result/press/В России начнутся продажи кроссовера Kia Soul 2022-го модельного года.txt (deflated 64%)
#   adding: result/press/1 сентября состоялась премьера европейской версии нового Kia Sportage.txt (deflated 69%)
#   adding: result/press/Kia планирует начать продажи электрического кроссовера EV6 в России в 2022-м году.txt (deflated 69%)
#   adding: result/press/Kia Russia & CIS объявляет результаты продаж в России
#   adding: result/press/Спортивный фастбек Kia Stinger доступен для заказа в версии 2022-го модельного года.txt (deflated 66%)
#   adding: result/press/Kia представляет первый дилерский центр в России в концепции Kia Store.txt (deflated 64%)
#   adding: result/press/Kia инвестировала в развитие сети зарядных станций IONITY.txt (deflated 65%)
#   adding: result/press/Kia Russia & CIS объявляет результаты продаж в России в июне 2021 года.txt (deflated 61%)
#   adding: result/press/Рафаэль Надаль станет вдохновляющим примером использования электромобиля Kia EV6.txt (deflated 63%)
#   adding: result/press/Kia объявляет цены и комплектации обновленного Ceed.txt (deflated 72%)
#   adding: result/press/Kia EV6 удостоен награды конкурса «Автомобиль года в Германии».txt (deflated 63%)
#   adding: result/press/Kia представила Sorento PHEV, подготовленные специально для рейд-ралли по пустыне.txt (deflated 63%)
#   adding: result/press/Kia Sorento Plug-in Hybrid выйдет на рынок США.txt (deflated 69%)
#   adding: result/press/Модели Hyundai IONIQ 5 и Kia EV6.txt (deflated 65%)
#   adding: result/press/Kia объявляет результаты продаж в России в мае 2021 года.txt (deflated 62%)
#   adding: result/press/В Узбекистане начались продажи седана Kia K8.txt (deflated 61%)
#   adding: result/press/Kia на автосалоне IAA Mobility: премьера электрических моделей Sportage PHEV и EV6.txt (deflated 69%)
#   adding: result/press/Kia представит в России седан К9.txt (deflated 60%)
#   adding: result/press/В Европе представлен обновленный Kia Ceed.txt (deflated 71%)
#   adding: result/press/Kia представляет новый Sportage для российского рынка.txt (deflated 62%)
#   adding: result/press/В Корее состоялась премьера флагманского седана Kia K9.txt (deflated 71%)
#   adding: result/press/В Индии состоялась мировая премьера нового компактного минивэна Kia Carens.txt (deflated 67%)
#   adding: result/press/Обновленный Kia Ceed сертифицирован для российского рынка.txt (deflated 67%)
#   adding: result/about/ (stored 0%)
#   adding: result/about/Электронноуправляемая адаптивная подвеска (ECS).txt (deflated 42%)
#   adding: result/about/Система распознавания дорожных знаков (SLIF).txt (deflated 44%)
#   adding: result/about/Приборная панель Supervision 12.3".txt (deflated 40%)
#   adding: result/about/Встроенная навигация в Вашем автомобиле.txt (deflated 60%)
#   adding: result/about/Интеллектуальный круиз-контроль (SCC).txt (deflated 48%)
#   adding: result/about/Система предотвращения выезда из полосы движения (LKA).txt (deflated 52%)
#   adding: result/about/Динамическая подсветка интерьера Mood Lamp.txt (deflated 42%)
#   adding: result/about/Проекционный дисплей (HUD).txt (deflated 44%)
#   adding: result/about/Ассистент движения в полосе (LFA).txt (deflated 49%)
#   adding: result/about/Система выбора режима движения Drive Mode Select.txt (deflated 49%)
#   adding: result/about/Система контроля внимания водителя (DAW).txt (deflated 51%)
#   adding: result/about/Современные двигатели Kia.txt (deflated 58%)
#   adding: result/about/Электронное управление трансмиссией (Shift by Wire).txt (deflated 49%)
#   adding: result/about/Современные системы полного привода Kia.txt (deflated 61%)
#   adding: result/about/Система бесключевого доступа Smart Key и запуск двигателя кнопкой.txt (deflated 41%)
#   adding: result/about/Интеллектуальный круиз-контроль (SCC) с функцией Stop&Go.txt (deflated 57%)
#   adding: result/about/Kia Connect.txt (deflated 63%)
#   adding: result/about/Камеры контроля слепых зон - Камеры, отображающие изображение в слепых зонах на панелиприборов (BVM).txt (deflated 49%)
#   adding: result/about/Система кругового обзора (SVM) .txt (deflated 45%)
#   adding: result/about/Система предотвращения фронтального столкновения (FCA).txt (deflated 54%)
#   adding: result/about/Мультимедийная система AVN с широкоформатным дисплеем и встроенной навигацией.txt (deflated 40%)
#   adding: result/about/Современные коробки передач Kia.txt (deflated 61%)
#   adding: result/about/Роботизированная трансмиссия 8DCT.txt (deflated 56%)
#   adding: result/about/Интеллектуальная система автоматической парковки (SPAS).txt (deflated 61%)
#   adding: result/about/Система безопасного выхода (SEA).txt (deflated 51%)
#   adding: result/about/Беспроводная зарядка для мобильных устройств.txt (deflated 51%)
#   adding: result/about/Ассистент управления дальним светом (HBA).txt (deflated 53%)
#   adding: result/about/Система контроля слепых зон (BCW).txt (deflated 48%)
#   adding: result/about/Аудиосистемы премиум-класса.txt (deflated 44%)
#   adding: result/about/Мультимедийные системы Kia без встроенной навигации (AV).txt (deflated 58%)
#   adding: result/about/Дистанционный запуск двигателя с ключа.txt (deflated 51%)
#   adding: result/about/Система предупреждения при выезде с парковки задним ходом (RCCW).txt (deflated 51%)
#   adding: result/about/Мультимедийные системы Kia со встроенной навигацией (AVN).txt (deflated 61%)
#   adding: result/about/Система предотвращения столкновения с автомобилем в слепой зоне (BCA).txt (deflated 52%)
#   adding: result/accessories/ (stored 0%)
#   adding: result/accessories/accessories.txt (deflated 88%)
#   adding: result/kiaflex/ (stored 0%)
#   adding: result/kiaflex/kiaflex.txt (deflated 71%)
#   adding: result/models/ (stored 0%)
#   adding: result/models/Kia K9 2022.txt (deflated 74%)
#   adding: result/models/Kia Carnival 2022.txt (deflated 89%)
#   adding: result/models/Kia Ceed 2022.txt (deflated 86%)
#   adding: result/models/Kia Sorento 2022.txt (deflated 94%)
#   adding: result/models/Kia Seltos 2022.txt (deflated 94%)
#   adding: result/models/Kia Cerato 2022.txt (deflated 91%)
#   adding: result/models/Kia K5 2022.txt (deflated 92%)
#   adding: result/models/Kia Mohave 2022.txt (deflated 85%)
#   adding: result/models/Kia Rio 2022.txt (deflated 86%)
#   adding: result/models/Kia Ceed SW 2022.txt (deflated 86%)
#   adding: result/models/Kia Rio X 2022.txt (deflated 88%)
#   adding: result/models/Kia Picanto 2022.txt (deflated 85%)
#   adding: result/models/Kia Stinger 2022.txt (deflated 91%)
#   adding: result/models/Kia Sportage 2022.txt (deflated 93%)
#   adding: result/models/Kia Soul 2022.txt (deflated 92%)
#   adding: database.txt (deflated 86%)
#   adding: database.txt (deflated 86%)

# %%
# !rm -rf /content/drive/MyDrive/KIA_PARSER

# %%
# !mkdir -p /content/drive/MyDrive/KIA_PARSER

# %%
# !cp -f database.zip /content/drive/MyDrive/KIA_PARSER/database.zip
