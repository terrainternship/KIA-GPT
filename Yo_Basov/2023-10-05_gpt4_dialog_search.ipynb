# %% [markdown]
# ### Установка и загрузка необходимых модулей

# %%
# !pip install faiss-cpu langchain openai tiktoken
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 75.1 MB/s eta 0:00:00
# Collecting langchain
#   Downloading langchain-0.0.309-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 81.5 MB/s eta 0:00:00
# Collecting openai
#   Downloading openai-0.28.1-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 9.8 MB/s eta 0:00:00
# Collecting tiktoken
#   Downloading tiktoken-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 85.5 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.21)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.8.5)
# Requirement already satisfied: anyio<4.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.7.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.1-py3-none-any.whl (27 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langsmith<0.1.0,>=0.0.40 (from langchain)
#   Downloading langsmith-0.0.42-py3-none-any.whl (39 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.23.5)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.10.13)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.2.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2023.6.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain) (1.1.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.1 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (4.5.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->langchain) (23.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: faiss-cpu, mypy-extensions, marshmallow, jsonpointer, typing-inspect, tiktoken, langsmith, jsonpatch, openai, dataclasses-json, langchain
# Successfully installed dataclasses-json-0.6.1 faiss-cpu-1.7.4 jsonpatch-1.33 jsonpointer-2.4 langchain-0.0.309 langsmith-0.0.42 marshmallow-3.20.1 mypy-extensions-1.0.0 openai-0.28.1 tiktoken-0.5.1 typing-inspect-0.9.0

# %%
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.document_loaders import TextLoader
import os
import getpass
import re
import requests
import openai
from langchain.docstore.document import Document

# %%
# Получение ключа API от пользователя и установка его как переменной окружения
openai_key = getpass.getpass("OpenAI API Key:")
os.environ["OPENAI_API_KEY"] = openai_key
openai.api_key = openai_key
# Out:
# OpenAI API Key:··········

# %% [markdown]
# ### Создаем текстовый файл с диалогами из Гугл таблицы

# %%
import pandas as pd
import requests
from io import BytesIO

# функция для загрузки таблицы по ссылке из гугл драйв
#def load_xls_pd(url: str) -> str:
def load_xls_pd(url: str, sheet_name: str = 0) -> str:

    # Extract the document ID from the URL
    match_ = re.search('/spreadsheets/d/([a-zA-Z0-9-_]+)', url)
    if match_ is None:
        raise ValueError('Invalid Google Sheets URL')
    doc_id = match_.group(1)

    if sheet_name is None:
        raise ValueError('Invalid sheet_name')

    # Download the table as pandas
    response = requests.get(f'https://docs.google.com/spreadsheets/d/{doc_id}/export?format=xlsx')
    response.raise_for_status()     #проверяет статус код ответа. Если получен ответ с кодом ошибки (4xx или 5xx), вызывается исключение HTTPError.
    #data = pd.read_excel(BytesIO(response.content), sheet_name=0)  #чтение первого листа из книги
    data = pd.read_excel(BytesIO(response.content),sheet_name = sheet_name, header=None) #чтение конкретного листа из Книги Excel

    ''' Разъяснение:
        Когда мы хотим прочитать данные Excel с помощью функции pd.read_excel(), она требует передачи ей пути к файлу или объекта, представляющего файл.
        В параметре io функции pd.read_excel() необходимо указать путь к файлу (в виде строки, содержащей путь к файлу) или объект файлового типа (такой как BufferedWriter, BufferedReader и другие).
        response.content возвращает содержимое ответа на запрос HTTP в виде байтового массива (bytes array).
        Чтобы передать эти данные в функцию pd.read_excel(), нужно создать объект файла из байтового массива.
        Для этой цели используется объект BytesIO из модуля io, который предоставляет интерфейс для работы с данными в памяти, как если бы они находились в файле.
    '''
    return data

# Шаг 1: Загрузить xlsx файл из Google Drive
google_sheet_url = "https://docs.google.com/spreadsheets/d/1uKrXGbXKhbvKjYU7Ao_XlsS0vQgOy8UaQxD-nZ3M8Sg/edit?usp=sharing"
sheet_name='dialogs_2023-09-11_20-54-18.csv'

#data = load_xls_pd(google_sheet_url)   #если в таблице только один лист
data = load_xls_pd(google_sheet_url, sheet_name)

# Шаг 2: Извлечь столбец с диалогами
text_column = data[data.columns[1]]

# Шаг 3: Заменить "operatorMessage: Здравствуйте" на "<operatorMessage: Здравствуйте>" для удобства деления на чанки в дальнейшем
text_column = text_column.str.replace("operatorMessage: Здравствуйте", "<operatorMessage: Здравствуйте>")

# Шаг 4: Сохранить в файл "Dialogs__.txt" в своей папке
file_path = "/content/kia_dialogs.txt"

with open(file_path, "w", encoding="utf-8") as f:
    for text in text_column:
        f.write(str(text) + "\n")

print("Файл kia_dialog.txt успешно сохранен!")
# Out:
# Файл kia_dialog.txt успешно сохранен!

# %% [markdown]
# ### Функция для загрузки диалогов из Гугл докс

# %%
def load_document_text(url: str) -> str:
    # Extract the document ID from the URL
    match_ = re.search('/document/d/([a-zA-Z0-9-_]+)', url)
    if match_ is None:
        raise ValueError('Invalid Google Docs URL')
    doc_id = match_.group(1)

    # Download the document as plain text
    response = requests.get(f'https://docs.google.com/document/d/{doc_id}/export?format=txt')
    response.raise_for_status()
    text = response.text

    return text

# %% [markdown]
# Деление на чанки текстового файла

# %%
loader = TextLoader("/content/kia_dialogs.txt")
documents = loader.load()

# %%
#type(documents)

# %%
text_splitter = CharacterTextSplitter(separator="<", chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

'''source_chunks = []     #разные методы деления текста
splitter = CharacterTextSplitter(separator="\n", chunk_size=1000, chunk_overlap=0)

for chunk in splitter.split_text(documents):
    source_chunks.append(Document(page_content=chunk, metadata={}))'''
# Out:
# WARNING:langchain.text_splitter:Created a chunk of size 2023, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1652, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1187, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1114, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1721, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1051, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1056, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1490, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1773, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1134, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1108, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1028, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1693, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1154, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1370, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3020, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3263, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1582, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1154, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1235, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1530, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1015, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2216, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1434, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3356, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1245, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1004, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1507, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1379, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1066, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1752, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1157, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1025, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1080, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1154, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2956, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2112, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 4587, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 16102, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1957, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1162, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1562, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2079, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1434, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2213, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1485, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2368, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2804, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1054, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 4560, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1363, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3563, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 4162, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1970, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2354, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1684, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2839, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2686, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3626, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1030, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3217, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2253, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1497, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2316, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1708, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2119, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3990, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1346, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1694, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1085, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1146, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2181, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1501, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1330, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1400, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1999, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1052, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1508, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2093, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1512, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1054, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1724, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1367, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1185, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1293, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 4649, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2168, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2490, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1915, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2490, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2757, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1770, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3316, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1914, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1845, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1068, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1815, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1304, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1324, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1760, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1337, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2786, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1074, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1032, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2031, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2127, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2061, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1705, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1914, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1733, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1535, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2458, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1263, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1479, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1502, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1156, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1862, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1613, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 4286, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1801, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1147, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1032, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2341, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2949, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1608, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1241, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1064, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1202, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1607, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1332, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1645, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1646, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1919, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2888, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1481, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1705, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1099, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 5729, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1373, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2015, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1251, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3482, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1382, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1898, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1572, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1006, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1775, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1188, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1648, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1263, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1018, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2162, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1246, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1639, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2143, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1035, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1206, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 
which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2086, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2207, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1896, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1102, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1775, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1829, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3507, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1751, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1298, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2227, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1721, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2233, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2128, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 7700, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1240, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3179, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1706, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1802, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1773, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1097, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1445, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1094, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1084, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1299, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1375, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1121, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2918, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1247, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1294, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2210, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3365, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3475, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1666, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2022, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2560, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1234, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1302, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2618, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1088, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2034, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1912, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1297, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1159, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1874, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2375, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2006, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2531, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2943, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1652, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2935, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1197, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 6212, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1267, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1314, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1718, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1782, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1338, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2683, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1718, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2081, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1758, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1328, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1378, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1030, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2745, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1061, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1308, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2167, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1397, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1105, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1494, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1935, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1288, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2221, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1172, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1353, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1662, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1068, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1536, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2286, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1327, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3215, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1830, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1187, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1164, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1097, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 3740, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1093, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1330, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2364, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1046, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1711, which is longer than the specified 1000
# 'source_chunks = []     #разные методы деления текста\nsplitter = CharacterTextSplitter(separator="\n", chunk_size=1000, chunk_overlap=0)\n\nfor chunk in splitter.split_text(documents):\n    source_chunks.append(Document(page_content=chunk, metadata={}))'

# %%
# всего получилось чанков:
len(docs)
# Out:
# 2334

# %%
# первый чанк
print(docs)
page_content = docs[0].page_content
# длина первого чанка
print(len(page_content))

# %%
# третий чанк:
page_content = docs[2].page_content
print(page_content)
# длина третьего чанка
print(len(page_content))
# Out:
# operatorMessage: Здравствуйте>.
# Уточните, пожалуйста, какая информация Вас интересует? clientMessage: подскажите, я сейчас нахожусь в республике Казахстан, прошлое ТО проходила в России, в сервисном дилерском центре Киа, могу ли я пройти ТО в республике Казахстан также в сервисном центре?  operatorMessage: Уточните, пожалуйста, как к Вам можно обращаться? clientMessage: Мария operatorMessage: Мария, очень приятно. Пройти ТО у официального дилера за границей Вы можете (список на сайте www.kia.com). При этом у Вас должны стоять отметки в сервисной книжке и должен быть заказ- наряд. operatorMessage: При любом обращении к Дилеру на территории РФ, рекомендуем добавить эти отметки в историю ТО в базу официальных дилеров Киа на территории РФ. Список дилеров доступен на официальном сайте по ссылке: https://www.kia.ru/dealers/. operatorMessage: Уточните, пожалуйста, могу еще чем-либо Вам помочь? clientMessage: сервизная книжка при себе, а что значит должен быть заказ наряд? clientMessage: и будет ли это ТО засчитываться на территории России? не слетит ли у меня гарантия, если я пройду у дилера ТО в республике Казахстан? operatorMessage: В Сервисной книжке автомобиля указано, что необходимо хранить заказ-наряды, выданные при проведении ТО в официальных дилерских центрах для сохранения гарантийных обязательств на автомобиль. operatorMessage: Как ранее информировали, решение о внесении отметки в базу официальных дилеров на территории РФ будет принимать инженер по гарантии официального дилерского центра на основании предоставленных Вами заказ-нарядов о выполненных работах. clientMessage: поняла, спасибо, верно я поняла https://kia-karaganda.kz что этот сервисный центр относится к списку официальных дилеров Киа? operatorMessage: Как информировали выше, список официальных дилеров за границей рекомендуем уточнять на сайте www.kia.com. operatorMessage: Уточните, пожалуйста, нужна ли консультация по другим вопросам? clientMessage: нет operatorMessage: Благодарим за обращение.
#  clientMessage: Здравствуйте.
# 2022

# %% [markdown]
# ### Обращение к ChatGPT для обработки диалогов

# %% [markdown]
# Установка температуры и вывода ChatGPT

# %%
temperature=0          # подставьте сюда необходимое значение
verbose=0              # подставьте сюда необходимое значение

# %%
#функция удобочитаемого вывода
def insert_newlines(text: str, max_len: int = 170) -> str:
    words = text.split()
    lines = []
    current_line = ""
    for word in words:
        if len(current_line + word + " ") > max_len:
            lines.append(current_line)
            current_line = ""
        current_line += word + " "
    lines.append(current_line)
    return " ".join(lines)

# %%
# Инструкция для GPT, которая будет подаваться в system
system_prompt = load_document_text('https://docs.google.com/document/d/1UrEzeIboxdz9rlaMcgZGi7DqNoMPvxHlgnNRQyWcBEw/edit?usp=sharing')   # подставьте сюда необходимое значение
user_prompt = load_document_text('https://docs.google.com/document/d/1VS5kGrUMKM-vc3d7oTdsrlQiLHRAmTZ8rM5Mb-MwO-8/edit?usp=sharing')   # подставьте сюда необходимое значение

# %% [markdown]
# ### Подключение Google Disk для сохранения обработанной базы

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from IPython.display import clear_output

# %%
itog = ""
#for i in range(len(docs)):
for i in range(272, 2334):
    #print(docs[i].page_content)  # Вывод текущего элемента списка
    print(i)
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": f"{user_prompt}\n{docs[i].page_content}"}
    ]
    completion = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k",
        messages=messages,
        temperature=temperature
    )
    answer = f'\n{insert_newlines(completion.choices[0].message.content)}'
    #itog += f'\n{answer}'

    # запись в файл
    with open("/content/drive/MyDrive/Stazhirovka_Kia/Dialogs/Useful_from_Dialog.txt", "a") as file:
        file.write(answer)
    clear_output()
# Out:
# 1860
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-cd900130e76e> in <cell line: 3>()
#      17
#      18     # запись в файл
# ---> 19     with open("/content/drive/MyDrive/Stazhirovka_Kia/Dialogs/Useful_from_Dialog.txt", "a") as file:
#      20         file.write(answer)
#      21     clear_output()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Stazhirovka_Kia/Dialogs/Useful_from_Dialog.txt'

# %%
answer
# Out:
# '\n## Раздел "Техническая поддержка" - Клиент обращается с вопросом о работе сайта и ссылке на дилерский центр, которая не работает. - Оператор предоставляет клиенту  актуальную ссылку на сайт с контактами дилеров. - Клиент уточняет, является ли сайт мошенническим. - Оператор подтверждает, что ссылка активна и информация указана  корректно. - Клиент продолжает сомневаться и указывает, что при переходе по ссылке на сайт дилера в Сочи пишет, что сайт не активен. - Оператор предоставляет контактные  данные дилерского центра в Сочи. - Клиент уточняет, что происходит с сайтом. - Оператор предоставляет клиенту ссылку на официальный сайт компании Киа. - Клиент  подтверждает, что сайт заработал и благодарит оператора. - Оператор уточняет, нуждается ли клиент в дополнительной помощи. - Клиент отвечает, что нет и завершает диалог.  ## Раздел "Техническая поддержка" '

# %% [markdown]
# ## Взаимодействие с векторной базой

# %% [markdown]
# ### Перевод в эмбеддинги и FAISS

# %%
# Инициализирум модель эмбеддингов
embeddings = OpenAIEmbeddings()

# Создадим индексную базу из разделенных фрагментов текста
db = FAISS.from_documents(docs, embeddings)

# %% [markdown]
# ### Сохранение и загрузка векторной базы из диалогов локально.

# %%
db.save_local("faiss_index")    #Сохранение локальной векторной базы
new_db = FAISS.load_local("faiss_index", embeddings)   #Загрузка локальной векторной базы
